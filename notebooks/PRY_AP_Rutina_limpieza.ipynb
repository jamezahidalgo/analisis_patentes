# %% [markdown]
# # Descripción
#
# Primero, se trabaja con similitud usando una métrica: jaccard_similarity u se usan dos versiones:
# + Con el texto sin tokenizar
# + Con el texto tokenizado
#
# Luego se trabaja con técnicas para calcular la similitud entre frases y términos:
#
# + Coincidencia de subcadenas
# + Búsqueda de prefijos/sufijos
# + Coincidencia fuzzy
# + Coincidencia basada en stemming
# + Usando expresiones regulares

# %% [markdown]
# # Descarga la data

# %%
# Crear la carpeta data si no existe
# !mkdir -p data

# Descargar el archivo y guardarlo en la carpeta data
# !wget -P data https://raw.githubusercontent.com/jamezahidalgo/datos/master/Concentracio%CC%81n_de_Minerales.csv
# Out:
# --2024-08-18 23:55:17--  https://raw.githubusercontent.com/jamezahidalgo/datos/master/Concentracio%CC%81n_de_Minerales.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5764305 (5.5M) [text/plain]
# Saving to: ‘data/Concentración_de_Minerales.csv’
#
# Concentracio%cc%81n 100%[===================>]   5.50M  --.-KB/s    in 0.09s
#
# 2024-08-18 23:55:17 (62.8 MB/s) - ‘data/Concentración_de_Minerales.csv’ saved [5764305/5764305]

# %% [markdown]
# # Instalación de librerías

# %%
# !pip install nltk scikit-learn
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
# !pip install fuzzywuzzy
# !pip install python-Levenshtein
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.25.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting Levenshtein==0.25.1 (from python-Levenshtein)
#   Downloading Levenshtein-0.25.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting rapidfuzz<4.0.0,>=3.8.0 (from Levenshtein==0.25.1->python-Levenshtein)
#   Downloading rapidfuzz-3.9.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Downloading python_Levenshtein-0.25.1-py3-none-any.whl (9.4 kB)
# Downloading Levenshtein-0.25.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 1.8 MB/s eta 0:00:00
# Downloading rapidfuzz-3.9.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 17.1 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.25.1 python-Levenshtein-0.25.1 rapidfuzz-3.9.6

# %% [markdown]
# # Carga de librerías necesarias

# %%
import numpy as np
import pandas as pd
import nltk
import string
import re

from fuzzywuzzy import fuzz
from nltk.stem import PorterStemmer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import jaccard_score

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

from collections import Counter

# %%
# Descargar recursos de NLTK
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# # Carga de la data

# %%
# Carga de datos
data = pd.read_csv("data/Concentración_de_Minerales.csv")
data.shape
# Out:
# (3192, 33)

# %% [markdown]
# # Preprocesamiento inicial

# %%
data.columns = data.columns.str.lower().str.replace(" ", "_", regex=True)
data.columns
# Out:
# Index(['#', 'jurisdiction', 'kind', 'display_key', 'lens_id',
#        'publication_date', 'publication_year', 'application_number',
#        'application_date', 'priority_numbers', 'earliest_priority_date',
#        'title', 'abstract', 'applicants', 'inventors', 'owners', 'url',
#        'document_type', 'has_full_text', 'cites_patent_count',
#        'cited_by_patent_count', 'simple_family_size', 'extended_family_size',
#        'sequence_count', 'cpc_classifications', 'ipcr_classifications',
#        'us_classifications', 'npl_citation_count',
#        'npl_resolved_citation_count', 'npl_resolved_lens_id(s)',
#        'npl_resolved_external_id(s)', 'npl_citations', 'legal_status'],
#       dtype='object')

# %%
# Extracción de las variables de interes
data_target = data[['title', 'abstract','publication_date', 'cpc_classifications']]

# %%
data_target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3192 entries, 0 to 3191
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                3192 non-null   object
#  1   abstract             3165 non-null   object
#  2   publication_date     3192 non-null   object
#  3   cpc_classifications  2472 non-null   object
# dtypes: object(4)
# memory usage: 99.9+ KB

# %% [markdown]
# ---
# **Observación**
#
# ---
# Existen patentes que no registran abstract

# %%
data_target[data_target['abstract'].isnull()]
# Out:
#                                                   title abstract  \
# 15    A METHOD AND AN ARRANGEMENT FOR CONTROLLING OF...      NaN
# 184                          BLASTING SYSTEM AND METHOD      NaN
# 271   ORE DRESSING MULTI-PRODUCTION-INDEX OPTIMIZATI...      NaN
# 287                        MINERAL FLOTATION SEPARATION      NaN
# 317   SYSTEM, METHOD AND APPARATUS FOR PLANNING DRIV...      NaN
# 577   METHOD AND APPARATUS FOR THE CONTROL OF A FLOT...      NaN
# 715   SYSTEM AND METHOD FOR PLANT CONTROL BASED ON F...      NaN
# 804         DYNAMIC CASCADED CLUSTERING FOR DYNAMIC VNF      NaN
# 947   CERMET OR CEMENTED CARBIDE MIXTURE AND THREE D...      NaN
# 1051  AUTOMATICALLY SCANNING AND REPRESENTING AN ENV...      NaN
# 1337  DATA DISCOVERY AND INTEGRATION BETWEEN DISPARA...      NaN
# 1446  METHOD AND SYSTEM FOR SECURING COMMUNICATIONS ...      NaN
# 1481  METHOD AND APPARATUS FOR MINING PEDESTRIAN PRO...      NaN
# 1822      METHODS AND SYSTEMS FOR PROCESSING IMAGE DATA      NaN
# 2070  A DECENTRALIZED ASSET CUSTODY AND CLEARING PLA...      NaN
# 2270  OBSTACLE DETECTION SYSTEM AND TRANSPORTATION V...      NaN
# 2379  GAS ANALYSIS APPARATUS, PROGRAM FOR GAS ANALYS...      NaN
# 2394      OBJECT MEMORY DATA FLOW INSTRUCTION EXECUTION      NaN
# 2530  METHOD, COMPUTER PROGRAM AND SYSTEM FOR PROVID...      NaN
# 2582  METHOD,DEVICE AND SYSTEM FOR INFORMATION INPUT...      NaN
# 2726  DETERMINING CRYPTOGRAPHIC OPERATION MASKS FOR ...      NaN
# 2752  DRILLING TOOL FOR SINKING AUTOMATICALLY DIRECT...      NaN
# 2827                        KERNEL-LEVEL SECURITY AGENT      NaN
# 2924              AUTONOMOUS LOADING VEHICLE CONTROLLER      NaN
# 2983   METHOD FOR OPERATING A HIGH-VOLTAGE PULSE SYSTEM      NaN
# 3076  SIGNAL ENHANCER AND METHOD FOR WEAK AND BLIND ...      NaN
# 3093  MULTI-PHASIC MODULARISED SHRIMP PRODUCTION SYS...      NaN
#
#      publication_date                                cpc_classifications
# 15         2021-04-21  B02C23/02;;B02C25/00;;B02C25/00;;B02C17/1805;;...
# 184        2023-05-10  F42D1/00;;F42D3/04;;F42D3/04;;G06N3/08;;G06T17...
# 271        2021-01-13  G05B13/04;;B03B13/00;;B07B13/18;;G05B17/02;;G0...
# 287        2023-06-22                      B03D1/02;;G06N20/00;;G06N5/01
# 317        2024-01-03  G01C21/3407;;G01C21/3423;;G01C21/3492;;G08G1/0...
# 577        2021-02-24  B03D1/028;;G05B19/401;;B03D1/028;;B07C5/34;;G0...
# 715        2020-10-14  G05B19/41865;;G05B2219/32252;;G05B23/0291;;G05...
# 804        2020-11-18  H04L45/00;;H04L45/76;;H04L47/783;;H04L45/00;;H...
# 947        2022-02-23  C22C1/051;;C22C29/06;;B24D3/008;;B33Y10/00;;B3...
# 1051       2023-09-27  G05D1/0248;;E21D9/006;;E21B7/022;;E21D9/003;;G...
# 1337       2023-06-28  G06Q10/06;;G06Q10/08;;G06Q10/087;;G06Q10/0875;...
# 1446       2024-06-12  H04L9/0877;;H04L9/3226;;H04L63/083;;H04L63/168...
# 1481       2022-03-09  G01C21/3841;;G08G1/0112;;G08G1/012;;G08G1/0129...
# 1822       2023-04-26  G06V10/82;;G06V40/175;;G06V10/82;;G06F18/21;;G...
# 2070       2021-09-08  G06Q40/12;;G06Q40/04;;G06Q40/04;;H04L9/3239;;H...
# 2270       2021-02-17  G08G1/166;;G01S7/411;;G01S13/726;;G01S13/878;;...
# 2379       2022-12-07  G01N21/3504;;G01N21/274;;G01N2021/3595;;G01N21...
# 2394       2022-02-09  G06F12/0646;;G06F3/0613;;G06F12/0824;;G06F12/0...
# 2530       2020-01-01               G06F11/366;;G06F11/0706;;G06F11/0781
# 2582       2020-05-20  G03G21/1878;;G03G15/0863;;G03G2215/0695;;G03G2...
# 2726       2021-08-04  G06F21/72;;G06F21/75;;H04L9/003;;H04L9/0625;;H...
# 2752       2020-03-25  E21B7/06;;E21B17/04;;E21B17/1014;;E21B47/18;;E...
# 2827       2020-01-08  G06F21/554;;G06F21/568;;G06F21/566;;H04L63/144...
# 2924       2023-07-05  E02F9/265;;E02F3/434;;E02F9/2029;;E02F9/205;;E...
# 2983       2020-07-08  B02C19/18;;B02C2019/183;;B02C19/18;;B02C2019/1...
# 3076       2022-09-21  G01N29/14;;G01N29/40;;G01N29/44;;G10K11/16;;G1...
# 3093       2023-12-06  A01K61/59;;Y02A40/81;;A01K61/80;;A01K63/04;;A0...

# %% [markdown]
# # Funciones generales

# %%
stop_words = set(stopwords.words("english"))

def preprocesar_texto(texto : str):
  palabras = texto.split()
  palabras_filtradas = [palabra.lower() for palabra in palabras if palabra.lower() not in stop_words]
  texto_filtrado = ' '.join(palabras_filtradas)

  return texto_filtrado

# %% [markdown]
# # Revisión de registros repetidos

# %%
def preprocess_text_basic(text : str):
	if not isinstance(text, float):
		return text.lower()
	return text

# %%
data_target['title'] = data['title'].apply(preprocess_text_basic)
# Out:
# <ipython-input-13-ae45e65ac9a3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_target['title'] = data['title'].apply(preprocess_text_basic)

# %%
cuenta_repetidos = data_target['title'].value_counts()
repetidos = cuenta_repetidos[cuenta_repetidos > 1].index.tolist()
print(repetidos)
print(f"Se registran {len(repetidos)} registros repetidos")
# Out:
# ['data visualization platform for event-based behavior clustering', 'systems and methods for radiant gas dynamic mining of permafrost for propellant extraction', 'system and method for adjusting leaching operations based on leach analytic data', 'mining electric locomotive power supply system', 'ore pulp ph value detection method and device and computer readable storage medium', 'system and method for determining a location of ore in a stockpile', 'leaching agent migration test system and leaching agent migration conversion test system', 'data model for mining', 'removal of amines from aqueous streams', 'underground mining methods via boreholes and multilateral blast-holes', 'embedded electromagnetic multi-vertical-ring high-gradient magnetic separator', 'mechanical automatic ore crushing device', 'evaluation and/or adaptation of industrial and/or technical process models', 'methods and systems for managing energy consumption of cryptocurrency mining', 'intelligent explosion-proof diesel engine monorail hoist', 'smart city smart drone uass/uav/vtol smart mailbox landing pad', 'secure methods and systems for environmental credit scoring', 'sparse phase unwrapping', 'flow and pressure control device', 'maintenance recommendations using lifecycle clustering', 'sample storage device for iron ore geological exploration', 'method and system for controlling hydrophobic conditions and fouling in water intensive processes', 'ore feeding process automatic control system based on 5gai technology', 'novel mineral micro powder conveying device', 'integration of carbon sequestration with selective hydrometallurgical recovery of metal values', 'post information processing method and device based on ai, equipment and storage medium', 'mining compound sliding car arrester with adjustable car arresting distance', 'gas monitoring system for hexafluorobutadiene storage place and monitoring method thereof', 'systems and methods for automated document review', 'entity alias mining method and device, computer equipment and storage medium', 'system and method for telematics for tracking equipment usage', 'fact management system', 'mining area air quality monitoring system based on internet of things', 'efficient automatic spraying and dust-settling device for exploiting and blasting gravel aggregate', 'systems and methods for renewable powerplant serving multiple loads', 'deep sea digging tooth rock breaking robot', 'system and method for processing a battery passport', 'system and method to recommend service action for predictive maintenance', 'apparatus and method for seabed resources collection', 'automatic repair of computing devices in a data center', 'method for determining source sink term in ionic type rare earth ore leaching process', 'system and method for role mining in identity management artificial intelligence systems using cluster based analysis of network identity graphs', 'intelligent financial management tool based on cloud architecture', 'automatic aging calibration system, intelligent aging cabinet and intelligent aging vehicle', 'system, method, and apparatus for a neural network model for a vehicle', 'intelligent sorting system based on x-ray imaging', 'negative electrodes for electrochemical cells', 'data processing method, device and equipment and computer storage medium', 'mineral recovery control', 'artificial intelligence techniques for improving efficiency', 'system and method for online/offline payment with virtual currency for nodes included in mobile-based blockchain distributed network', 'experimental device for evaluating influence of uranium ore in-situ leaching chemical clogging on permeability', 'natural language understanding model with context resolver', 'data acquisition and control system of magnetic separator', 'mine equipment operation state data visualization system', 'mining pure water preparation device', 'air conditioning system of large mining dump truck', 'full-automatic ore sample preparation and moist ...
# Se registran 72 registros repetidos

# %%
data_target[data_target['title'] == 'data visualization platform for event-based behavior clustering']
# Out:
#                                                   title  \
# 1838  data visualization platform for event-based be...
# 1917  data visualization platform for event-based be...
# 2153  data visualization platform for event-based be...
#
#                                                abstract publication_date  \
# 1838  A platform for processing event traces to gene...       2021-01-07
# 1917  A platform for processing event traces to gene...       2023-08-15
# 2153  A platform for processing event traces to gene...       2022-10-12
#
#                                     cpc_classifications
# 1838  G06F16/358;;G06F16/26;;G06F16/2465;;G06F16/287...
# 1917  G06F16/358;;G06F16/26;;G06F16/2465;;G06F16/287...
# 2153  G16H50/70;;G06N20/00;;G16H40/20;;G06N3/126;;G0...

# %%
data_target[data_target['title'] == 'systems and methods for radiant gas dynamic mining of permafrost for propellant extraction']
# Out:
#                                                   title  \
# 1796  systems and methods for radiant gas dynamic mi...
# 1818  systems and methods for radiant gas dynamic mi...
# 2123  systems and methods for radiant gas dynamic mi...
#
#                                                abstract publication_date  \
# 1796  Systems and methods are disclosed for mining l...       2023-08-15
# 1818  Systems and methods are disclosed for mining l...       2022-03-17
# 2123  Systems and methods are disclosed for mining l...       2020-02-13
#
#                                     cpc_classifications
# 1796  E21B7/15;;E21B36/04;;E21C37/16;;E21C51/00;;E21...
# 1818  E21B7/15;;E21B36/04;;E21C37/16;;E21C51/00;;E21...
# 2123  E21B7/15;;E21B36/04;;E21C37/16;;E21C51/00;;E21...

# %% [markdown]
# ---
#
#
# **Observación**
#
#
# ---
# Se aprecian registros repetidos, son las mismas patentes en distintos años de publicación

# %% [markdown]
# # Define términos excluyentes

# %%
excluyentes = ['data mining', 'blockchain mining', 'mining transaction', 'transaction',
               'transactional','pattern mining', 'information mining', 'word mining']

# %% [markdown]
# # Similitud usando 'jaccard_similarity'

# %%
def jaccard_similarity(str1 : str, str2 :str):
    """
    Calcula la similitud de Jaccard entre dos frases.

    Args:
        str1 (str): La primera frase.
        str2 (str): La segunda frase.

    Returns:
        float: La similitud de Jaccard entre las dos frases.
    """
    # Convertir las frases a minúsculas y tokenizar en palabras
    set1 = set(str1.lower().split())
    set2 = set(str2.lower().split())

    # Calcular la intersección y la unión de los conjuntos de palabras
    intersection = set1.intersection(set2)
    union = set1.union(set2)

    # Calcular la similitud de Jaccard
    similarity = len(intersection) / len(union)
    return similarity

def jaccard_similarity_tfidf(str1, str2):
    """
    Calcula la similitud de Jaccard entre dos frases usando TfidfVectorizer.

    Args:
        str1 (str): La primera frase.
        str2 (str): La segunda frase.

    Returns:
        float: La similitud de Jaccard entre las dos frases.
    """
    # Crear el vectorizador TF-IDF
    vectorizer = TfidfVectorizer()

    # Transformar las frases en matrices TF-IDF
    tfidf_matrix = vectorizer.fit_transform([str1, str2])

    # Convertir las matrices TF-IDF en vectores binarios (presencia/ausencia de palabras)
    binary_matrix = (tfidf_matrix > 0).astype(int)

    # Extraer los vectores binarios
    vector1 = binary_matrix.toarray()[0]
    vector2 = binary_matrix.toarray()[1]

    # Calcular la similitud de Jaccard
    similarity = jaccard_score(vector1, vector2)
    return similarity

# %% [markdown]
# ## Experimento considerando las stopwords

# %%
lst_similitudes = []
for frase in data_target['title']:
  for termino in excluyentes:
    sim1 = jaccard_similarity(frase, termino)
    sim2 = jaccard_similarity_tfidf(frase, termino)
    lst_similitudes.append((frase, termino, sim1, sim2))

data_similitudes = pd.DataFrame(lst_similitudes, columns = ['frase', 'termino', 'jaccard_simple', 'jaccard_tifdVectorizer'])

# %%
data_similitudes[data_similitudes['jaccard_tifdVectorizer'] > 0]
# Out:
#                                                    frase             termino  \
# 8      process for integrating the mining and process...         data mining
# 9      process for integrating the mining and process...   blockchain mining
# 10     process for integrating the mining and process...  mining transaction
# 13     process for integrating the mining and process...      pattern mining
# 14     process for integrating the mining and process...  information mining
# ...                                                  ...                 ...
# 25458                       mining gas monitoring sensor  mining transaction
# 25461                       mining gas monitoring sensor      pattern mining
# 25462                       mining gas monitoring sensor  information mining
# 25463                       mining gas monitoring sensor         word mining
# 25512  method for providing clock frequencies for com...         data mining
#
#        jaccard_simple  jaccard_tifdVectorizer
# 8            0.066667                0.068966
# 9            0.032258                0.033333
# 10           0.032258                0.033333
# 13           0.032258                0.033333
# 14           0.032258                0.033333
# ...               ...                     ...
# 25458        0.200000                0.200000
# 25461        0.200000                0.200000
# 25462        0.200000                0.200000
# 25463        0.200000                0.200000
# 25512        0.076923                0.076923
#
# [5042 rows x 4 columns]

# %%
data_similitudes[data_similitudes['jaccard_tifdVectorizer'] > 0.3].groupby("termino").size()
# Out:
# termino
# blockchain mining     3
# data mining           6
# information mining    2
# mining transaction    2
# pattern mining        3
# word mining           2
# dtype: int64

# %%
data_similitudes[data_similitudes['jaccard_tifdVectorizer'] >= 0.2].groupby("termino").size()
# Out:
# termino
# blockchain mining     40
# data mining           59
# information mining    41
# mining transaction    39
# pattern mining        39
# word mining           39
# dtype: int64

# %%
data_similitudes[data_similitudes['jaccard_tifdVectorizer'] >= 0.1].groupby("termino").size()
# Out:
# termino
# blockchain mining     323
# data mining           518
# information mining    342
# mining transaction    315
# pattern mining        315
# word mining           316
# dtype: int64

# %%
data_similitudes[(data_similitudes['jaccard_tifdVectorizer'] > 0.3) & (data_similitudes['termino'] == 'blockchain mining')]
# Out:
#                                          frase            termino  \
# 22761  mining robot system based on blockchain  blockchain mining
# 23073                             mining robot  blockchain mining
# 24153                            mining sensor  blockchain mining
#
#        jaccard_simple  jaccard_tifdVectorizer
# 22761        0.333333                0.333333
# 23073        0.333333                0.333333
# 24153        0.333333                0.333333

# %% [markdown]
# ## Experimento DESCARTANDO las stopwords

# %%
data_target['title'] = data_target['title'].apply(preprocesar_texto)
# Out:
# <ipython-input-25-545dede3c648>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_target['title'] = data_target['title'].apply(preprocesar_texto)

# %%
lst_similitudes = []
for frase in data_target['title']:
  for termino in excluyentes:
    sim1 = jaccard_similarity(frase, termino)
    sim2 = jaccard_similarity_tfidf(frase, termino)
    lst_similitudes.append((frase, termino, sim1, sim2))
    """
    print(f" Similitud entre '{termino}' y '{frase}'")
    print("\t{0:<45} : {1:.2f}".format("Similitud de Jaccard simple", sim1))
    print("\t{0:<45} : {1:.2f}".format("Similitud de Jaccard usando TifdVectorizer", sim2))
    """
data_similitudes_sin_stopwords = pd.DataFrame(lst_similitudes, columns = ['frase', 'termino', 'jaccard_simple', 'jaccard_tifdVectorizer'])

# %%
data_similitudes_sin_stopwords[data_similitudes_sin_stopwords['jaccard_tifdVectorizer'] > 0]
# Out:
#                                                    frase             termino  \
# 8      process integrating mining processing together...         data mining
# 9      process integrating mining processing together...   blockchain mining
# 10     process integrating mining processing together...  mining transaction
# 13     process integrating mining processing together...      pattern mining
# 14     process integrating mining processing together...  information mining
# ...                                                  ...                 ...
# 25458                       mining gas monitoring sensor  mining transaction
# 25461                       mining gas monitoring sensor      pattern mining
# 25462                       mining gas monitoring sensor  information mining
# 25463                       mining gas monitoring sensor         word mining
# 25512  method providing clock frequencies computing c...         data mining
#
#        jaccard_simple  jaccard_tifdVectorizer
# 8            0.083333                0.083333
# 9            0.040000                0.040000
# 10           0.040000                0.040000
# 13           0.040000                0.040000
# 14           0.040000                0.040000
# ...               ...                     ...
# 25458        0.200000                0.200000
# 25461        0.200000                0.200000
# 25462        0.200000                0.200000
# 25463        0.200000                0.200000
# 25512        0.090909                0.090909
#
# [5042 rows x 4 columns]

# %%
data_similitudes_sin_stopwords[data_similitudes_sin_stopwords['jaccard_tifdVectorizer'] >= 0.2].groupby("termino").size()
# Out:
# termino
# blockchain mining     57
# data mining           99
# information mining    62
# mining transaction    54
# pattern mining        54
# word mining           54
# dtype: int64

# %%
data_similitudes_sin_stopwords[(data_similitudes_sin_stopwords['jaccard_tifdVectorizer'] > 0.3) & (data_similitudes_sin_stopwords['termino'] == 'blockchain mining')]
# Out:
#                                       frase            termino  \
# 22761  mining robot system based blockchain  blockchain mining
# 23073                          mining robot  blockchain mining
# 24153                         mining sensor  blockchain mining
#
#        jaccard_simple  jaccard_tifdVectorizer
# 22761        0.400000                0.400000
# 23073        0.333333                0.333333
# 24153        0.333333                0.333333

# %%
data_similitudes[(data_similitudes['jaccard_tifdVectorizer'] > 0.3) & (data_similitudes['termino'] == 'blockchain mining')]
# Out:
#                                          frase            termino  \
# 22761  mining robot system based on blockchain  blockchain mining
# 23073                             mining robot  blockchain mining
# 24153                            mining sensor  blockchain mining
#
#        jaccard_simple  jaccard_tifdVectorizer
# 22761        0.333333                0.333333
# 23073        0.333333                0.333333
# 24153        0.333333                0.333333

# %% [markdown]
# # Técnicas de similitud

# %%
def convierte_a_minusculas(text : str):
	if not isinstance(text, float):
		return text.lower()
	return text

# %%
def obtiene_descartados(filtrados, data_target : pd.DataFrame, feature = "title"):
  total_gral = Counter(data_target[feature])
  total_filtrados = Counter(filtrados)
  diferencia = total_gral - total_filtrados
  return list(diferencia.elements())

# %% [markdown]
# ## Filtro usando coincidencia de subcadenas

# %%
def contains_substring(abstract, terms):
    for term in terms:
        if term in abstract:
            return True
    return False

# %% [markdown]
# ### Experimento incluyendo las stopwords

# %%
data_target = data[['title', 'abstract', 'publication_date']]
data_target['title'] = data['title'].apply(preprocess_text_basic)
# Out:
# <ipython-input-22-8f112739cedf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_target['title'] = data['title'].apply(preprocess_text_basic)

# %%
# Obtiene el núnero de filtrados
len([title for title in data_target['title'] if not contains_substring(title, excluyentes)]
)
# Out:
# 3187

# %%
filtrados_usando_subcadenas = [title for title in data_target['title'] if not contains_substring(title, excluyentes)]
filtrados_usando_subcadenas
# Out:
# ['method for operating a comminution circuit and respective comminution circuit',
#  'process for integrating the mining and processing together with data collection in real time. dry pre-concentration via sensor based ore sorting (sbs), combined with dry comminution, in combination with a wet final concentration flowsheet',
#  'system and method for continuous optimization of mineral processing operations',
#  'method for water and moisture management for a mining operation',
#  'method for training a quality prediction model for a processing device of a continuous industrial process, method for controlling of a continuous industrial process comprising a processing device, and a processing device',
#  'computer-implemented methods referring to an industrial process for manufacturing a product and system for performing said methods',
#  'method for optimizing mineral recovery process',
#  'industrial robotic platforms',
#  'monitoring ore',
#  'real-time monitoring and estimation system for wear in rubber liners and lifter bars utilized in ore grinding mills',
#  'mineral recovery control',
#  'low cost, size, weight, and power (cswap) geolocation capability utilizing signal characteristics passed through to backhaul network',
#  'system for carrying out cross-protocol communication between iot (internet of things) devices',
#  'big data quality inspection method for customer service voice text based on machine learning',
#  'user generated tag collection system and method',
#  'a method and an arrangement for controlling of a comminution process having a grinding circuit',
#  'optimal energy storage utilization',
#  'method and device for positioning internet of things devices',
#  'model updating method and device for automatically mining scene data and storage medium',
#  'method and system for resilient hydrogen production',
#  'modular system and method for beneficiating a ferrous ore',
#  'ai-based platform for automated labor law compliance associated with mining operations',
#  'smart city disorderly-stacked material management system and method',
#  'predictive data analysis of stocks',
#  'virtual simulation practical training system for detection and control of ore grinding grading system of dressing plant',
#  'pump machine unit optimized operation regulation system and method based on digital twin',
#  'systems, methods, and devices for generation of peer validated geospatial data and proof of reception of tracking data',
#  'computer security based on artificial intelligence',
#  'underground mine energy management system',
#  'ore component analysis device and method',
#  'system and method for adjusting leaching operations based on leach analytic data',
#  'service platform and method based on algorithm enabling and data value mining, and storage medium',
#  'automated updating of geological model boundaries for improved ore extraction',
#  'mining transportation scheduling management system based on artificial intelligence',
#  'method and a control node for controlling a mining rig',
#  'artificial intelligence techniques for improving efficiency',
#  'experimental device and experimental method for natural gas hydrate solid-state fluidized mining and crushing',
#  'artificial intelligence techniques for improving efficiency',
#  'spectral imaging for material characterization and control of systems and methods for processing earthen materials',
#  'systems and methods for deriving leading indicators of economic activity using predictive analytics',
#  'digital twin systems and methods for transportation systems',
#  'digital twin systems and methods for transportation systems',
#  'deriving leading indicators of economic activity using predictive analytics applied to agricultural, mining, construction, and environmental attributes to predict ecological trends and economic outcomes',
#  'mineral recovery control',
#  'method and system for extracting gold without chemicals',
#  'storage method for land big data distributed mining analysis',
#  'method for constructing spatial semantic database based on bim and gis data integration',
#  'mining equipment inspection system, mining equipment inspection method, and mining equipment inspection device',
#  'fluidized-bed flotation unit, mineral processing apparatus, and fluidized-bed flotation method',
#  'vulnerability mining method and device based on internet of things firmware, equipment and storage medium',
#  'multi-scene applicable smart energy management system based on edge calculation',
#  'system and method for changing liners, the configuration of which allows the automated removal and insertion of liners of a mill used for ore grinding',
#  'everything interconnection training platform and control method and device',
#  'coarse particle flotation equipment and method based on coupled fluidization of cyclone and damping',
#  'method for improved drilling and blasting in open cut mines',
#  'method for predicting ore crushing effect based on ore fracture energy and discrete element method',
#  'industrial control vulnerability mining method, system and equipment based on deep learning and storage medium',
#  'beneficiation method for ore blending',
#  'system, apparatus, and method for making a prediction regarding a passage system',
#  'molybdenum selection process production technology and method based on industry big data',
#  'deep ore body information stratum bionic self-navigation perspective exploration system based on digital twinning',
#  'method and system for constructing digital mine three-dimensional twinborn model',
#  'decentralized platform for deploying ai models',
#  'mining machine adapted for extracting material from a deposit, and method for control thereof',
#  'safety interlock recommendation system',
#  'data analysis query method and system for mining area unmanned transportation system',
#  'smart city smart drone uass/uav/vtol smart mailbox landing pad',
#  'smart city smart drone uass/uav/vtol smart mailbox landing pad',
#  'calculation method for inspecting particle size distribution data consistency correction in ore crushing or grinding process',
#  'methods and systems for managing energy consumption of cryptocurrency mining',
#  'augmented photo capture',
#  'methods and systems for managing energy consumption of cryptocurrency mining',
#  'system and method for securing sensor data in internet of things (iot) network',
#  'process data sequence correlation analysis method and process optimization method in ore grinding production process',
#  'system and method for promoting safe interaction with electrical equipment',
#  'handsfree information system and method',
#  'device and method for solid-state fluidization mining of seabed shallow layer non-diagenetic natural gas hydrates',
#  'ai-based client mining method, device and equipment and storage medium',
#  'three-dimensional virtual simulation automatic design method for ore crushing and grinding processes',
#  'internet big data processing system and method based on artificial intelligence',
#  'system and method for adjusting leaching operations based on leach analytic data',
#  'method for full resource utilization of graphite ores',
#  'method for predicting granularity of ore grinding product based on ore grinding dynamics principle',
#  'adaptive discovery and mixed-variable optimization of next generation synthesizable microelectronic materials',
#  'offloaded sensor authentication for internet of things',
#  'finite element-based ore deposit drilling information processing and analysis method and device',
#  'optimization system and an optimization method',
#  'system and method for determining estimated remaining mineral in a stockpile',
#  'systems and methods for assessing extractability of prospective helium-natural gas sources',
#  'spacecraft assembly process management and control method and system based on digital twinning',
#  'method and apparatus for identifying malicious mining behavior, and device and storage medium',
#  'beneficiation process for efficiently recovering iron and rare earth from bayan obo medium-lean oxidized heaped ore',
#  'wireless data storage method and device for mining frequency converter',
#  'method for utilizing graphite ore resources',
#  'copper ore data analysis method and system based on artificial intelligence',
#  'simulation system for ore grinding classification process',
#  'deep well operation safety data analysis system and method based on artificial intelligence',
#  'intelligent agricultural management system based on data processing',
#  'power big data treatment method and device, electronic equipment and storage medium',
#  'big data analysis system based on network service',
#  'computerized method and system for validating a computing infrastructure by mining',
#  'maximise the value of a sulphide ore resource through sequential waste rejection',
#  'big data analysis method and system based on cloud computing',
#  'team-based tele-diagnostics blockchain-enabled system',
#  'urban health index prediction system, prediction analysis method and storage medium thereof',
#  'determining ore characteristics',
#  'method and system for mining synonyms of radio station names based on big data, electronic equipment and storage medium',
#  'rare earth mine mining monitoring method and device based on remote sensing data and storage medium',
#  'methods and systems for the batch delivery of material to a continuous material processor',
#  'method and system for automated public information discovery',
#  'ore grinding-weak and strong magnetic separation-reverse flotation process method for refractory iron ore tailings',
#  'method for improving strip mine unmanned mine truck dynamic path planning',
#  'modeling method and device for gold ore feeding process, storage medium and computer equipment',
#  'semi-autogenous mill operation state optimization method based on digital twinning',
#  'method and system for space design',
#  'document digitization, transformation and validation',
#  'process execution management and compliance check method and system based on process mining',
#  'method and system for monitoring and predicting performance of gyratory crusher based on digital twinning',
#  'provisioning edge devices in a mobile carrier network as compute nodes in a blockchain network',
#  'system and method for detecting friction in websites',
#  'method and system for predicting metallurgical performance of sintered ore, electronic equipment and storage medium',
#  'mining data storage system',
#  'e-commerce high-quality resource mining method and device, electronic equipment and storage medium',
#  'management method of mining equipment based on internet of things and readable storage medium',
#  'grinding media, system and method for optimising comminution circuit',
#  'data relationship mining method and device, computer equipment and readable storage medium',
#  'intelligent detector data storage method based on deep learning and related equipment',
#  'method and system for learning novel relationships among various biological entities',
#  'electromechanical device patrol data management system and method thereof',
#  'bad example mining method and device and storage medium',
#  'method for monitoring a continuous industrial process and system for performing said method',
#  'ball mill ore discharge granularity control method and system based on digital twinning technology',
#  'insurance value determination method and device, equipment and storage medium',
#  'a method for mining and processing of an ore',
#  'mining method and device based on blockchain, and computer readable storage medium',
#  'system and method for determining locations for recoverable mineral in a stockpile',
#  'hybrid reasoning based on physics and machine learning for prognostics of systems with conflated degradation modes',
#  'strip mine digital twin remote operation and maintenance method and device and storage medium',
#  'mining area road exploration and transportation road maintenance equipment based on multi-source data',
#  'predictive customer service environment',
#  'entity relation mining method based on biomedical literature',
#  'crushing and flotation all-in-one machine',
#  'apparatus, system and method for comminution',
#  'system and method for adjusting leaching operations based on leach analytic data',
#  'measurement system and measurement method',
#  'healthcare information technology system for predicting or preventing readmissions',
#  'methods and systems for industrial internet of things data collection in a network sensitive mining environment',
#  'method and system for optimizing call distribution among callers for improved positive outcome',
#  'flotation ph value prediction method and device, electronic equipment and storage medium',
#  'systems and methods for automated document review',
#  'intelligent analysis system for domestic trade big data',
#  'systems and methods for automated document review',
#  'big data processing method based on cloud computing',
#  'predicting energy production for energy generating assets',
#  'mining and tailing comprehensive utilization equipment set and automatic control system',
#  'locked-on target based object tracking method and portable terminal therefor',
#  'mining area unmanned transportation system and control method thereof',
#  'data traceability method and system based on cloud edge collaboration',
#  'method and device for grinding and screening barite ore',
#  'a cyber-physical hybrid electric autonomous or semi-autonomous off-highway dump truck for surface mining industry',
#  'self-building hierarchically indexed multimedia database',
#  'ai big data analysis method for assisting optimization of bank outlet layout, electronic equipment, storage medium and platform',
#  'vehicle, electric shovel and cloud fusion-based parking method for unmanned transportation in mining area',
#  'iron-zinc ore grinding and grading automation system',
#  'digital life and/or health claims processing system integrating multiple claim channels, and method thereof',
#  'mining production investigation sampling device based on internet of things',
#  'synonym mining method, application method of synonym dictionary, medical synonym mining method, application method of medical synonym dictionary, synonym mining device and storage medium',
#  'copper ore flotation intelligent soft measurement method and system based on wireless sensor network',
#  'mining dump truck data storage system based on off-line acquisition and mining dump truck',
#  'dense three-dimensional correspondence estimation with multi-level metric learning and hierarchical matching',
#  'method for predicting relative size of wear rate of lining plate under different ore grinding parameters based on discrete element method',
#  'ore grading process',
#  'method and device for mining new road based on driving track and electronic equipment',
#  'talent evaluation method and system based on data deep mining and storage medium',
#  'ground surface settlement monitoring method and device, electronic equipment and storage medium',
#  'ground rail of ore transportation rail robot',
#  'cross-platform data analysis method, system and device and readable storage medium',
#  'mining method and device for graph data, electronic equipment and readable storage medium',
#  'method and system for analyzing computer network situation based on big data and neural network',
#  'blockage cleaning robot for secondary crushing of lump ores in mine draw shaft',
#  'crushing production line based on internet of things control',
#  'internet of things data atlas generation method and device, computer equipment and storage medium',
#  'method for development of complex-structure solid mineral deposits',
#  'blasting system and method',
#  'mining inclined roadway elevator comprehensive control integrated system based on internet of things',
#  'association-rule based data outlier detection and record completion system and method',
#  'data model for mining',
#  'system and method for intelligent recruitment management',
#  'data model for mining',
#  'human-machine dialogue system and method',
#  'ore granularity detection method and system based on autonomous learning and deep learning',
#  'smart city security monitoring system',
#  'prediction data analysis system and method based on construction engineering cost',
#  'ore grinding and blending method based on hard rock grade',
#  'task data relationship mining method and device, electronic equipment and storage medium',
#  'conversion rate prediction method, device and equipment and storage medium',
#  'computing environment provisioning',
#  'data statistical mining and fusion display method, system and device and storage medium',
#  'gigabit potential customer prediction method and device, computer equipment and storage medium',
#  'cloud service capability rating method and device based on graph mining, equipment and storage medium',
#  'flotation recovery rate prediction method based on ore gene characteristics',
#  'system and method for determining lift heights of a stockpile',
#  'processing of laterite ores',
#  'transferable hybrid prognostics based on fundamental degradation modes',
#  'portable modular gastrointestinal simulator system that quantifies bioaccessibility of metals in a sample remotely and in real time, and method',
#  'tailing pond risk monitoring and early warning system based on internet of things',
#  'tailing pond risk monitoring and early-warning system based on internet of things',
#  'well mining real-time data processing method and device, storage medium and electronic equipment',
#  'mineral processing production quality monitoring system and method based on multiple data sources',
#  '5g-based mining area unmanned transportation system and cooperative control method of mine forklift of 5g-based mining area unmanned transportation system',
#  'method and device for mining domain vocabularies based on correlation analysis algorithm and storage medium',
#  'pre-selection process for lead-zinc raw ore',
#  'ore stock bin of deep-sea mining vehicle and metering method',
#  'container type mining energy storage system integration box',
#  'binary system gold ore gold-bearing mineral gold content determination method',
#  'risk account identification method and device, computer equipment and storage medium',
#  'method for sorting low-grade complex copper-sulfur ore and application',
#  'internet of things equipment encryption key acquisition method and device, equipment and storage medium',
#  'data optimization storage method based on artificial intelligence and big data system',
#  'dynamic implicit relationship mining method and system based on graph deep learning',
#  'bus operation optimization simulation method based on big data',
#  'clinical test method, system and equipment based on digital twinning and storage medium',
#  'non-ferrous metal mineral flotation chemical pretreatment method',
#  'service achievement data processing method',
#  'flotation reagent adsorption behavior and mineral floatability prediction method and system and storage device',
#  'establishment method and device of label mining model, storage medium and terminal',
#  'load-based management for nvme over tcp connections',
#  'improvements to operational state determination and modification',
#  'service rule mining method and device for order data, equipment and storage medium',
#  'sandstone particle size distribution curve detection method based on deep learning',
#  'flotation field parameter detection device',
#  'method and system for streamlined auditing',
#  'measuring tank fluids and remote monitoring system',
#  'human-machine collaborative conversation interaction system and method',
#  'method and device for predicting proportion of fine-particle-size ores and readable storage medium',
#  'living body detection model training method and device, electronic equipment and storage medium',
#  'reducing the need for tailings storage dams in mineral flotation',
#  'rpa and ai combined rpa process generation method, corresponding equipment and readable storage medium',
#  'system and method for grinding and classifying aggregate material',
#  'mine field mining quantity metering method and system',
#  'automatic positioning mechanism and ore unloading device of mining automatic dumping car',
#  'intelligent ore positioning and crushing control method and device',
#  'telephone traffic request quantity prediction method and device, electronic equipment and storage medium',
#  'automatic creation of data models based on semantic understanding',
#  'mining vehicle operation optimization method based on digital twinning technology in intelligent mine',
#  'excitation compatibility consensus method, device and equipment for decentered ore pool and storage medium',
#  'smart red tourism system based on big data',
#  'comprehensive optimization method for mining and discharging space and freight distance of strip mine',
#  'solar modules with integrated flexible hybrid electronics',
#  'raise caving method for mining deposits, and a mining infrastructure, monitoring system, machinery, control system and data medium therefor',
#  'device and method for measuring softening and melting performances of iron ore in blast furnace under reducing condition',
#  'open source threat intelligence aggregation platform',
#  'social security early warning system, method and equipment based on big data and storage medium',
#  'test system and method for simulating invasion of mining transportation equipment in multiple directions',
#  'energy storage battery internal resistance online calculation method based on cloud platform',
#  'concentrate grade optimization engine in a material processing system',
#  '5g-based mining area unmanned transportation system and unloading cooperative control method thereof',
#  'explainers for machine learning classifiers',
#  'data access method, apparatus and system based on mining computer, and readable storage medium',
#  'robot data collection iterative training method and system based on active learning technology, and storage medium',
#  'automatic lithotripsy method and equipment based on three-dimensional laser radar and camera and medium',
#  'cancer prognosis marker mining method and device, server and storage medium',
#  'mine internet of things data management system based on block chain',
#  'power optimization through orchestration and prioritization of machines and functions',
#  'mining area image recognition method and device, server and storage medium',
#  'crusher ore feeding control method and device, electronic equipment and storage medium',
#  'calculation method based on artificial intelligence data processing',
#  'automatic filling mining system',
#  'device and method for enhancing biological leaching by treating straw with acid',
#  'mining temperature prediction device of sinter cooler facility',
#  'ore dressing multi-production-index optimization decision making system and method based on cloud and mobile terminal',
#  'method of, and a system for, drilling to a position relative to a geological boundary',
#  'system and method for insight automation from social data',
#  'ore grindability obtaining method and device and prediction model',
#  'lightweight multi-path mesh image segmentation method and system, and electronic equipment',
#  'integrated energy storage management system and energy management method',
#  'data storage module-based curing barn temperature and humidity remote monitoring system',
#  'vulnerability mining method based on equipment firmware simulation under novel power system and storage medium',
#  'silver mineral quantification method for oxidized silver-containing ore',
#  'automatic control practical training device for reagent addition of multi-process flotation column separation system',
#  'phosphorite flotation tailing treatment system',
#  'intelligent access control system based on internet of things',
#  'machine learning based on radiology report',
#  'removal of amines from aqueous streams',
#  'multi-process flotation column separation system reagent adding automatic control practical training device',
#  'inspection task issuing method and device, inspection path planning method and device and storage medium',
#  'mineral flotation separation',
#  'full-closed-loop supervision and early warning method and system for mine sandstone industry',
#  'selection of diverse candidate peptides for peptide therapeutics',
#  'ore crushing method based on binocular stereoscopic visual perception',
#  'intelligent mediation optimization follow-up system and method',
#  'screening device for primary processing of manganese ore',
#  'deep-sea mining mixed transportation lifting test system for simulating influence of seawater movement',
#  'method and apparatus for magnetic resonance imaging and plaque recognition',
#  'photo album video recognition method, system and device and storage medium',
#  'method for determining grinding granularity of ore based on ore properties',
#  'automated object detection in a dusty environment',
#  'smart city management method and system based on big data, and storage medium',
#  'method for sampling closed tailing pond of valley type metal mine and determining re-selection scheme',
#  'big data platform system for railway port station',
#  'ai-based operation and maintenance fault determination method and device, equipment and storage medium',
#  'transporting mined material',
#  'cableway safe operation control system, structure and method',
#  'image-text data relation mining method, device and equipment and readable storage medium',
#  'method for echelon recycling and large-scale absorption of copper mine tailings',
#  'association rule mining method and system oriented to mes system data and storage medium',
#  'method for predicting semi-autogenous grinding hard rock crushing effect and determining steel ball grading based on tavaries crushing model',
#  'data blood relationship mining method and device, storage medium and electronic equipment',
#  'smart application system',
#  'mining area air quality monitoring system based on internet of things',
#  'prompting method, device and equipment and readable storage medium',
#  'intelligent sintering ore blending system based on pre-ironmaking big data',
#  'a method for estimating disturbances and giving recommendations for improving process performance',
#  'production control platform for determining production source output to a production destination',
#  'intelligent table ore zone segmentation method based on yolov5 improvement',
#  'method and device for determining mining and dressing plan and readable storage medium',
#  'system, method and apparatus for planning driving path of vehicle',
#  'mining of distributed scientific data for enriched valuation',
#  'mining method and device of operation and maintenance knowledge, equipment, storage medium and program product',
#  'scalable, data-driven digital marketplace providing a standardized secured data system for interlinking sensitive risk-related data, and method thereof',
#  'intelligent freight management system and method based on big data platform',
#  'electric power data sharing system, method and equipment based on artificial intelligence and block chain, and medium',
#  'mining area air quality monitoring system based on internet of things',
#  'health detection and management method based on medical big data',
#  'full-automatic lump ore sample preparation system and full-automatic lump ore sample preparation method',
#  'providing a virtual control',
#  'data display device for collecting tail gas of mining vehicle',
#  'damage monitoring and online maintenance system for metal material structure',
#  'intelligent decision-making method for sintering production process',
#  'request identification method and apparatus, device, and storage medium',
#  'method and system for analyzing geo-spatial data regarding spatial object representations',
#  'method and system for predicting a risk for rollover of a working machine',
#  'health medical big data sharing system and method',
#  'removal of amines from aqueous streams',
#  'method and apparatus for generating simulation digital certificate, mining pool diagnosis, medium, and product',
#  'multidimensional privacy control',
#  'systems and methods for a milling system',
#  'multi-process flotation liquid level automatic control practical training device',
#  'big data analysis system and method',
#  'metallic ore mining, grinding and separating method',
#  'mining behavior detection method based on electric power data and storage medium',
#  'fault collection, storage and prediction system and method for mining dump truck',
#  'smart park energy comprehensive management and control platform based on data analysis',
#  'digital intelligent mine system',
#  'tailing crushing device for production of self-heat-preservation foam light building blocks',
#  'selective processing',
#  'experimental device for simulating weathering oxidation of tailings and barren rocks in intermittent rivers in mining area',
#  'automatic ore crushing and humidifying equipment',
#  'image processing method and system',
#  'disease data scheduling management method and bone cancer risk prediction system',
#  'mining and metallurgy beneficiation device and using method thereof',
#  'generation method and device of promotion information, storage medium and electronic equipment',
#  'disease data reporting method and device based on mining clustering algorithm, and storage medium',
#  'artificial intelligence distributed storage system',
#  'ore classification and size grading method and device based on deep learning network',
#  'detecting relationships across data columns',
#  'interactive validation of annotated documents',
#  'magnetic microfluidic concentrator, intelligent magnetic microfluidic concentrator, and complete set of beneficiation equipment using the same',
#  'full-intelligent sintering fuel granularity control method',
#  'workshop-level digital twin system based on data driving',
#  'ceramic 3d printing material based on iron tailings and preparation method',
#  'multi-scale data acquiring and processing device and method for aluminum oxide production process',
#  'flotation kinetic parameter measurement method, device and system and storage medium',
#  'drug group mining method and device of target disease, electronic equipment and storage medium',
#  'synthesis of zeolite nanosheets from mining waste',
#  'leaching agent migration test system and leaching agent migration conversion test system',
#  'scientific and technological achievement data text mining method, electronic equipment and storage medium',
#  'mining message processing method and device, electronic equipment and storage medium',
#  'avoiding prohibited sequences of materials processing at a crusher using predictive analytics',
#  'retrieval system and method in database based on cloud computing management platform',
#  'full-automatic fine ore sample preparation system and full-automatic fine ore sample preparation method',
#  'optics and structure for space applications',
#  'sensor and actuator based lifecycle monitoring of machines performing automated machine tasks',
#  'ore removal temperature prediction device of sintering cooling device',
#  'sludge processing assembly and method for drying aqueous waste streams',
#  'highway-railway combined transportation volume prediction method, device and equipment and readable storage medium',
#  'intelligent operation and maintenance data storage platform',
#  'online visual ore pulp detector for flotation dosing control',
#  'system for recovering micro-fine particle fluorite in multi-metal tailings by adopting flotation column-flotation machine',
#  'real-time mine car scheduling system and method based on mine transportation demand prediction',
#  'wild animal monitoring system based on edge cloud intelligent architecture',
#  'user preference mining method and device, electronic equipment and medium',
#  'mechanical automatic ore crushing device',
#  'mining area transportation frequency detection method and device, computer equipment and storage medium',
#  'mill ore feeding amount prediction method based on image recognition technology',
#  'copper-molybdenum ore froth flotation segmentation method and system',
#  'ore metallic mineral content prediction method based on high-voltage electric pulse crushing',
#  'big data risk identification method for smart medical service and storage medium',
#  'cement production intelligent analysis management platform based on internet of things',
#  'calculation method and system based on three-dimensional model and storage medium',
#  'automated mining area system and method for performing mining area operation by using automated mining area system',
#  'solar power distribution and management for cryptocurrency mining',
#  'process mining method based on full-link monitoring data, storage medium and equipment',
#  'method for optimizing mineral recovery process',
#  'high-capacity-ratio photovoltaic short-term power prediction method, device and equipment and storage medium',
#  'method and system for training a virtual agent using optimal utterances',
#  'intelligent medical analysis processing method based on big data',
#  'repurchase business opportunity mining method, electronic equipment and storage medium',
#  'automation and optimization of data recovery after a ransomware attack',
#  'method and system for controlling hydrophobic conditions and fouling in water intensive processes',
#  'method and system for performing localization of an object in a 3d',
#  'mineral resource intelligent mining lean management system and method',
#  'big data platform computing system',
#  'security vulnerability test method and device, equipment and readable storage medium',
#  'method for discriminating ore prospecting types based on compositional change of epidote',
#  'flotation process problem diagnosis method based on mla',
#  'mining area mining subsidence prediction method and device, electronic equipment and storage medium',
#  'mining multifunctional crawler-type auxiliary transportation robot',
#  'feo content prediction method, model training method and device, electronic equipment and medium',
#  'distributed photovoltaic active multi-system data fusion method',
#  'method and system for performing intelligent sorting based on dynamic adjustment of threshold',
#  'system for automatic loading / unloading and related devices',
#  'high-precision map making method for mine unmanned driving scene',
#  'copper smelting slag flotation control method',
#  'tantalum-niobium ore ball mill',
#  'online flotation working condition detection device',
#  'electrcally-driven mining vehicle and brake operation guiding method in electrically-driven mining vehicle',
#  'configurable action generation for a remote network management platform',
#  'big data analysis management system based on cultural tourism',
#  'flotation reagent automatic adding control system based on data analysis',
#  'data flow arrangement method and system applied to oil and gas production system',
#  'method and system for controlling hydrophobic conditions and fouling in water intensive processes',
#  'multi-type ore storage yard reserve dynamic analysis method and system, equipment and medium',
#  'blacklist mining method and device and computer readable storage medium',
#  'leaching agent migration test system and leaching agent migration conversion test system',
#  'the production method of lithium carbonate used in the cathode material of lithium-ion batteries from buxite ore',
#  'automatic ore dressing monitoring method and system',
#  'beneficiation method for tin-tungsten-copper-zinc polymetallic ore by stage crushing and stage waste throwing',
#  'reactive power-saving control system based on intelligent internet of things',
#  'rare event prediction',
#  'ore grinding optimization treatment system based on large model',
#  'balance management method for mining and selecting metal in surface mine',
#  'method for predicting yield of concentrate on that day',
#  'strong magnetic machine current optimization method based on feeding parameter and intelligent algorithm',
#  'bert-rcnn model extraction feature-based data classification method for realizing energy-efficient storage',
#  'intelligent monitoring device for ore pulp and foam fullness of flotation cell, and monitoring method thereof',
#  'method for automatic control of technological grades of ore in flow',
#  'geological disaster early warning method and device based on artificial intelligence and storage medium',
#  'intelligent identification method and device for underground mining subsidence area, electronic equipment and storage medium',
#  'research and application of efficient novel copper collecting agent m1',
#  'big data application information cloud platform based on beidou',
#  'expressway charging auditing system',
#  'phosphorite associated fluorine resource storage volume prediction method, device, equipment and medium',
#  'interface semantic data generation method and device, computer equipment and storage medium',
#  'matching method and device for ore grinding control parameters and electronic equipment',
#  'precise medical health big data platform',
#  'penetration test method and system for network device',
#  'front-end sensing equipment health index evaluation system based on hudi data lake',
#  'customer mining method and device applied to insurance recommendation, equipment and storage medium',
#  'production process and equipment for ultra-pure fine iron powder',
#  'intelligent mine automatic transportation equipment based on internet of things',
#  'gravity-assisted dental design',
#  'ai technology-based elutriation magnetic separator tailing control method and terminal',
#  'mining apparatus and methods',
#  'internet of things access authentication and identity authentication method and device, electronic equipment and storage medium',
#  'soft measurement modeling method for overflow granularity in multi-working-condition ore dressing process',
#  'uninterrupted power supply (ups) discharge identification system and method based on edge calculation',
#  'metal oxide material reduction means',
#  'machine learning models for determining pathogenic genetic variants',
#  'foam flotation iron ore grade prediction method based on dynamic low-rank reconstruction',
#  'metal oxide material reduction means',
#  'ore crushing and grinding device',
#  'method and device for controlling single stone crusher, storage medium and electronic equipment',
#  'relationship mining method, device and equipment and readable storage medium',
#  'projection constraints enforced in a database system',
#  'electronic medical record quality control method and system, terminal and storage medium',
#  'method and system for predicting power consumption of cement raw material grinding system',
#  'privacy control-adjustable commercial vehicle electronic logging device (eld) and trip data-sharing system between a transportation company and a third-party corporate partner entity',
#  'industrial and mining equipment monitoring and early warning device based on industrial internet of things',
#  'big data-based edge computing network management method and platform',
#  'multi-modal data fusion method and device, computer equipment and storage medium',
#  'anti-counterfeiting traceability method and device for automobile parts, and storage medium',
#  'privacy control-adjustable commercial vehicle electronic logging device (eld) and trip data-sharing system between a transportation company and a third-party corporate partner entity',
#  'intelligent prediction method, device and equipment for uranium concentration in in-situ leaching uranium mining and storage medium',
#  'integration of carbon sequestration with selective hydrometallurgical recovery of metal values',
#  'ore detection method, server, terminal and system',
#  'auxiliary ore transportation system and transportation control method',
#  'coastal nuclear power station cold source disaster-causing object alarm and early warning intelligent system',
#  'transportation device for mining',
#  'analytics system for evaluating readiness an autonomous vehicles',
#  'device for realizing closed-loop continuous flotation of single-tank flotation machine',
#  'systems and methods for lowering the reduction of iron ore energy',
#  'deep-sea mining mixed transportation lifting test system for simulating deep-sea environment',
#  'method, device and equipment for measuring ore discharge port of rough crushing machine',
#  'content-based contextual reactions for posts on a social networking system',
#  'ffeasibility cloud computing analysis method',
#  'content recommendation system based on artificial intelligence, electronic equipment and storage medium',
#  'behavior path generation method and device, equipment and storage medium',
#  'pre-selecting and waste-discarding method for non-ferrous metal ores',
#  'mining area mining subsidence prediction method, readable storage medium and computer equipment',
#  'artificial intelligence-based generation of anthropomorphic signatures and use thereof',
#  'intelligent control method for ore pulp liquid level in flotation process',
#  'intellectual property case source recognition method and device, equipment and storage medium',
#  'distributed data management monitoring system based on big data',
#  'devices, systems, facilities and processes for co2 post combustion capture incorporated at a data center',
#  'ore pulp phase bubble image in-situ acquisition device of flotation machine',
#  'data acquisition method, electronic equipment and storage medium',
#  'flotation system and method for continuously and automatically controlling eh and ph of ore pulp',
#  'feature mining combination method, device and equipment and computer readable storage medium',
#  'truck anti-collision early warning method and device for strip mine and storage medium',
#  'blasting fragmentation prediction method based on ore rock crushing mechanism',
#  'financial product incentive data configuration method and device, computer equipment and medium',
#  'automatic power supply control method and system based on artificial intelligence and storage medium',
#  'method for evaluating ore grinding cost in magnetic separation-fine screening regrinding process',
#  'system and method for determining a location of ore in a stockpile',
#  'abnormal patient identification method and device, terminal equipment and storage medium',
#  'multistage silicon removal and purification device and method for fine iron powder',
#  'system and method for determining a location of ore in a stockpile',
#  'internet of things system for monitoring storage stage state of solid rocket engine',
#  'apparatus, systems, and methods for enhancing hydrocarbon extraction and techniques related thereto',
#  'method and system for provenance-based data backups',
#  'harmless treatment method for phosphate ore beneficiation tailings',
#  'fuzzy control method for flotation concentrate grade',
#  'user intention determination method and device, computer equipment and storage medium',
#  'sample-efficient representation learning for real-time latent speaker state characterisation',
#  'smart city informatization analysis system',
#  'digital twinning system of transformer substation',
#  'crusher feed metering device',
#  'integration of carbon sequestration with selective hydrometallurgical recovery of metal values',
#  'pavement model creating method and device of mine simulation system, medium and equipment',
#  'user real-time recommendation method, device, system and equipment and readable storage medium',
#  'ore storage bin bridge type grab bucket automatic loading method and system',
#  'p-wave arrival time automatic pickup method based on deep learning',
#  'systems and methods for sorting and collecting enhanced metal-bearing ores of a desired size from metal-bearing ores',
#  'data recommendation method and device, storage medium and processor',
#  'sae-qpso-rvm-based mining dump truck starting lead-acid storage battery life prediction method',
#  'dynamic network roaming',
#  'mining area power dispatching method and device, electronic equipment and readable storage medium',
#  'novel efficient ore grinding equipment',
#  'visualized dynamic filtration loss and discharge and mining simulation device and simulation method for tight gas reservoir fracturing fluid',
#  'system and method for assigning a haul truck dump to a location',
#  'method for treating heavy metal pollution in sulphide ore tailings',
#  'control method of mining robot, mining robot and storage medium',
#  'mineral resource exploration multi-dimensional analysis processing system based on internet of things and feature recognition',
#  'flow message identification method and device, computing equipment and computer storage medium',
#  'system and method for determining a dump location for a vehicle',
#  'aggregate service with user interface',
#  '3d printing equipment for lunar soil resources in lunar pit',
#  'predicting fatigue of an asset that heals',
#  'method for processing potash ores',
#  'determining shear rate and/or shear stress from sonar based velocity profiles and differential pressure',
#  'mining truck remote emergency takeover system based on stacked head-up display',
#  'sensitive comment recognition method and device, terminal equipment and storage medium',
#  'arrangement for delivery of production control information to a mining work machine',
#  'point cloud data enhancement method and device for mining area automatic driving data set construction',
#  'detection method and device for emerging theme, computer equipment and storage medium',
#  'network security detection method and system based on big data, and storage medium',
#  'urban rail transit underground structure intelligent monitoring system based on internet of things',
#  'coordinated scheduling optimization method for dense dehydration process',
#  'gas monitoring system for hexafluorobutadiene storage place and monitoring method thereof',
#  'ore grinding granularity soft measurement method, system, medium, equipment and terminal',
#  'gas monitoring system for hexafluorobutadiene storage place and monitoring method thereof',
#  'video analytic processing with neuro-symbolic artificial intelligence',
#  'method for selecting ball diameter and grading of grinding ball of horizontal stirring mill',
#  'method for adjusting elutriation magnetic separator, terminal and storage medium',
#  'medical comprehensive management cloud platform based on block chain technology',
#  'question mining method and device, electronic equipment and storage medium',
#  'intelligent mining method for manned and unmanned mixed team of surface mine',
#  'mining flotation machine',
#  'smart campus cloud platform system',
#  'abnormal scene detection method for laser radar, electronic equipment and storage medium',
#  'real-time, stream data information integration and analytics system',
#  'method for determining flotation design time based on laboratory flotation closed-circuit test',
#  'blasting drilling method, device and equipment based on artificial intelligence and medium',
#  'apparatus for acquiring 3-dimensional maps of a scene',
#  'online crushing and screening equipment and process for large-particle-size nickel ore',
#  'economically dependent customer mining method and device, storage medium and electronic equipment',
#  'mine fully-mechanized mining automation equipment based on internet of things control',
#  'method and device for realizing parallel mining based on large-scale financial investment time series data, processor and computer readable storage medium thereof',
#  'ore pulp shipborne dehydration device of ocean mining ship',
#  'microbiome based systems, apparatus and methods for the exploration and production of hydrocarbons',
#  'voiceprint data acquisition system for mining transformer',
#  'strip mine surface three-dimensional model construction method, device and equipment and storage medium',
#  'intelligent park personnel congestion dredging management system and method',
#  'flotation cell ph adjusting device',
#  'energy management method for hybrid-drive unmanned mining truck',
#  'method and apparatus for the control of a flotation separation process, including parameters of the flotation process and reagent addition to optimize mineral recovery',
#  'intelligent film and television work subtitle production method and system',
# ...
#  'energy management system with machine learning',
#  'sampling device for mineral geological exploration',
#  'thickener analogue simulation experiment device',
#  'client mining method based on artificial intelligence and related equipment',
#  'sampling device for lead zinc ore component detection',
#  'intelligent sorting system based on x-ray imaging',
#  'system and method for auto-mining of resources, building dependency registry and notifying impacted services',
#  'ore sample crushing device for geological mineral exploration',
#  'high-efficiency recovery process for full-size tio2 in vanadium magnetite tailings',
#  'dynamic cascaded clustering for dynamic vnf',
#  'three-dimensional directional transient electromagnetic detection device and method for mining borehole',
#  'phosphate ore sorting method and device, readable storage medium and equipment',
#  'service quality evaluation processing method and device, computer equipment and storage medium',
#  'feeding device capable of accurately controlling feeding amount and control method thereof',
#  'ore granularity grading method and system based on image and deep neural network',
#  'account evaluation method and device, computer equipment and storage medium',
#  'shearing system for longwall mining',
#  'mine equipment operation state data visualization system',
#  'mine equipment operation state data visualization system',
#  'database design method for city management',
#  'ore pulp copper grade online prediction soft measurement modeling method',
#  'e-mirror automatic position adjustment system',
#  'weighing system, carry-scraper and weighing method',
#  'ore sampling and sample preparation system and method',
#  'externally validated proof of work for appending a block record to a blockchain with a commitment database server',
#  'user mining method and device, computer equipment and readable storage medium',
#  'mining area rockfall monitoring device and method',
#  'multi-probe particle size detector for ore pulp',
#  'system and method to recommend service action for predictive maintenance',
#  'label mining method and device, electronic equipment and storage medium',
#  'ore component information extraction method and apparatus and storage medium',
#  'intent-based organisation of apis',
#  'intelligent optimization control method for ore grinding process',
#  'intelligent precious metal pretreatment reselection equipment',
#  'aerial photography insulator spontaneous explosion defect detection model, method and equipment and storage medium',
#  'small flotation column for laboratory',
#  'user complaint database expansion method and device thereof and storage medium',
#  'copper grade scn modeling algorithm for x fluorescence grade analyzer',
#  'mechanical-electrical integrated ore processing equipment',
#  'electric shovel positioning method based on density clustering',
#  'self-propelled towing simulator for deep-sea mining system applicable to natural water bodies and simulation method using the same',
#  'encryption method and device for private data transmission',
#  'quality inspection function method and device for mass medical data storage',
#  'element analysis method based on ore grinding image',
#  'method for automatic control of technological grades of crushed ore in flow',
#  'crushing mechanism for automatic gold ore dressing system',
#  'theme mining method and device, electronic equipment and storage medium',
#  'automatic driving scene mining method based on semi-supervised transform detection',
#  'intelligent sorting system based on x-ray imaging',
#  'session prompting method and device based on artificial intelligence, storage medium and equipment',
#  'digital medical information protection method based on artificial intelligence and storage medium',
#  'fluorite mine flotation recovery device based on waste heat recycling',
#  'method and system for secure exchange of user cookie-data and user interactions for cryptocurrency',
#  'method for constructing four-dimensional database of black rock type uranium mine',
#  'coarse crushing integrated control system and method',
#  'lime preparing and adding system',
#  'high-quality and ultra-pure fine iron powder grading preparation device and high-quality and ultra-pure fine iron powder grading preparation method',
#  'predictions for a process in an industrial plant',
#  'pedestrian flow analysis method, storage medium and processor',
#  'centrifugal diffusion fusion type flotation equipment',
#  'ore grinding medium bulk specific gravity measuring device and method',
#  'mining node, computer program product and method of operation thereof for use in appending a block record to a blockchain',
#  'soft measurement method for exciting current of strong magnetic machine',
#  'system, apparatus and method for performing a 3d surface scan and/or texture acquisition using rolling shutter cameras',
#  'mine information management transmission system device based on f5g',
#  'titanium dioxide waste residue recycling system',
#  'method and device for mining fuel consumption optimization strategy, electronic equipment, medium and chip',
#  'mining area railway line deformation monitoring method based on beidou satellite positioning',
#  'zinc fast coarse adding amount adjusting method based on memory network and predictive controller',
#  'mine transportation management system and management method',
#  'curve cooperative sensing method of 5g-based mining area unmanned transportation system',
#  'data processing method, device and equipment and computer storage medium',
#  'method for flotation separation of copper-sulfur minerals through ferrate',
#  'digital twin foundation development platform for park energy consumption',
#  'attachment status monitoring of ground engaging tools (get) at heavy machinery',
#  'fracturing evaluation method and system based on electromagnetic fracturing monitoring and storage medium',
#  'digital forest and grass system',
#  'tailing slurry sampling device',
#  'decentralized social news network website application (dapplication) on a blockchain including a newsfeed, nft marketplace, and a content moderation process for vetted content providers',
#  'sensor cleaning method and device, mining unmanned vehicle and readable storage medium',
#  'method for carrying out regional transportation volume statistics according to vehicle satellite positioning data',
#  'intelligent fire extinguishing system for field of mine mining based on internet of things technology',
#  'event log acquisition method based on task mining technology',
#  'abnormal traffic detection method and device, storage medium and equipment',
#  'combined commodity mining method based on knowledge graph rule embedding',
#  'method and device for constructing digital disease module',
#  'multi-metal nodule crushing device and method based on supercritical carbon dioxide',
#  'equipment for detecting vanadium content in ore',
#  'portrait lock capable of recognizing and storing portraits based on big data',
#  'business system construction method and device, electronic equipment and computer storage medium',
#  'reclamation area feature extraction method and device, computer equipment and storage medium',
#  'liquid iron-free aluminum sulfate production system',
#  'satellite-borne magnetic field data processing system based on big data',
#  'image feature mining method, device, storage medium and electronic equipment',
#  'dust removal device for mineral separation',
#  'automatic control device for liquid level of ore pulp tank of flotation machine',
#  'computerized system and method for automatically communicating conditional messages within a mobile application environment',
#  'equipment control method and device, electronic equipment and storage medium',
#  'space-time big data management method based on metadata',
#  'ore crusher with anti-blocking function',
#  'comprehensive data analysis and management system based on distributed architecture',
#  'ore grade automatic real-time monitoring system and method suitable for rail transportation',
#  'agricultural machine maintenance prediction method and device, storage medium and electronic equipment',
#  'enterprise informatization management platform and method based on big data',
#  'response to emergency department surge prediction',
#  'federated learning method and apparatus based on graph neural network, and federated learning system',
#  'personnel positioning-based transportation metering system',
#  'method and system for analyzing performance of oltp service system',
#  'big data authentication method and system based on knowledge graph',
#  'multi-line laser radar and range finder coupled stored mine pile scanning equipment',
#  'simulated macadam experimental equipment for mining',
#  'machine pump type selection and analysis technology based on big data algorithm',
#  'plant-microorganism combined remediation system for mining wasteland ecology',
#  'mining method and mine',
#  'offline capabilities for live applications in a cloud collaboration platform',
#  'pressure-control temperature-control hypergravity experimental device for simulating deep-sea seabed responses',
#  'mine waste identification method, device and equipment based on fused image and storage medium',
#  'method and system for cryptocurrency mining center',
#  'strip mine yield determination method, device and system, chip and terminal',
#  'systems and methods for trajectory determination',
#  'mineral data integrated acquisition platform based on geological exploration and potential evaluation',
#  'method for generating expert feature dimension required by machine learning modeling',
#  'differentiable method for mining constant rules',
#  'obstacle processing system in unmanned mine driving area',
#  'data collaborative sharing security system',
#  'multi-view unsupervised graph contrast learning model construction method and system, computer, storage medium and application',
#  'automatic separation adjusting system and method for dry magnetic separator',
#  'method and device for identifying working state of excavator, excavator and processor',
#  'slope soil curing agent for tailing storage yard in southern rare earth mining area',
#  'belt ore conveying weighing and particle size estimation intelligent detection system and method',
#  'mining eco-environment damage evaluation method and system, and storable medium',
#  'peak regulation and frequency modulation method and system for power plant storage battery data center',
#  'automatic aging calibration system, intelligent aging cabinet and intelligent aging vehicle',
#  'ship accompanying movement mode mining method, system and equipment and storage medium',
#  'method for monitoring mine safety management based on insar',
#  'assessing the benefits of automatic grinding control using pst technology for true on-line particle size measurement',
#  'device and method for solid-state fluidized mining of natural gas hydrates in shallow seabed',
#  'automatic feature mining management method and device, computer equipment and storage medium',
#  'intelligent mining dispatching information acquisition guiding device',
#  'methods for processing oil sands containing swelling clays',
#  'hazardous truck transportation risk assessment method and system based on hierarchical fuzzy neural network',
#  'big data marketing method and device based on viewing behavior and readable storage medium',
#  'externally validated proof of work for appending a block record to a blockchain with a mining node',
#  'passenger flow warehouse data tracing method, device and system and storage medium',
#  'retaining wall detection method, retaining wall detection device and storage medium',
#  'crushing system control method based on cyclic load',
#  'frequency conversion control system of sand making machine and frequency conversion control method and device of sand making machine',
#  'clamping and fixing device for ore test',
#  'distributed detection of malicious cloud actors',
#  'abnormality detection method and device, equipment and storage medium',
#  'parameter configuration optimization method and optimization system for cloud storage system',
#  'redo mining during rolling upgrade',
#  'cermet or cemented carbide mixture and three dimensional printing thereof',
#  'synonym mining method, device and equipment and storage medium',
#  'laboratory ore sample grinding sample preparation bag',
#  'real-time ore blending-oriented multi-target ore card online scheduling method and system',
#  'method for recycling mineral powder slurry and comprehensively utilizing resources in open-pit stope',
#  'mining exploration development area evaluation method and device',
#  'method and control node for assisted vehicle control in a mining environment',
#  'vehicle fault analysis method and device, electronic equipment and storage medium',
#  'strip mine planned mining and stripping amount evaluation method and device, storage medium and terminal',
#  'unmanned aerial vehicle fault prediction system based on management big data',
#  'arc-shaped lining plate structure of ball mill and cavity type optimization method',
#  'financial management system and financial management method',
#  'super range extension control system for electric vehicles (evs)',
#  'negative electrodes for electrochemical cells',
#  'solid iron-free aluminum sulfate production system',
#  'multi-source streaming big data fusion convergence processing framework model implementation method',
#  'precise industry chain investment attracting system based on big data',
#  'mental health state prediction method and system based on correlation analysis',
#  'device for rapidly detecting total iron content in iron ore',
#  'security risk prediction method and device, equipment and storage medium',
#  'estimating the moving state of rotating machines systems and methods',
#  'full-automatic alloy ore sample preparation screening and measuring system',
#  'network node, mobile node and methods performed therein',
#  'unbalanced incremental learning method based on complementary relationship mining',
#  'fact management system',
#  'electric power personal casualty accident key hidden danger factor extraction method based on text mining',
#  'fast hydrating polyacrylamide microplates',
#  'intelligent mine management and control method and management and control facility based on digital twinning',
#  'task scheduling method and device, electronic equipment and storage medium',
#  'collophanite reverse flotation magnesium removal raw ore blending method',
#  'in-situ leaching uranium mining experiment management system',
#  'method for detecting components of lithium-containing mineral flotation pulp in real time',
#  'live browsing of granular mailbox data',
#  'method for pre-enrichment, suspension roasting, separation and enrichment of ferromanganese ore',
#  'unmanned inspection equipment for iron ore',
#  'online ore sorting equipment based on machine vision',
#  'method and arrangement for managing power consumption in a mine',
#  'mineral aggregate distribution method and device and computer readable storage medium',
#  'mining inspection robot storage bin',
#  'credit risk assessment method and device, computer equipment and storage medium',
#  'collaborative loading and transporting system and method for unmanned transportation of mine',
#  'post information processing method and device based on ai, equipment and storage medium',
#  'cloud service auditing system and method based on blockchain',
#  'photographing method and terminal',
#  'system performance index prediction method and device, server and storage medium',
#  'data analysis method and device, electronic equipment and storage medium',
#  'mining intrinsically safe processing terminal',
#  'metadata-based diagnosis and management system for cardiovascular and cerebrovascular diseases',
#  'storage device and memory controller',
#  'mill control method and mill control device',
#  'train wheel set turning repair scheduling system and method',
#  'learning graph',
#  'data analysis method and device, equipment, storage medium and product',
#  'downhole ore metering system',
#  ...]

# %%
descartados_subc_con_stopwords = obtiene_descartados(filtrados_usando_subcadenas, data_target)
len(descartados_subc_con_stopwords)
# Out:
# 5

# %%
# Obtiene los descartados
data_descartados_con_subc = data_target[data_target['title'].isin(descartados_subc_con_stopwords)]
data_descartados_con_subc
# Out:
#                                                   title  \
# 145      file system integration into data mining model
# 1544              interactive sequential pattern mining
# 1821  text keyword mining method and device thereof,...
# 2020            keyword mining system and mining method
# 2373  text main body keyword mining method, system a...
#
#                                                abstract publication_date
# 145   Aspects of a storage device including a memory...       2023-11-09
# 1544  Interactive sequential pattern mining is discl...       2020-02-18
# 1821  The invention discloses a text keyword mining ...       2022-02-18
# 2020  The invention discloses a keyword mining syste...       2021-03-26
# 2373  The invention relates to the field of patent d...       2023-05-09

# %%
# Obtiene los filtrados
data_filtrados_con_subc = data_target[~data_target['title'].isin(descartados_subc_con_stopwords)]
data_filtrados_con_subc
# Out:
#                                                   title  \
# 0     method for operating a comminution circuit and...
# 1     process for integrating the mining and process...
# 2     system and method for continuous optimization ...
# 3     method for water and moisture management for a...
# 4     method for training a quality prediction model...
# ...                                                 ...
# 3187  systems, methods, and program products for fac...
# 3188  method and system for managing vehicle transpo...
# 3189  method for providing clock frequencies for com...
# 3190  wall panels and other components for custom en...
# 3191  retrofit cover plate and assembly to adapt alt...
#
#                                                abstract publication_date
# 0     A method for operating an ore comminution circ...       2020-09-03
# 1     The present invention belongs to the mining se...       2023-08-10
# 2     A method for continuously optimizing an ore gr...       2023-12-21
# 3     Wet conditions pose a plurality of hazards for...       2024-03-14
# 4     A method (1000, 1001) for training a quality p...       2022-09-22
# ...                                                 ...              ...
# 3187  Machine learning systems and methods are descr...       2023-06-13
# 3188  CA 03091162 2020-08-13 (12) INTERNATIONAL APPL...       2021-11-16
# 3189  The present disclosure relates to a method for...       2023-04-20
# 3190  Custom enclosures are made using various types...       2023-08-03
# 3191  A multi-functional retrofit cover plate assemb...       2022-06-23
#
# [3187 rows x 3 columns]

# %% [markdown]
# ---
# **Observación**
#
# ---
#
# La técnica de subcadenas considerando las stopwords logra descatar 5 registos dejando 3187.

# %% [markdown]
# ### Excluyendo las stopwords

# %%
data_target = data[['title', 'abstract', 'publication_date']]
data_target['title'] = data_target['title'].apply(preprocesar_texto)
# Out:
# <ipython-input-28-42840effbdc5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_target['title'] = data_target['title'].apply(preprocesar_texto)

# %% [markdown]
# ## Filtro usando coincidencia fuzzy
# Este método ocupa umbrales y se ha probado con varios umbrales desde 10% a 90%.
#
# La función por defecto usa un umbral del 80%.
#
# Consideraciones:
# + Valores Bajos (e.g., 50%): Puede aumentar la cantidad de coincidencias, pero podría incluir coincidencias no deseadas.
# + Valores Altos (e.g., 90-100%): Limita las coincidencias a aquellas que son casi exactas, reduciendo falsos positivos.
# + El ajuste del threshold dependerá de cuánta tolerancia tengas a diferencias en la ortografía, errores tipográficos o variaciones en los términos que se están comparando.

# %%
def remove_numbers(text):
    return re.sub(r'\d+', '', text)

def contains_fuzzy_match(text, terms, threshold=80):
    # Limpiar el texto
    text_sin_numeros = remove_numbers(text)
    words = text_sin_numeros.split()
    for word in words:
        for term in terms:
            if fuzz.partial_ratio(word, term) >= threshold:
                return True
    return False

# %%
lst_resultados = []

# %% [markdown]
# ### Experimento incluyendo las stopwords

# %%
# Vuelve a seleecionar los datos para asegurar
data_target = data[['title', 'abstract', 'publication_date']]
data_target['title'] = data_target['title'].apply(convierte_a_minusculas)
# Out:
# <ipython-input-117-ee3b0254d62c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_target['title'] = data_target['title'].apply(convierte_a_minusculas)

# %%
# Probando con varios umbrales
for limite in range(1,10):
  print(f"Con threshold {limite*10} quedan {len([title for title in data_target['title'] if not contains_fuzzy_match(title, excluyentes, threshold=limite*10)])} registros")
# Out:
# Con threshold 10 quedan 0 registros
# Con threshold 20 quedan 0 registros
# Con threshold 30 quedan 0 registros
# Con threshold 40 quedan 1 registros
# Con threshold 50 quedan 14 registros
# Con threshold 60 quedan 95 registros
# Con threshold 70 quedan 675 registros
# Con threshold 80 quedan 981 registros
# Con threshold 90 quedan 1022 registros

# %%
filtro_fuzzy = [title for title in data_target['title'] if not contains_fuzzy_match(title, excluyentes, threshold=90)]
filtro_fuzzy
# Out:
# ['industrial robotic platforms',
#  'monitoring ore',
#  'mineral recovery control',
#  'low cost, size, weight, and power (cswap) geolocation capability utilizing signal characteristics passed through to backhaul network',
#  'user generated tag collection system and method',
#  'optimal energy storage utilization',
#  'smart city disorderly-stacked material management system and method',
#  'underground mine energy management system',
#  'ore component analysis device and method',
#  'mineral recovery control',
#  'fluidized-bed flotation unit, mineral processing apparatus, and fluidized-bed flotation method',
#  'everything interconnection training platform and control method and device',
#  'safety interlock recommendation system',
#  'smart city smart drone uass/uav/vtol smart mailbox landing pad',
#  'smart city smart drone uass/uav/vtol smart mailbox landing pad',
#  'augmented photo capture',
#  'adaptive discovery and mixed-variable optimization of next generation synthesizable microelectronic materials',
#  'team-based tele-diagnostics blockchain-enabled system',
#  'urban health index prediction system, prediction analysis method and storage medium thereof',
#  'determining ore characteristics',
#  'document digitization, transformation and validation',
#  'insurance value determination method and device, equipment and storage medium',
#  'strip mine digital twin remote operation and maintenance method and device and storage medium',
#  'predictive customer service environment',
#  'crushing and flotation all-in-one machine',
#  'measurement system and measurement method',
#  'flotation ph value prediction method and device, electronic equipment and storage medium',
#  'locked-on target based object tracking method and portable terminal therefor',
#  'self-building hierarchically indexed multimedia database',
#  'iron-zinc ore grinding and grading automation system',
#  'digital life and/or health claims processing system integrating multiple claim channels, and method thereof',
#  'dense three-dimensional correspondence estimation with multi-level metric learning and hierarchical matching',
#  'ore grading process',
#  'ground surface settlement monitoring method and device, electronic equipment and storage medium',
#  'ground rail of ore transportation rail robot',
#  'blasting system and method',
#  'human-machine dialogue system and method',
#  'smart city security monitoring system',
#  'conversion rate prediction method, device and equipment and storage medium',
#  'computing environment provisioning',
#  'gigabit potential customer prediction method and device, computer equipment and storage medium',
#  'processing of laterite ores',
#  'binary system gold ore gold-bearing mineral gold content determination method',
#  'risk account identification method and device, computer equipment and storage medium',
#  'internet of things equipment encryption key acquisition method and device, equipment and storage medium',
#  'non-ferrous metal mineral flotation chemical pretreatment method',
#  'flotation reagent adsorption behavior and mineral floatability prediction method and system and storage device',
#  'improvements to operational state determination and modification',
#  'flotation field parameter detection device',
#  'measuring tank fluids and remote monitoring system',
#  'human-machine collaborative conversation interaction system and method',
#  'living body detection model training method and device, electronic equipment and storage medium',
#  'intelligent ore positioning and crushing control method and device',
#  'telephone traffic request quantity prediction method and device, electronic equipment and storage medium',
#  'solar modules with integrated flexible hybrid electronics',
#  'open source threat intelligence aggregation platform',
#  'power optimization through orchestration and prioritization of machines and functions',
#  'crusher ore feeding control method and device, electronic equipment and storage medium',
#  'ore grindability obtaining method and device and prediction model',
#  'lightweight multi-path mesh image segmentation method and system, and electronic equipment',
#  'integrated energy storage management system and energy management method',
#  'phosphorite flotation tailing treatment system',
#  'removal of amines from aqueous streams',
#  'multi-process flotation column separation system reagent adding automatic control practical training device',
#  'inspection task issuing method and device, inspection path planning method and device and storage medium',
#  'mineral flotation separation',
#  'intelligent mediation optimization follow-up system and method',
#  'photo album video recognition method, system and device and storage medium',
#  'ai-based operation and maintenance fault determination method and device, equipment and storage medium',
#  'transporting mined material',
#  'cableway safe operation control system, structure and method',
#  'smart application system',
#  'prompting method, device and equipment and readable storage medium',
#  'full-automatic lump ore sample preparation system and full-automatic lump ore sample preparation method',
#  'request identification method and apparatus, device, and storage medium',
#  'removal of amines from aqueous streams',
#  'multidimensional privacy control',
#  'multi-process flotation liquid level automatic control practical training device',
#  'digital intelligent mine system',
#  'selective processing',
#  'automatic ore crushing and humidifying equipment',
#  'image processing method and system',
#  'artificial intelligence distributed storage system',
#  'interactive validation of annotated documents',
#  'magnetic microfluidic concentrator, intelligent magnetic microfluidic concentrator, and complete set of beneficiation equipment using the same',
#  'full-intelligent sintering fuel granularity control method',
#  'flotation kinetic parameter measurement method, device and system and storage medium',
#  'leaching agent migration test system and leaching agent migration conversion test system',
#  'full-automatic fine ore sample preparation system and full-automatic fine ore sample preparation method',
#  'sensor and actuator based lifecycle monitoring of machines performing automated machine tasks',
#  'ore removal temperature prediction device of sintering cooling device',
#  'highway-railway combined transportation volume prediction method, device and equipment and readable storage medium',
#  'mechanical automatic ore crushing device',
#  'copper-molybdenum ore froth flotation segmentation method and system',
#  'high-capacity-ratio photovoltaic short-term power prediction method, device and equipment and storage medium',
#  'security vulnerability test method and device, equipment and readable storage medium',
#  'feo content prediction method, model training method and device, electronic equipment and medium',
#  'copper smelting slag flotation control method',
#  'tantalum-niobium ore ball mill',
#  'online flotation working condition detection device',
#  'multi-type ore storage yard reserve dynamic analysis method and system, equipment and medium',
#  'leaching agent migration test system and leaching agent migration conversion test system',
#  'automatic ore dressing monitoring method and system',
#  'rare event prediction',
#  'expressway charging auditing system',
#  'phosphorite associated fluorine resource storage volume prediction method, device, equipment and medium',
#  'gravity-assisted dental design',
#  'internet of things access authentication and identity authentication method and device, electronic equipment and storage medium',
#  'metal oxide material reduction means',
#  'metal oxide material reduction means',
#  'ore crushing and grinding device',
#  'electronic medical record quality control method and system, terminal and storage medium',
#  'big data-based edge computing network management method and platform',
#  'integration of carbon sequestration with selective hydrometallurgical recovery of metal values',
#  'ore detection method, server, terminal and system',
#  'auxiliary ore transportation system and transportation control method',
#  'coastal nuclear power station cold source disaster-causing object alarm and early warning intelligent system',
#  'ffeasibility cloud computing analysis method',
#  'behavior path generation method and device, equipment and storage medium',
#  'artificial intelligence-based generation of anthropomorphic signatures and use thereof',
#  'intellectual property case source recognition method and device, equipment and storage medium',
#  'ore pulp phase bubble image in-situ acquisition device of flotation machine',
#  'abnormal patient identification method and device, terminal equipment and storage medium',
#  'user intention determination method and device, computer equipment and storage medium',
#  'smart city informatization analysis system',
#  'digital twinning system of transformer substation',
#  'crusher feed metering device',
#  'integration of carbon sequestration with selective hydrometallurgical recovery of metal values',
#  'pavement model creating method and device of mine simulation system, medium and equipment',
#  'user real-time recommendation method, device, system and equipment and readable storage medium',
#  'ore storage bin bridge type grab bucket automatic loading method and system',
#  'dynamic network roaming',
#  'novel efficient ore grinding equipment',
#  'flow message identification method and device, computing equipment and computer storage medium',
#  'aggregate service with user interface',
#  'determining shear rate and/or shear stress from sonar based velocity profiles and differential pressure',
#  'sensitive comment recognition method and device, terminal equipment and storage medium',
#  'ore grinding granularity soft measurement method, system, medium, equipment and terminal',
#  'video analytic processing with neuro-symbolic artificial intelligence',
#  'smart campus cloud platform system',
#  'strip mine surface three-dimensional model construction method, device and equipment and storage medium',
#  'intelligent park personnel congestion dredging management system and method',
#  'flotation cell ph adjusting device',
#  'intelligent film and television work subtitle production method and system',
#  'user tag portrait processing method, user portrait system, device and storage medium',
#  'fund product analysis and management method, device and system',
#  'iron ore air shaft ore pass breaking method and system',
#  'cloud-oriented database security situation awareness system',
#  'two-lane automation equipment management method and device, electronic equipment and storage medium',
#  'maintenance recommendations using lifecycle clustering',
#  'mechanical automatic ore crushing device',
#  'basketball training analysis method and system and storage medium',
#  'flotation recovery rate prediction device, flotation recovery rate prediction method, and program',
#  'full-automatic ore sample preparation and moisture determination system',
#  'gold ore grinding-floating process energy consumption prediction method',
#  'laboratory flotation temperature control auxiliary equipment and using method thereof',
#  'verbal skill template evaluation method and device, electronic equipment and storage medium',
#  'construction method and system of traditional chinese medicine knowledge graph, and storage medium',
#  'environmental management system',
#  'trusted user system construction method and system and readable storage medium',
#  'continuous intelligent multi-stage mineral separation device and mineral separation application method',
#  'oxidative heap leaching of base metals',
#  'distributed ore grinding expert system model prediction control method',
#  'multi-size-fraction mineral preparation machine',
#  'unattended ore full-automatic sample preparation system',
#  'dumping position state detection method and device, electronic equipment and storage medium',
#  'fine grain tailing damming method and simulation device',
#  'maintenance recommendations using lifecycle clustering',
#  'intelligent control system of flotation system',
#  'full-automatic ore sample preparation and moisture determination system',
#  'device of predicting, medium of predicting, and method of predicting production index using moving object stay number',
#  'human body temperature acquisition processing method and system',
#  'multi-modal methods and systems of disease diagnosis',
#  'preparation and valuing method of molybdenum raw ore standard sample',
#  'cloud-based enterprise holographic archive management and control method and device and storage medium',
#  'embedded system-oriented flotation froth flow velocity extraction method',
#  'tailing pond flood regulation storage capacity prediction method and device, electronic equipment and medium',
#  'beneficiation fine grinding control method and beneficiation fine grinding control system thereof',
#  'mineral treatment method and system applying ultrasound to flotation froth',
#  'strip mine transportation scheduling scheme making method',
#  'source code vulnerability detection method and system and storage medium',
#  'flotation dosing device with automatic pipeline cleaning function',
#  'big data-based vehicle-mounted video monitoring device and processing method',
#  'hydrogen explosion ore crushing equipment and crushing method',
#  'mine intelligent whole production process management and control system',
#  'iron ore concentrate long-distance pipeline terminal material treatment device and method',
#  'unattended ore full-automatic sample preparation system',
#  'battery health state prediction method and device, storage medium and electronic equipment',
#  'fleet-specific performance impact of vehicle configuration',
#  'ore pulp conveying digital pipeline monitoring management system',
#  'mine simulation analysis method and device, equipment and storage medium',
#  'natural gas extraction desanding and dewatering device',
#  'flotation pulp steam heating device',
#  'temperature-control flotation concentrator',
#  'auxiliary feeding device of calcium carbonate ore grinding machine',
#  'medical waste intelligent tracking management system and method',
#  'ore flow optimization',
#  'ore feeder of centrifugal concentrator',
#  'self-learning recommendation method and device, computer equipment and storage medium',
#  'cloud computing platform with container cloud real-time anomaly detection',
#  'beneficiation processing method',
#  'weak ore spot ore sorting method and device, readable storage medium and equipment',
#  'flotation blanking device',
#  'liquid level control system of vertical ring high-gradient magnetic separator',
#  'post-earthquake trend analysis method and device, electronic equipment and readable storage medium',
#  'mineral analysis laboratory business plan with lowest turnover',
#  'full-automatic alloy ore sample preparation, screening and determination system',
#  'liquid level control system of vertical-ring high-gradient magnetic separator',
#  'automatic ore polished section grinding and polishing equipment and polished section grinding and polishing method',
#  'user behavior analysis method and device, electronic equipment and storage medium',
#  'energy management system with machine learning',
#  'thickener analogue simulation experiment device',
#  'phosphate ore sorting method and device, readable storage medium and equipment',
#  'service quality evaluation processing method and device, computer equipment and storage medium',
#  'feeding device capable of accurately controlling feeding amount and control method thereof',
#  'account evaluation method and device, computer equipment and storage medium',
#  'ore pulp copper grade online prediction soft measurement modeling method',
#  'e-mirror automatic position adjustment system',
#  'weighing system, carry-scraper and weighing method',
#  'ore sampling and sample preparation system and method',
#  'intent-based organisation of apis',
#  'intelligent precious metal pretreatment reselection equipment',
#  'aerial photography insulator spontaneous explosion defect detection model, method and equipment and storage medium',
#  'user complaint database expansion method and device thereof and storage medium',
#  'mechanical-electrical integrated ore processing equipment',
#  'coarse crushing integrated control system and method',
#  'lime preparing and adding system',
#  'high-quality and ultra-pure fine iron powder grading preparation device and high-quality and ultra-pure fine iron powder grading preparation method',
#  'pedestrian flow analysis method, storage medium and processor',
#  'centrifugal diffusion fusion type flotation equipment',
#  'ore grinding medium bulk specific gravity measuring device and method',
#  'titanium dioxide waste residue recycling system',
#  'mine transportation management system and management method',
#  'digital forest and grass system',
#  'tailing slurry sampling device',
#  'abnormal traffic detection method and device, storage medium and equipment',
#  'business system construction method and device, electronic equipment and computer storage medium',
#  'reclamation area feature extraction method and device, computer equipment and storage medium',
#  'liquid iron-free aluminum sulfate production system',
#  'equipment control method and device, electronic equipment and storage medium',
#  'ore crusher with anti-blocking function',
#  'agricultural machine maintenance prediction method and device, storage medium and electronic equipment',
#  'response to emergency department surge prediction',
#  'personnel positioning-based transportation metering system',
#  'multi-line laser radar and range finder coupled stored mine pile scanning equipment',
#  'strip mine yield determination method, device and system, chip and terminal',
#  'multi-view unsupervised graph contrast learning model construction method and system, computer, storage medium and application',
#  'belt ore conveying weighing and particle size estimation intelligent detection system and method',
#  'automatic aging calibration system, intelligent aging cabinet and intelligent aging vehicle',
#  'retaining wall detection method, retaining wall detection device and storage medium',
#  'frequency conversion control system of sand making machine and frequency conversion control method and device of sand making machine',
#  'distributed detection of malicious cloud actors',
#  'abnormality detection method and device, equipment and storage medium',
#  'laboratory ore sample grinding sample preparation bag',
#  'real-time ore blending-oriented multi-target ore card online scheduling method and system',
#  'vehicle fault analysis method and device, electronic equipment and storage medium',
#  'arc-shaped lining plate structure of ball mill and cavity type optimization method',
#  'financial management system and financial management method',
#  'solid iron-free aluminum sulfate production system',
#  'security risk prediction method and device, equipment and storage medium',
#  'estimating the moving state of rotating machines systems and methods',
#  'full-automatic alloy ore sample preparation screening and measuring system',
#  'network node, mobile node and methods performed therein',
#  'fact management system',
#  'fast hydrating polyacrylamide microplates',
#  'task scheduling method and device, electronic equipment and storage medium',
#  'collophanite reverse flotation magnesium removal raw ore blending method',
#  'mineral aggregate distribution method and device and computer readable storage medium',
#  'credit risk assessment method and device, computer equipment and storage medium',
#  'photographing method and terminal',
#  'system performance index prediction method and device, server and storage medium',
#  'storage device and memory controller',
#  'mill control method and mill control device',
#  'train wheel set turning repair scheduling system and method',
#  'learning graph',
#  'downhole ore metering system',
#  'intelligent ore blending device',
#  'productivity platform providing user specific functionality',
#  'underground mine stope operation management and control system and method',
#  'hydraulic gyratory crusher ore discharge port measuring tool and use method thereof',
#  'power fault diagnosis early warning method, device, equipment and storage medium',
#  'automatic multifunctional composite magnetic separation equipment',
#  'energy optimization plant and operating method thereof',
#  'recommendation method and device of vehicle insurance product, equipment and storage medium',
#  'microservice intelligent operation and maintenance system and method oriented to cloud native and application',
#  'digital ore drawing design platform, automatic ore drawing generation method and virtual-real fusion method',
#  'fact management system',
#  'tailing recovery method',
#  'mine car positioning control system',
#  'mine car positioning control system and method',
#  'automatic ore blending and setting device of ball mill',
#  'large-scale photovoltaic power station energy storage capacity configuration method considering light abandoning rate and prediction precision',
#  'traffic speed prediction method and system and storage medium',
#  'ore crusher',
#  'radar antenna scanning mode identification method and device, equipment and storage medium',
#  'ore pulp grade instrument and feedback regulation method thereof',
#  'few-shot object detection method',
#  'customer group classification method and device, computer equipment and storage medium',
#  'hydropower station milp model optimal representative water head selection method and system',
#  'mechanical automation crushing device convenient to screen',
#  'pressure prediction method and device, storage medium and terminal',
#  'charging plan generation method, electronic equipment and storage medium',
#  'ore discharge alarm device of autogenous mill',
#  'thermal-insulation real stone paint taking molybdenum tailings and molybdenum ore waste rock machine-made sand as aggregate, preparation method of thermal-insulation real stone paint and coating system containing thermal-insulation real stone paint',
#  'enterprise risk behavior intervention method and device, storage medium and computer equipment',
#  'ore-dressing equipment',
#  'ore granularity detection method and system, electronic equipment and storage medium',
#  'mineral flotation concentrate grade soft measurement method and device and related equipment',
#  'efficient environment-friendly ore processing production line',
#  'semantics and deviation aware content request and multi-factored in-network content caching',
#  'foam flotation machine',
#  'iron ore reasonable water content evaluation system and method',
#  'xxe attack detection method, system and device and computer storage medium',
#  'equipment site selection method and device, storage medium and electronic equipment',
#  'sintering temperature measuring system and method',
#  'mineral separation fine grinding control device',
#  'pharmaceutical process',
#  'automatic discharging device of mortar ore storage bucket',
#  'construction method and system of mine blasting area model and storage medium',
#  'underground metal mine trackless transportation system scheduling simulation method and device',
#  'cloud computing-based vehicle fleet benchmarking',
#  'rock ore specimen resistivity measuring device',
#  'system and method of predicting human interaction with vehicles',
#  'crowd flow characteristic determination method and device, electronic equipment and storage medium',
#  'double-handle flotation machine feeding sample sampler',
#  'ultraflotation with magnetically responsive carrier particles',
#  'multi-index comprehensive drought monitoring and early warning system',
#  'statistical method, device and equipment of mine resource model and storage medium',
#  'automatic control hydraulic magnetic force short-cone cyclone beneficiation system',
#  'electric power intelligent environmental protection platform',
#  'sustainable resources exchange method and system',
#  'underground mine rail transportation monitoring video automatic switching system and method',
#  'advertisement conversion rate estimation method and device, storage medium and electronic equipment',
#  'flotation liquid medicine high-precision feeding device',
#  'vit framework-based multi-category rock ore rapid classification method and equipment, and storage medium',
#  'service item prediction method and device, computer equipment and storage medium thereof',
#  'dangerous road section identification method and device',
#  'truck traffic flow prediction method, device and equipment and storage medium',
#  'unmanned wide-body mine truck',
#  'underground monitoring alarm device and method and computer readable storage medium',
#  'auxiliary control method, device and equipment of excavator and readable storage medium',
#  'automatic ore crushing device',
#  'construction and application of rvm sintered ore feo content soft measurement model',
#  'gnns social media mining-based fairness backdoor evaluation method and system',
#  'uranium mine water pumping test duration curve drawing method',
#  'medical aid decision model interpretation method and device, storage medium and electronic equipment',
#  'shale oil exploitation mode determination method and device, equipment and readable storage medium',
#  'tailing fluidity test factor evaluation method, device and equipment',
#  'automatic aging calibration system, intelligent aging cabinet and intelligent aging vehicle',
#  'traffic violation behavior analysis method and system, electronic equipment and storage medium',
#  'underground pollutant concentration prediction method and device, electronic equipment and storage medium',
#  'distribution trolley optimization scheduling method, device and equipment and storage medium',
#  'voice quality evaluation method and device, electronic equipment and computer storage medium',
#  'mill filling rate vibration monitoring system',
#  'abnormal brain connection prediction system, method and device and readable storage medium',
#  'full-life-cycle carbon footprint processing method and device, storage medium and equipment',
#  'reduced write amplification using small-block log',
#  'excavator control method, system and equipment and readable storage medium',
#  'association determination',
#  'cloud-native reservoir simulation',
#  'multifunctional private cloud storage device',
#  'semantic search method and device, electronic equipment, storage medium and product',
#  'metallurgical cycle grinding equipment',
#  'shale oil exploitation area division method, device and equipment and readable storage medium',
#  'intelligent logistics storage park safety perception system',
#  'sintered ore feo content detection method and sintered ore feo content detection system',
#  'single-cylinder hydraulic cone crusher tool',
#  'chinese medicine production process knowledge system',
#  'intelligent medicine box',
#  'mvt type lead zinc ore mineralization prediction method and device, computer equipment and storage medium',
#  'seawater suspended sediment concentration calculation method and device, electronic equipment and storage medium',
#  'splash-proof mineral separation flotation machine',
#  'court authorized pedestrian hidden property estimation decision support system architecture',
#  'transportation mechanism control system and transportation equipment',
#  'intelligent air compressor unattended system',
#  'virtual-real fusion flexible production line variable control method and system',
#  'intelligent mineral separation thickener',
#  'mineral product crusher with conveyor belt',
#  'pulp hydraulic transportation',
#  'ecological environment quality factor analysis method and device, storage medium and processor',
#  'non-metallic ore superfine grinding high-end intelligent production line',
#  'tailing dam loading test method under influence of lenticular body',
#  'liquid level adjusting device of flotation machine',
#  'agricultural water early warning method and device, electronic equipment and storage medium',
#  'production cost control method and system, storage medium and equipment',
#  'lithium-rich brine spatial distribution prediction method and system and electronic equipment',
#  'strip mine driverless single-marshalling transportation hardware-in-the-loop simulation test system and method',
#  'natural language understanding model with context resolver',
#  'blast furnace material change control method and device and computer readable storage medium',
#  'natural language understanding model with context resolver',
#  'gravel crushing device with screening mechanism',
#  'user portrait construction method and device oriented to poverty prevention early warning, and storage medium',
#  'screening device facilitating mineral crushing',
#  'efficient environment-friendly ore finish machining production line',
#  'service processing method and device, electronic equipment and readable storage medium',
#  'pressurized multi-channel column leaching test device and test method thereof',
#  'renewable/sustainable energy harvesting and monetization ecosystem',
#  'gravity feeding device of antimony ore crusher',
#  'automatic machine learning and training method and device and storage medium',
#  'perception-based driverless transport vehicle pointed parking method',
#  'interpretive conclusion report generation method, device and equipment and storage medium',
#  'implicit video recommendation algorithm',
#  'horizontal shaft vibration protection device of gyratory crusher',
#  'truck fuel consumption prediction method, system and equipment and storage medium',
#  'enhanced material detection by stereo beam profile analysis',
#  'commercial vehicle demand prediction method and device, equipment and storage medium',
#  'flocculant automatic dosing treatment system',
#  'online ore pulp solid sample cake sample preparation device',
#  'graph database optimization method and device, electronic equipment and storage medium',
#  'ore crusher equipment operation state monitoring method',
#  'dust-free ore crusher',
#  'knowledge extraction method of medical cognition intelligent scientific research platform',
#  'transcritical co2 pulverization',
#  'hydrate and shallow gas combined exploitation physical simulation experiment device and method',
#  'abnormal behavior detection method and device, equipment and storage medium',
#  'ore ecological restoration greening auxiliary device',
#  'warp engine powered by gravitional waves',
#  'whole-process consultation knowledge integrated management system and method',
#  'geological environment treatment monitoring system',
#  'anti-collision method and device, storage medium and electronic equipment',
#  'text matching method and device, storage medium and computer equipment',
#  'financial factor generation method, electronic device and computer readable storage medium',
#  'map knowledge service construction method, device and system',
#  'ore grinding granularity automatic detection device',
#  'terrain detection vehicle',
#  'automatic table ore belt identification and receiving method and device',
#  'xrt equipment auditing system and method of using same',
#  'man-machine loop method, device and system, electronic equipment and storage medium',
#  'high-temperature softening material grinding method and device with temperature control function',
#  'intelligent ore crushing device with automatic adjusting function',
#  'fracture density model system, methods, and apparatuses',
#  'mineral mill subcritical rotating speed judgment method',
#  'anomaly event detection using frequent patterns',
#  'intelligent construction site informatization management method',
#  'supervision object employment post intelligent matching method, device and equipment and storage medium',
#  'clothing manuscript generation method and device, electronic equipment and storage medium',
#  'rail type mineral separation system',
#  'intelligent ore discharge control device',
#  'full-process safe operation threat discovery system and method',
#  'building stone ore tailing pond resource recovery system',
#  'automatic control device of mine crusher',
#  'strip mine forklift walking planning method and system oriented to simulated ore blending',
#  'automatic ore washing assembly line',
#  'voice playing method and computer equipment',
#  'multi-host link hotspot analysis method and system, computer equipment and storage medium',
#  'mill detection method, device and equipment',
#  'excavator operation range setting method, terminal equipment and readable storage medium',
#  'three-dimensional space coordinate conversion method, storage medium and computing device',
#  'knowledge graph display method and device, computer device and readable storage medium',
#  'uranium concentration main control factor diagnosis method, device and equipment and readable storage medium',
#  'report generation and management method and apparatus, computer device, and storage medium',
#  'federal learning-based model construction method and device, and storage medium',
#  'battery energy storage distributed calculation control system and control method',
#  'abnormal analysis method and device and storage medium',
#  'drilling anchoring type asteroid mineral collection and cross-domain transportation system and method',
#  'wear-resistant steel plate impact test evaluation processing method and system',
#  'intelligent agent map analysis method and system and readable storage medium',
#  'cognitive assistant with recommendation capability',
#  'mobile phone number abnormity identification method and device, equipment and storage medium',
#  'mine earthquake positioning method and device and storage medium',
#  'comprehensive raw material warehouse conveying and storing equipment',
#  'corpus text processing method and device, computer equipment and storage medium',
#  'glass raw material crushing device',
#  'electromagnetic ore processing method and implementation device thereof',
#  'crushed ore sample holder with annular pressure and ore sample column leaching pretreatment method',
#  'tunnel advanced geology forecasting method and system and storage medium',
#  'detection and recovery of metals from ore',
#  'automatic sampling device',
#  'ore pulp granularity online detection equipment and method and storage medium',
#  'sparse phase unwrapping',
#  'flotation pulp temperature detection automatic control system',
#  'automated retail store and system',
#  'ore sand drying treatment equipment',
#  'bluetooth communication identity recognition method and system, computer and storage medium',
#  'customer manager recommendation method and device, electronic equipment and storage medium',
#  'structure-controlled hydrothermal deposit hidden ore body space skew determination and deep prospecting target determination method',
#  'plateau alpine surface mine blasting construction safety evaluation method',
#  'filling material proportioning scheme generation method and device',
#  'income evaluation method and device of echelon utilization battery energy storage system',
#  'oil sands tailings liability, existance reduction (ostler)',
#  'raw material bin blockage monitoring method and device',
#  'task sequence generation method and device, equipment and storage medium',
#  'multi-source language front-end science and technology knowledge graph construction method and system and storage medium',
#  'knowledge graph construction method and device, electronic equipment and storage medium thereof',
#  'cross-modal fusion disease analysis system and device, and storage medium',
#  'heavy breaking hammer with improved structure',
#  'mineral processing equipment',
#  'petroleum layering oil extraction method',
#  'quality detection method and device of test tool, computing equipment and storage medium',
#  'user screening method and device and computer readable storage medium',
#  'deep sea digging tooth rock breaking robot',
#  'ball mill load measuring method and device, electronic equipment and medium',
#  'target complaint party identification method and device, equipment and storage medium',
#  'deep geothermal resource exploration method',
#  'explosion-proof ore separation equipment with ray emission mechanism',
#  'deep sea digging tooth rock breaking robot',
#  'product knowledge aggregation method and device, computer equipment and storage medium',
#  'abnormal behavior vehicle identification system',
#  'anhydrous lithium hydroxide production device',
#  'construction method and device of tailing heap liquefaction prediction model',
#  'underground parking lot entrance and exit excavation method and device and electronic equipment',
#  'ore image acquisition device',
#  'commodity recommendation method and device, robot, electronic equipment and storage medium',
#  'macroeconomic indicator public opinion database',
#  'mine high and narrow draw shaft ore storage bin material level depth detection system and method',
#  'operation scheduling system of unmanned mine card',
#  'water body pollution detection method, device and equipment and storage medium',
#  'tail section analysis-based drum strength intelligent identification method',
#  'mine high and narrow draw shaft ore storage bin material level depth detection system',
#  'anti-blocking continuous feeding type vertical mill capable of sensing and self-cleaning',
#  'green channel vehicle checking method and system, medium and electronic equipment',
#  'deep high-temperature rheological deposit tailing filling body pore water pressure simulation method and application thereof',
#  'automatic mineral product sample preparation system with self-protection function and implementation method',
#  'special-shaped rock particle specific surface area estimation method, system and equipment',
#  'mine ground solid waste material semi-underground distributed storage and unloading system',
#  'bottom layer driving controller of remotely-driven underground carry-scraper',
#  'potential risk object identification method and device, terminal equipment and storage medium',
#  'hypertension risk prediction method and system, electronic equipment and storage medium',
#  'metallurgy flotation pulp temperature control device',
#  'high-concentration tailing rheology and flow characteristic testing system and use method thereof',
#  'sstability determination method and device of rock drilling chamber, and computer readable storage medium',
#  'service strategy generation method and device, computer equipment and storage medium',
#  'user number portability judgment system',
#  'beneficiation lime emulsifying and automatic feeding and discharging device',
#  'near-field binaural rendering',
#  'image reconstruction using tracer and various parameters',
#  'collection and application of roadway profile map',
#  'traffic capacity carrying intention identification method',
#  'psychological state knowledge base construction method and device, computer equipment and storage medium',
#  'heavy carrier rocket launching support equipment remote state monitoring system',
#  'knowledge extraction method and device and storage medium',
#  'unmanned mine car dispatching system and method',
#  'asset management',
#  'voice feature extraction method and device, electronic equipment and storage medium',
#  'alarm association method, device and equipment and computer storage medium',
#  'task planning method and device, electronic equipment, storage medium and program product',
#  'large-scale new energy and direct current multi-infeed power grid operation situation sensing method',
#  'expanded and expandable granular materials',
#  'map service publishing method and device, terminal equipment and readable storage medium',
#  'tailing pond dam break model device capable of simulating different dam break modes',
#  'edem-based mine ball mill working parameter optimization method',
#  'equipment, method & computer program product',
#  'energy-intensive and greenhouse system',
#  'endless rope transportation monitoring system',
#  'geothermal reservoir multi-field coupling numerical simulation method',
#  'goaf settlement monitoring method and device, electronic equipment and storage medium',
#  'integrated circuit fault recording system',
#  'hard disk sub-health detection method and device, electronic equipment and computer readable medium',
#  'robust useful and general task-oriented virtual assistants',
#  'lead-zinc slag pellet raw material preparation system',
#  'model training method and device, equipment and storage medium',
#  'special suspension-type tracked underwater robot adaptable to ultra-soft geological conditions',
#  'screening method and device of insurance fraud suspected object, storage medium and electronic device',
#  'deep document processing with self-supervised learning',
#  'supervised sae-based tail gas hydrogen sulfide concentration real-time monitoring method',
#  'medical insurance fraud behavior identification method and device, storage medium and electronic device',
#  'sandstone ore bed pre-dredging experiment device',
#  'sandstone ore bed pre-dredging experimental device and experimental method',
#  'marketing strategy generation method and device, terminal equipment and storage medium',
#  'hydraulic support top beam posture detection system',
#  'deep learning-based medical image hierarchical classification method and device, storage medium and terminal',
#  'anchor-shaped sampler of small flotation machine',
#  'coalbed methane well fine pressure regulating and gas controlling system',
#  'directional label determination method and device, computing equipment and storage medium',
#  'continuous causal effect estimation method and device, equipment and storage medium',
#  'traffic proxy method and device, computer equipment and storage medium',
#  'production filter capable of controlling water content of fine iron powder',
#  'energy management system',
#  'power and axial pressure control device of semi-autogenous mill',
#  'substation equipment operation state monitoring method, system and equipment and storage medium',
#  'distributing device and mineral aggregate supply system',
#  'in-situ leaching sidetrack windowing secondary development seepage field reconstruction method',
#  'page resource loading method and terminal',
#  'vehicle accessory arrangement',
#  'magnaporthe oryzae infected rice key srna recognition system and recognition method',
#  'object detection model processing method and device, equipment and storage medium',
#  'mine communication method, device, equipment and system and storage medium',
#  'knowledge service prediction method and device, equipment and storage medium',
#  'fully-mechanized face goaf internal temperature measurement optical cable laying structure and method',
#  'novel tunnel monitoring, measuring and observing mark',
#  'crawler belt remote control type breaking hammer vehicle',
#  'manganese ore drying machine',
#  'limit unfreezing threshold dynamic adjustment method and device, equipment and storage medium',
#  'hospital emergency treatment space layout optimization method and device, computer equipment and storage medium',
#  'knowledge generation method, knowledge generation device, equipment and storage medium',
#  'tailing settling-dehydrating-curing device and experimental method thereof',
#  'device and method to generate and apply gravito-magnetic energy',
#  'potential user prediction method and system, electronic equipment and storage medium',
#  'energy interconnection energy storage and distribution method and system',
#  'safety control system and method',
#  'tailing workshop traditional thickener automatic control system',
#  'tailing workshop traditional thickener automatic control system and method',
#  'industrial head up display',
#  'sample image enhancement method and system, electronic equipment and readable storage medium',
#  'well testing analysis method, device and system considering inter-well interference and storage medium',
#  'anomaly event detection',
#  'service control method and device of roadside equipment, electronic equipment and storage medium',
#  'image-text matching model training method and device, equipment and storage medium',
#  'platform state monitoring method and device, electronic equipment and storage medium',
#  'mobile roadway full-section monitoring method',
#  'magnetic separation process optimization control method and device, computer equipment and storage medium',
#  'bitcoin flow detection method and device of ipv6 network, equipment and medium',
#  'user recall method and device, electronic equipment, storage medium and product',
#  'bidding object review method, electronic equipment and storage medium',
#  'voice item monitoring and supervising method and system and storage medium',
#  'mass structured data-oriented knowledge graph parallel construction method',
#  'multi-middle-section ore removal counting system',
#  'metadata blood relationship analysis method, system and equipment and storage medium',
#  'interactive chemical material interface',
#  'energy storage battery health degree evaluation method, system and device and storage medium',
#  'intellectual property case analysis method and device, computer equipment and storage medium',
#  'enterprise-level audit knowledge graph construction method',
#  'high-performance wave recording master station architecture',
#  'games, lotteries, and sweepstakes and tickets, systems, technologies, and methods related thereto',
#  'tunnel boring machine operating arrangement and method',
#  'recovery of memory from asynchronous power loss',
#  'high-voltage cable composite state evaluation method and system, storage medium and equipment',
#  'untrusted customer identification method, device and equipment and storage medium',
#  'social media healthcare analytics',
#  'fraud risk identification method, system and device and storage medium',
#  'text annotation method and apparatus, electronic device, and readable storage medium',
#  'disease code conversion method and system, electronic equipment, and storage medium',
#  'car insurance fraud identification method and device and storage medium',
#  'financial industry general service authorization system',
#  'method of improving log processing system architecture',
#  'exploration potential evaluation method and device and readable storage medium',
#  'fault delimiting and positioning method, equipment and storage device',
#  'oil-gas-water three-phase multiphase pump test system',
#  'polymerisable oligomeric liquid crystal, polymerisable medium and polymerised liquid crystal film',
#  'fraud risk identification method and device, storage medium and electronic equipment',
#  'roadside equipment monitoring method and device, electronic equipment and storage medium',
#  'abnormity detection method and device, electronic device and storage medium',
#  'track feature extraction method and device, storage medium and terminal',
#  'user account automatic identification method and device, computer equipment and storage medium',
#  'traffic control scene determination method and device, electronic equipment and storage medium',
#  'task sequence discovery method and device and storage medium',
#  'vulnerability testing method and device, electronic device and computer equipment',
#  'product matching method and device, computer equipment and storage medium',
#  'oxygen sensor',
#  'index generation method, electronic equipment and storage medium',
#  'rpa process representation method, system and device and storage medium',
#  'mineral product result prediction method and device, computer equipment and storage medium',
#  'sparse phase unwrapping',
#  'aluminum oxide ball mill monitoring method and system',
#  'radar antenna scanning period measuring and calculating method, device and equipment and storage medium',
#  'poi processing method and device, electronic equipment and storage medium',
#  'article flow direction judgment method and device, computer equipment and storage medium',
#  'channel packet delivery cheating monitoring method and device and network live broadcast system',
#  'setting method, device and equipment of elevator frequency converter and storage medium',
#  'home decoration company risk identification method and device, terminal and storage medium',
#  'bidding and tendering life cycle association method and system, storage medium and computer equipment',
#  'ore body three-dimensional modeling method and device and computer storage medium',
#  'wireless laser methane sensor',
#  'cracking zone height prediction method and device, storage medium and electronic equipment',
#  'shovel loading transportation equipment',
# ...
#  'measurement and control of bitumen-containing process streams',
#  'person re-identification method of integrating global features and ladder-shaped local features and device thereof',
#  'parking prediction',
#  'building operation energy consumption abnormity identification method and system, and computer readable storage medium',
#  'traffic flow sensing method and device, computer storage medium and electronic equipment',
#  'associated disease category analysis method and device, equipment and storage medium',
#  'pure electric underground mine transporting dumper',
#  'evaluation and/or adaptation of industrial and/or technical process models',
#  'evaluation and/or adaptation of industrial and/or technical process models',
#  'drilling natural gas hydrate monitoring secondary generation experimental device and method',
#  'position determination method and device, server and readable storage medium',
#  'sintering cost daily accounting method and system, storage medium and terminal',
#  'target object clustering method and device, electronic equipment and readable storage medium',
#  'pollution possibility assessment method and device, computer equipment and storage medium',
#  'road generation method and device, equipment and storage medium',
#  'varied depth determination using stereo vision and phase detection auto focus (pdaf)',
#  'novel mineral micro powder conveying device',
#  'network attack type prediction method and device and storage medium',
#  'underground multi-pipe transportation type pipeline installation robot',
#  'goods turnover mode visualization method oriented to digital storage',
#  'distributed storage device',
#  'arbitrarily tailorable electrochromic device and use thereof',
#  'charging system of belt conveyor inspection robots and using method of charging system',
#  'material pressing mechanism, ore powder pretreatment device and fluorescent rock debris detection system',
#  'indoor automatic ore drawing experiment simulation system and method',
#  'energy storage configuration scheme optimization method and optimization platform of energy storage system',
#  'user processing method and device, electronic equipment and storage medium',
#  'rule generation method and device, electronic equipment and storage medium',
#  'intelligent label operation system and method',
#  'care instrument',
#  'aerial reconnaissance missile',
#  'pedestrian and vehicle interaction scene extraction method and system and readable storage medium',
#  'in-transit queue dynamic adjustment method and device, and electronic equipment',
#  'regional governance strategy generation method and device, computer equipment and storage medium',
#  'ore pulp ph value detection method and device and computer readable storage medium',
#  'interaction method and device, electronic equipment and computer readable storage medium',
#  'warehouse logistics transfer method',
#  'remotely-controlled electric shovel tail wire cable winding and unwinding vehicle',
#  'hidden keyword extraction method, terminal equipment and storage medium',
#  'e-book similarity calculation method, electronic equipment and storage medium',
#  'icu electronic medical record knowledge graph construction method and system and storage medium',
#  'tracking and spatial location system of magnetic sensors and tracking and location method',
#  'medical image processing device, medical image processing method, and storage medium',
#  'non-contact deep sea polymetallic nodule conveying system and working method thereof',
#  'filling material and preparation method thereof',
#  'automatic swing type stirring ball mill',
#  'treatment method of coking wastewater sludge',
#  'large-stroke belt self-moving tail',
#  'mine monitoring and emergency alarm system and method',
#  'methane oxidation catalyst and method of using same',
#  'mine logistics management and control method and device, electronic equipment and storage medium',
#  'online delivery of law-related content, educational and entertainment-related content',
#  'image processing device, image capturing device, image processing method, and storage medium',
#  'iron ore iron content rapid detection device',
#  'microwave exploitation natural gas hydrate simulation device',
#  'electronic map construction method and device, and storage medium',
#  'rolling bearing fault diagnosis method, device and apparatus and storage medium',
#  'operation and maintenance method and device of cold source equipment, computing equipment and storage medium',
#  'hybrid heterogeneous model training method, device and equipment and readable storage medium',
#  'oled jet printing droplet quality estimation method and device, storage medium and terminal',
#  'windmill',
#  'refractory image determination method and device, electronic equipment and storage medium',
#  'thermal power plant safety accident analysis method, system and equipment and storage medium',
#  'message sending method, device and equipment and computer readable storage medium',
#  'commodity recommendation method and system, terminal and computer readable storage medium',
#  'anti-interference wireless detonator with small antenna',
#  'comprehensive energy efficiency service mixed recommendation method and system and storage medium',
#  'ore storage bin discharging blocking detection device',
#  'visual roof separation monitoring system and method',
#  'slurry pressure pipeline leakage test device and use method',
#  'disease risk assessment method and device, storage medium and electronic equipment',
#  'od passenger flow prediction method, device and equipment and readable storage medium',
#  'overlying strata damage height determination method and device, electronic equipment and storage medium',
#  'energy-saving rock drilling carriage air compressor heat dissipation control system',
#  'automatic spray-seeding mechanism of mine restoration greening machine',
#  'mine truck energy management method and device, mine truck and storage medium',
#  'ore pulp ph value detection method and device and computer readable storage medium',
#  'gas field water pipeline anti-corrosion process considering desulfurization treatment',
#  'aggregate mine automatic production scheduling method, module, system, electronic equipment and storage medium',
#  'ore deposit hydrogeological exploration device',
#  'intelligent explosion-proof diesel engine monorail hoist',
#  'intelligent explosion-proof diesel engine monorail hoist',
#  'fp-growth optimization algorithm, storage medium and electronic device',
#  'crowd emergency evacuation method and system, terminal and storage medium',
#  'dynamic goods allocation method and system, electronic equipment and computer readable storage medium',
#  'granger causality discovery method and device and storage device',
#  'uniform blanking structure and method applied to iron ore production',
#  'belt type conveying line multi-mining-plane operation scheduling system and scheduling method',
#  'fuel vehicle tail gas simulation generation device',
#  'programmable therapeutic agent delivery from eye mounted device',
#  'enterprise portrait generation method, computer equipment and computer readable storage medium',
#  'background perception tracking method, computer readable storage medium and computer equipment',
#  'emergency department communication system',
#  'breast tomosynthesis with display of highlighted suspected calcifications',
#  'device independent encrypted content access system',
#  'transport vehicle in-transit queuing control method and device and electronic equipment',
#  'sectional dump leaching test stock column',
#  'multi-task model generation method and device, computer equipment and storage medium',
#  'unmanned mine transporting locomotive',
#  'user load peak and valley period division method, device and equipment and readable storage medium',
#  'insurance probability determination method and device, storage medium and electronic equipment',
#  'water treatment system and method',
#  'asset level prediction method and device, computer equipment and storage medium',
#  'education technology management system',
#  'cement ore discharging and dust collecting system',
#  'intellectual property operation management system and method and storage medium',
#  'conversational query answering system',
#  'novel high-efficiency concentrating machine with high automation degree',
#  'plan modeling and user feedback',
#  'content discovery systems and methods',
#  'rapid switch over-current protection device',
#  'credibility determination method and device, equipment and storage medium',
#  'screening method of power battery pack characteristic monomers',
#  'user demand matching method and device, electronic equipment and storage medium',
#  'flow and pressure control device',
#  'explosive amount determination method and device, terminal equipment and storage medium',
#  'intelligent storage yard unloading management method and system',
#  'device and method capable of improving ability of casing pipe to resist shear dislocation between surrounding rock stratums',
#  'flow and pressure control device',
#  'high-strength rock mass in-situ low-energy-consumption rock crushing excavation robot and excavation method',
#  'kernel-level security agent',
#  'module-based energy systems having converter-source modules and methods related thereto',
#  'energy storage battery fault classification feature screening and dimension reduction method under affinity propagation clustering',
#  'reservoir level time sequence prediction method and system',
#  'mine water reinjection simulation experiment device',
#  'sectional dump leaching test stock column',
#  'slurry cascade hydraulic transport',
#  'shuttle car braking system, braking method and shuttle car with braking system',
#  'industrial control asset management method, device and equipment and storage medium',
#  'mine car derailment monitoring control structure',
#  'document processing method and device, computer program product and readable storage medium',
#  'under-mine paint spraying apparatus and under-mine paint spraying method',
#  'self-fit hearing instruments with self-reported measures of hearing loss and listening',
#  'strip mine ecological restoration system and supply power calculation method',
#  'integrated end-to-end travel instrument (ti) device generation system and integrated travel instrument device',
#  'tailing pulp quantity measuring device with high measuring precision',
#  'application prediction method, electronic equipment and storage medium',
#  'target object recognition method and device, electronic equipment and storage medium',
#  'crawler-type multi-degree-of-freedom submarine pick-up robot',
#  'sintered ore cooling test device and method',
#  'sandstone uranium mine permeability testing device',
#  'image recognition method and apparatus, and device and readable storage medium',
#  'ore sampling device',
#  'visual question and answer method and device and storage medium',
#  'model generation method and system, computer equipment and storage medium',
#  'log-based system anomaly detection method and device and storage medium',
#  'microseismic detection signal front-end processing system',
#  'linear time friend recommendation method and system, terminal and storage medium',
#  'purchase source searching management method, system and device and storage medium',
#  'artificial false roof facility by lower drift filling method and construction method',
#  'sintered ore lime powder sampling device',
#  'self-adaptive efficient low-disturbance polymetallic nodule collecting device',
#  'underground communication cable directional conveying robot',
#  'heat supply management platform customer feedback automatic identification method and device and storage medium',
#  'text processing method and device, storage medium and equipment',
#  'autonomous loading vehicle controller',
#  'embedded electromagnetic multi-vertical-ring high-gradient magnetic separator',
#  'embedded electromagnetic multi-vertical-ring high-gradient magnetic separator',
#  'fever disease multi-mode feature fusion cognitive system, equipment, and storage medium',
#  'product analysis method and device, electronic equipment and readable storage medium',
#  'chart switching method and device, storage medium and electronic equipment',
#  'overdue risk assessment method, device and equipment and readable storage medium',
#  'event log simplification method and device, equipment and storage medium',
#  'song menu multi-label recommendation method, system and device and storage medium',
#  'water quality monitoring and water depth measuring system and monitoring method thereof',
#  'natural gas hydrate exploitation system',
#  'dynamically configurable network architecture and methods',
#  'ore dump leaching tailing sampling device',
#  'dual-mode radio dock',
#  'self-supervised human body posture conversion method and system and readable storage medium',
#  'automatic control method and device of digging and anchoring all-in-one machine, electronic equipment and storage medium',
#  'power transformation main equipment knowledge joint extraction method fusing albert and entity segmentation algorithm, storage medium, electronic equipment and application',
#  'risk control method and device, computer equipment and computer readable storage medium',
#  'alga crust nutrient regulation simulation device',
#  'automatic tailing slurry mixing device',
#  'intelligent mine transport vehicle with positioning scheduling function',
#  'green mine environment monitoring equipment',
#  'falling type deep-cone thickener material level measuring device and deep-cone thickener',
#  'monorail crane track inspection robot',
#  'mine hoist applying rotating speed sensor',
#  'industrial machine containing hydraulic sensor and its operation method',
#  'automatic control system of endless rope continuous tractor',
#  'well completion pipe string of ultra-deep horizontal well borehole',
#  'transporting device position determining apparatus and method',
#  'power fee urging strategy design method and system and storage medium',
#  'traditional chinese medicine decoction piece recommendation method, system and equipment and storage medium',
#  'crowd expansion method, crowd expansion device, electronic equipment and readable storage medium',
#  'three-wheeled electric vehicle',
#  'deep sea crawler belt viscosity removing system and method with functions of carbon dioxide refrigeration and carbon sequestration',
#  'ore grinding and grading equipment with adjusting function',
#  'methane sensor calibration device',
#  'unmanned mine truck tire pressure monitoring alarm device',
#  'footrill out-of-mine car alarm device',
#  'shaftless screw conveyor',
#  'high-voltage electric pulse device with thunder and lightning test effect',
#  'sampling drill rod of automobile concentrate powder sampling robot',
#  'ball mill sound detection sensor',
#  'gold mine exploration sampling device',
#  'mine car roadway safety transportation alarm device',
#  'monorail crane lifting beam device and lifting method thereof',
#  'automatic shovel loading device, carry-scraper and shovel loading method',
#  'electromagnetic ore crusher',
#  'mine goaf and air inlet roadway cooling spontaneous combustion preventing device',
#  'portable mine gas sensor verification device',
#  'stepping type feeding device of mine monorail crane track mounting vehicle',
#  'ore grinding pump box component device with accurate component',
#  'traction position indicating device of endless rope continuous traction winch',
#  'iron ore total tailing curing agent strength detection device',
#  'novel falling ball testing machine',
#  'roof cutting entry retaining gangue blocking side stress analysis method',
#  'multi-phasic modularised shrimp production system and method',
#  'four-point type top plate displacement sensor',
#  'intelligent dialogue interaction method and device, storage medium, and electronic equipment',
#  'cage wireless charging device',
#  'dry-type automatic ash removal device',
#  'cooling system and battery scraper',
#  'surface double-sided reflection imaging and ray imaging combined sorting equipment capable of discharging dust',
#  'heavy metal recycling machine',
#  ...]

# %%
descartados_fuzzy_con_stopwords = obtiene_descartados(filtro_fuzzy, data_target)

# %%
print(len(filtro_fuzzy))
print(len(descartados_fuzzy_con_stopwords))
# Out:
# 1022
# 2170

# %%
len(filtro_fuzzy) + len(descartados_fuzzy_con_stopwords) == data_target['title'].shape[0]
# Out:
# True

# %% [markdown]
# ---
# **Observación**
#
# ---
#
# La técnica fuzzy considerando un umbral de 90% y tomando las stopwords logra descatar 2170 registos dejando 1022.

# %%
# Obtiene los filtrados
data_filtrados_fuzzy_sw = data_target[~data_target['title'].isin(descartados_fuzzy_con_stopwords)]
data_filtrados_fuzzy_sw
# Out:
#                                                   title  \
# 7                          industrial robotic platforms
# 8                                        monitoring ore
# 10                             mineral recovery control
# 11    low cost, size, weight, and power (cswap) geol...
# 14      user generated tag collection system and method
# ...                                                 ...
# 3174  temperature-pressure controllable paste slurry...
# 3175  bcma monoclonal antibody and the antibody-drug...
# 3184              apparatus and method of communication
# 3185  natural gas hydrate automatic microwave stirri...
# 3191  retrofit cover plate and assembly to adapt alt...
#
#                                                abstract publication_date
# 7     Industrial robotic platforms are described. Th...       2024-06-11
# 8     Systems and methods for estimating the magnitu...       2020-03-12
# 10    A mineral recovery system for use in a mining ...       2024-01-16
# 11    Aspects of the disclosure relate to a method f...       2023-12-21
# 14    In some embodiments, an input document is rece...       2021-09-09
# ...                                                 ...              ...
# 3174  The invention provides a temperature-pressure ...       2022-09-09
# 3175  Provided is an antibody and an antibody-drug c...       2023-05-11
# 3184  An apparatus and a method of communication are...       2022-01-13
# 3185  The invention relates to a natural gas hydrate...       2020-10-23
# 3191  A multi-functional retrofit cover plate assemb...       2022-06-23
#
# [1022 rows x 3 columns]

# %%
# Obtiene los descartados
data_descartados_fuzzy_sw = data_target[data_target['title'].isin(descartados_fuzzy_con_stopwords)]
data_descartados_fuzzy_sw
# Out:
#                                                   title  \
# 0     method for operating a comminution circuit and...
# 1     process for integrating the mining and process...
# 2     system and method for continuous optimization ...
# 3     method for water and moisture management for a...
# 4     method for training a quality prediction model...
# ...                                                 ...
# 3186  adaptive control of longitudinal roll in syste...
# 3187  systems, methods, and program products for fac...
# 3188  method and system for managing vehicle transpo...
# 3189  method for providing clock frequencies for com...
# 3190  wall panels and other components for custom en...
#
#                                                abstract publication_date
# 0     A method for operating an ore comminution circ...       2020-09-03
# 1     The present invention belongs to the mining se...       2023-08-10
# 2     A method for continuously optimizing an ore gr...       2023-12-21
# 3     Wet conditions pose a plurality of hazards for...       2024-03-14
# 4     A method (1000, 1001) for training a quality p...       2022-09-22
# ...                                                 ...              ...
# 3186  FIELD: mining.SUBSTANCE: invention relates to ...       2021-09-08
# 3187  Machine learning systems and methods are descr...       2023-06-13
# 3188  CA 03091162 2020-08-13 (12) INTERNATIONAL APPL...       2021-11-16
# 3189  The present disclosure relates to a method for...       2023-04-20
# 3190  Custom enclosures are made using various types...       2023-08-03
#
# [2170 rows x 3 columns]

# %% [markdown]
# ### Experimento DESCARTANDO las stopwords

# %%
# Vuelve a seleecionar los datos para asegurar
data_target = data[['title', 'abstract', 'publication_date']]
data_target['title'] = data_target['title'].apply(convierte_a_minusculas)
data_target['title'] = data_target['title'].apply(preprocesar_texto)
# Out:
# <ipython-input-125-0c1e2dc7e44e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_target['title'] = data_target['title'].apply(convierte_a_minusculas)
# <ipython-input-125-0c1e2dc7e44e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_target['title'] = data_target['title'].apply(preprocesar_texto)

# %%
# Probando con varios umbrales
for limite in range(1,10):
  print(f"Con threshold {limite*10} quedan {len([title for title in data_target['title'] if not contains_fuzzy_match(title, excluyentes, threshold=limite*10)])} registros")

# %%
filtro_fuzzy_sin_stopwords = [title for title in data_target['title'] if not contains_fuzzy_match(title, excluyentes, threshold=90)]
filtro_fuzzy_sin_stopwords
# Out:
# ['method operating comminution circuit respective comminution circuit',
#  'system method continuous optimization mineral processing operations',
#  'method training quality prediction model processing device continuous industrial process, method controlling continuous industrial process comprising processing device, processing device',
#  'computer-implemented methods referring industrial process manufacturing product system performing said methods',
#  'method optimizing mineral recovery process',
#  'industrial robotic platforms',
#  'monitoring ore',
#  'real-time monitoring estimation system wear rubber liners lifter bars utilized ore grinding mills',
#  'mineral recovery control',
#  'low cost, size, weight, power (cswap) geolocation capability utilizing signal characteristics passed backhaul network',
#  'system carrying cross-protocol communication iot (internet things) devices',
#  'user generated tag collection system method',
#  'method arrangement controlling comminution process grinding circuit',
#  'optimal energy storage utilization',
#  'method device positioning internet things devices',
#  'method system resilient hydrogen production',
#  'modular system method beneficiating ferrous ore',
#  'smart city disorderly-stacked material management system method',
#  'virtual simulation practical training system detection control ore grinding grading system dressing plant',
#  'pump machine unit optimized operation regulation system method based digital twin',
#  'computer security based artificial intelligence',
#  'underground mine energy management system',
#  'ore component analysis device method',
#  'automated updating geological model boundaries improved ore extraction',
#  'artificial intelligence techniques improving efficiency',
#  'artificial intelligence techniques improving efficiency',
#  'spectral imaging material characterization control systems methods processing earthen materials',
#  'systems methods deriving leading indicators economic activity using predictive analytics',
#  'digital twin systems methods transportation systems',
#  'digital twin systems methods transportation systems',
#  'mineral recovery control',
#  'method system extracting gold without chemicals',
#  'fluidized-bed flotation unit, mineral processing apparatus, fluidized-bed flotation method',
#  'multi-scene applicable smart energy management system based edge calculation',
#  'system method changing liners, configuration allows automated removal insertion liners mill used ore grinding',
#  'everything interconnection training platform control method device',
#  'coarse particle flotation equipment method based coupled fluidization cyclone damping',
#  'method improved drilling blasting open cut mines',
#  'method predicting ore crushing effect based ore fracture energy discrete element method',
#  'beneficiation method ore blending',
#  'system, apparatus, method making prediction regarding passage system',
#  'method system constructing digital mine three-dimensional twinborn model',
#  'safety interlock recommendation system',
#  'smart city smart drone uass/uav/vtol smart mailbox landing pad',
#  'smart city smart drone uass/uav/vtol smart mailbox landing pad',
#  'augmented photo capture',
#  'system method promoting safe interaction electrical equipment',
#  'three-dimensional virtual simulation automatic design method ore crushing grinding processes',
#  'method full resource utilization graphite ores',
#  'method predicting granularity ore grinding product based ore grinding dynamics principle',
#  'adaptive discovery mixed-variable optimization next generation synthesizable microelectronic materials',
#  'offloaded sensor authentication internet things',
#  'optimization system optimization method',
#  'system method determining estimated remaining mineral stockpile',
#  'systems methods assessing extractability prospective helium-natural gas sources',
#  'spacecraft assembly process management control method system based digital twinning',
#  'beneficiation process efficiently recovering iron rare earth bayan obo medium-lean oxidized heaped ore',
#  'method utilizing graphite ore resources',
#  'simulation system ore grinding classification process',
#  'maximise value sulphide ore resource sequential waste rejection',
#  'team-based tele-diagnostics blockchain-enabled system',
#  'urban health index prediction system, prediction analysis method storage medium thereof',
#  'determining ore characteristics',
#  'methods systems batch delivery material continuous material processor',
#  'ore grinding-weak strong magnetic separation-reverse flotation process method refractory iron ore tailings',
#  'method improving strip mine unmanned mine truck dynamic path planning',
#  'modeling method device gold ore feeding process, storage medium computer equipment',
#  'semi-autogenous mill operation state optimization method based digital twinning',
#  'method system space design',
#  'document digitization, transformation validation',
#  'method system monitoring predicting performance gyratory crusher based digital twinning',
#  'system method detecting friction websites',
#  'method system predicting metallurgical performance sintered ore, electronic equipment storage medium',
#  'grinding media, system method optimising comminution circuit',
#  'method system learning novel relationships among various biological entities',
#  'method monitoring continuous industrial process system performing said method',
#  'ball mill ore discharge granularity control method system based digital twinning technology',
#  'insurance value determination method device, equipment storage medium',
#  'system method determining locations recoverable mineral stockpile',
#  'hybrid reasoning based physics machine learning prognostics systems conflated degradation modes',
#  'strip mine digital twin remote operation maintenance method device storage medium',
#  'predictive customer service environment',
#  'crushing flotation all-in-one machine',
#  'apparatus, system method comminution',
#  'measurement system measurement method',
#  'method system optimizing call distribution among callers improved positive outcome',
#  'flotation ph value prediction method device, electronic equipment storage medium',
#  'systems methods automated document review',
#  'systems methods automated document review',
#  'predicting energy production energy generating assets',
#  'locked-on target based object tracking method portable terminal therefor',
#  'method device grinding screening barite ore',
#  'self-building hierarchically indexed multimedia database',
#  'iron-zinc ore grinding grading automation system',
#  'digital life and/or health claims processing system integrating multiple claim channels, method thereof',
#  'copper ore flotation intelligent soft measurement method system based wireless sensor network',
#  'dense three-dimensional correspondence estimation multi-level metric learning hierarchical matching',
#  'method predicting relative size wear rate lining plate different ore grinding parameters based discrete element method',
#  'ore grading process',
#  'ground surface settlement monitoring method device, electronic equipment storage medium',
#  'ground rail ore transportation rail robot',
#  'blockage cleaning robot secondary crushing lump ores mine draw shaft',
#  'crushing production line based internet things control',
#  'method development complex-structure solid mineral deposits',
#  'blasting system method',
#  'system method intelligent recruitment management',
#  'human-machine dialogue system method',
#  'ore granularity detection method system based autonomous learning deep learning',
#  'smart city security monitoring system',
#  'ore grinding blending method based hard rock grade',
#  'conversion rate prediction method, device equipment storage medium',
#  'computing environment provisioning',
#  'gigabit potential customer prediction method device, computer equipment storage medium',
#  'flotation recovery rate prediction method based ore gene characteristics',
#  'system method determining lift heights stockpile',
#  'processing laterite ores',
#  'transferable hybrid prognostics based fundamental degradation modes',
#  'portable modular gastrointestinal simulator system quantifies bioaccessibility metals sample remotely real time, method',
#  'tailing pond risk monitoring early warning system based internet things',
#  'tailing pond risk monitoring early-warning system based internet things',
#  'pre-selection process lead-zinc raw ore',
#  'binary system gold ore gold-bearing mineral gold content determination method',
#  'risk account identification method device, computer equipment storage medium',
#  'method sorting low-grade complex copper-sulfur ore application',
#  'internet things equipment encryption key acquisition method device, equipment storage medium',
#  'clinical test method, system equipment based digital twinning storage medium',
#  'non-ferrous metal mineral flotation chemical pretreatment method',
#  'flotation reagent adsorption behavior mineral floatability prediction method system storage device',
#  'load-based management nvme tcp connections',
#  'improvements operational state determination modification',
#  'sandstone particle size distribution curve detection method based deep learning',
#  'flotation field parameter detection device',
#  'method system streamlined auditing',
#  'measuring tank fluids remote monitoring system',
#  'human-machine collaborative conversation interaction system method',
#  'method device predicting proportion fine-particle-size ores readable storage medium',
#  'living body detection model training method device, electronic equipment storage medium',
#  'reducing need tailings storage dams mineral flotation',
#  'system method grinding classifying aggregate material',
#  'intelligent ore positioning crushing control method device',
#  'telephone traffic request quantity prediction method device, electronic equipment storage medium',
#  'excitation compatibility consensus method, device equipment decentered ore pool storage medium',
#  'solar modules integrated flexible hybrid electronics',
#  'device method measuring softening melting performances iron ore blast furnace reducing condition',
#  'open source threat intelligence aggregation platform',
#  'energy storage battery internal resistance online calculation method based cloud platform',
#  'concentrate grade optimization engine material processing system',
#  'explainers machine learning classifiers',
#  'automatic lithotripsy method equipment based three-dimensional laser radar camera medium',
#  'power optimization orchestration prioritization machines functions',
#  'crusher ore feeding control method device, electronic equipment storage medium',
#  'device method enhancing biological leaching treating straw acid',
#  'ore dressing multi-production-index optimization decision making system method based cloud mobile terminal',
#  'method of, system for, drilling position relative geological boundary',
#  'ore grindability obtaining method device prediction model',
#  'lightweight multi-path mesh image segmentation method system, electronic equipment',
#  'integrated energy storage management system energy management method',
#  'silver mineral quantification method oxidized silver-containing ore',
#  'automatic control practical training device reagent addition multi-process flotation column separation system',
#  'phosphorite flotation tailing treatment system',
#  'intelligent access control system based internet things',
#  'machine learning based radiology report',
#  'removal amines aqueous streams',
#  'multi-process flotation column separation system reagent adding automatic control practical training device',
#  'inspection task issuing method device, inspection path planning method device storage medium',
#  'mineral flotation separation',
#  'full-closed-loop supervision early warning method system mine sandstone industry',
#  'selection diverse candidate peptides peptide therapeutics',
#  'ore crushing method based binocular stereoscopic visual perception',
#  'intelligent mediation optimization follow-up system method',
#  'screening device primary processing manganese ore',
#  'method apparatus magnetic resonance imaging plaque recognition',
#  'photo album video recognition method, system device storage medium',
#  'method determining grinding granularity ore based ore properties',
#  'automated object detection dusty environment',
#  'smart city management method system based big data, storage medium',
#  'method sampling closed tailing pond valley type metal mine determining re-selection scheme',
#  'ai-based operation maintenance fault determination method device, equipment storage medium',
#  'transporting mined material',
#  'cableway safe operation control system, structure method',
#  'method echelon recycling large-scale absorption copper mine tailings',
#  'method predicting semi-autogenous grinding hard rock crushing effect determining steel ball grading based tavaries crushing model',
#  'smart application system',
#  'prompting method, device equipment readable storage medium',
#  'method estimating disturbances giving recommendations improving process performance',
#  'production control platform determining production source output production destination',
#  'intelligent table ore zone segmentation method based yolov5 improvement',
#  'system, method apparatus planning driving path vehicle',
#  'full-automatic lump ore sample preparation system full-automatic lump ore sample preparation method',
#  'providing virtual control',
#  'damage monitoring online maintenance system metal material structure',
#  'intelligent decision-making method sintering production process',
#  'request identification method apparatus, device, storage medium',
#  'method system predicting risk rollover working machine',
#  'removal amines aqueous streams',
#  'multidimensional privacy control',
#  'systems methods milling system',
#  'multi-process flotation liquid level automatic control practical training device',
#  'digital intelligent mine system',
#  'tailing crushing device production self-heat-preservation foam light building blocks',
#  'selective processing',
#  'automatic ore crushing humidifying equipment',
#  'image processing method system',
#  'artificial intelligence distributed storage system',
#  'ore classification size grading method device based deep learning network',
#  'interactive validation annotated documents',
#  'magnetic microfluidic concentrator, intelligent magnetic microfluidic concentrator, complete set beneficiation equipment using',
#  'full-intelligent sintering fuel granularity control method',
#  'flotation kinetic parameter measurement method, device system storage medium',
#  'leaching agent migration test system leaching agent migration conversion test system',
#  'avoiding prohibited sequences materials processing crusher using predictive analytics',
#  'retrieval system method database based cloud computing management platform',
#  'full-automatic fine ore sample preparation system full-automatic fine ore sample preparation method',
#  'optics structure space applications',
#  'sensor actuator based lifecycle monitoring machines performing automated machine tasks',
#  'ore removal temperature prediction device sintering cooling device',
#  'sludge processing assembly method drying aqueous waste streams',
#  'highway-railway combined transportation volume prediction method, device equipment readable storage medium',
#  'online visual ore pulp detector flotation dosing control',
#  'system recovering micro-fine particle fluorite multi-metal tailings adopting flotation column-flotation machine',
#  'real-time mine car scheduling system method based mine transportation demand prediction',
#  'wild animal monitoring system based edge cloud intelligent architecture',
#  'mechanical automatic ore crushing device',
#  'mill ore feeding amount prediction method based image recognition technology',
#  'copper-molybdenum ore froth flotation segmentation method system',
#  'ore metallic mineral content prediction method based high-voltage electric pulse crushing',
#  'cement production intelligent analysis management platform based internet things',
#  'calculation method system based three-dimensional model storage medium',
#  'method optimizing mineral recovery process',
#  'high-capacity-ratio photovoltaic short-term power prediction method, device equipment storage medium',
#  'method system training virtual agent using optimal utterances',
#  'method system controlling hydrophobic conditions fouling water intensive processes',
#  'security vulnerability test method device, equipment readable storage medium',
#  'method discriminating ore prospecting types based compositional change epidote',
#  'flotation process problem diagnosis method based mla',
#  'feo content prediction method, model training method device, electronic equipment medium',
#  'method system performing intelligent sorting based dynamic adjustment threshold',
#  'system automatic loading / unloading related devices',
#  'high-precision map making method mine unmanned driving scene',
#  'copper smelting slag flotation control method',
#  'tantalum-niobium ore ball mill',
#  'online flotation working condition detection device',
#  'method system controlling hydrophobic conditions fouling water intensive processes',
#  'multi-type ore storage yard reserve dynamic analysis method system, equipment medium',
#  'leaching agent migration test system leaching agent migration conversion test system',
#  'production method lithium carbonate used cathode material lithium-ion batteries buxite ore',
#  'automatic ore dressing monitoring method system',
#  'beneficiation method tin-tungsten-copper-zinc polymetallic ore stage crushing stage waste throwing',
#  'reactive power-saving control system based intelligent internet things',
#  'rare event prediction',
#  'ore grinding optimization treatment system based large model',
#  'method predicting yield concentrate day',
#  'strong magnetic machine current optimization method based feeding parameter intelligent algorithm',
#  'intelligent monitoring device ore pulp foam fullness flotation cell, monitoring method thereof',
#  'method automatic control technological grades ore flow',
#  'geological disaster early warning method device based artificial intelligence storage medium',
#  'expressway charging auditing system',
#  'phosphorite associated fluorine resource storage volume prediction method, device, equipment medium',
#  'matching method device ore grinding control parameters electronic equipment',
#  'penetration test method system network device',
#  'production process equipment ultra-pure fine iron powder',
#  'intelligent mine automatic transportation equipment based internet things',
#  'gravity-assisted dental design',
#  'internet things access authentication identity authentication method device, electronic equipment storage medium',
#  'soft measurement modeling method overflow granularity multi-working-condition ore dressing process',
#  'uninterrupted power supply (ups) discharge identification system method based edge calculation',
#  'metal oxide material reduction means',
#  'machine learning models determining pathogenic genetic variants',
#  'foam flotation iron ore grade prediction method based dynamic low-rank reconstruction',
#  'metal oxide material reduction means',
#  'ore crushing grinding device',
#  'method device controlling single stone crusher, storage medium electronic equipment',
#  'projection constraints enforced database system',
#  'electronic medical record quality control method system, terminal storage medium',
#  'method system predicting power consumption cement raw material grinding system',
#  'privacy control-adjustable commercial vehicle electronic logging device (eld) trip data-sharing system transportation company third-party corporate partner entity',
#  'big data-based edge computing network management method platform',
#  'anti-counterfeiting traceability method device automobile parts, storage medium',
#  'privacy control-adjustable commercial vehicle electronic logging device (eld) trip data-sharing system transportation company third-party corporate partner entity',
#  'integration carbon sequestration selective hydrometallurgical recovery metal values',
#  'ore detection method, server, terminal system',
#  'auxiliary ore transportation system transportation control method',
#  'coastal nuclear power station cold source disaster-causing object alarm early warning intelligent system',
#  'analytics system evaluating readiness autonomous vehicles',
#  'device realizing closed-loop continuous flotation single-tank flotation machine',
#  'systems methods lowering reduction iron ore energy',
#  'method, device equipment measuring ore discharge port rough crushing machine',
#  'content-based contextual reactions posts social networking system',
#  'ffeasibility cloud computing analysis method',
#  'content recommendation system based artificial intelligence, electronic equipment storage medium',
#  'behavior path generation method device, equipment storage medium',
#  'pre-selecting waste-discarding method non-ferrous metal ores',
#  'artificial intelligence-based generation anthropomorphic signatures use thereof',
#  'intelligent control method ore pulp liquid level flotation process',
#  'intellectual property case source recognition method device, equipment storage medium',
#  'ore pulp phase bubble image in-situ acquisition device flotation machine',
#  'flotation system method continuously automatically controlling eh ph ore pulp',
#  'truck anti-collision early warning method device strip mine storage medium',
#  'blasting fragmentation prediction method based ore rock crushing mechanism',
#  'automatic power supply control method system based artificial intelligence storage medium',
#  'method evaluating ore grinding cost magnetic separation-fine screening regrinding process',
#  'system method determining location ore stockpile',
#  'abnormal patient identification method device, terminal equipment storage medium',
#  'multistage silicon removal purification device method fine iron powder',
#  'system method determining location ore stockpile',
#  'internet things system monitoring storage stage state solid rocket engine',
#  'apparatus, systems, methods enhancing hydrocarbon extraction techniques related thereto',
#  'harmless treatment method phosphate ore beneficiation tailings',
#  'fuzzy control method flotation concentrate grade',
#  'user intention determination method device, computer equipment storage medium',
#  'sample-efficient representation learning real-time latent speaker state characterisation',
#  'smart city informatization analysis system',
#  'digital twinning system transformer substation',
#  'crusher feed metering device',
#  'integration carbon sequestration selective hydrometallurgical recovery metal values',
#  'pavement model creating method device mine simulation system, medium equipment',
#  'user real-time recommendation method, device, system equipment readable storage medium',
#  'ore storage bin bridge type grab bucket automatic loading method system',
#  'p-wave arrival time automatic pickup method based deep learning',
#  'systems methods sorting collecting enhanced metal-bearing ores desired size metal-bearing ores',
#  'dynamic network roaming',
#  'novel efficient ore grinding equipment',
#  'system method assigning haul truck dump location',
#  'method treating heavy metal pollution sulphide ore tailings',
#  'mineral resource exploration multi-dimensional analysis processing system based internet things feature recognition',
#  'flow message identification method device, computing equipment computer storage medium',
#  'system method determining dump location vehicle',
#  'aggregate service user interface',
#  'predicting fatigue asset heals',
#  'method processing potash ores',
#  'determining shear rate and/or shear stress sonar based velocity profiles differential pressure',
#  'sensitive comment recognition method device, terminal equipment storage medium',
#  'detection method device emerging theme, computer equipment storage medium',
#  'network security detection method system based big data, storage medium',
#  'urban rail transit underground structure intelligent monitoring system based internet things',
#  'coordinated scheduling optimization method dense dehydration process',
#  'gas monitoring system hexafluorobutadiene storage place monitoring method thereof',
#  'ore grinding granularity soft measurement method, system, medium, equipment terminal',
#  'gas monitoring system hexafluorobutadiene storage place monitoring method thereof',
#  'video analytic processing neuro-symbolic artificial intelligence',
#  'method selecting ball diameter grading grinding ball horizontal stirring mill',
#  'method adjusting elutriation magnetic separator, terminal storage medium',
#  'smart campus cloud platform system',
#  'abnormal scene detection method laser radar, electronic equipment storage medium',
#  'method determining flotation design time based laboratory flotation closed-circuit test',
#  'blasting drilling method, device equipment based artificial intelligence medium',
#  'apparatus acquiring 3-dimensional maps scene',
#  'online crushing screening equipment process large-particle-size nickel ore',
#  'microbiome based systems, apparatus methods exploration production hydrocarbons',
#  'strip mine surface three-dimensional model construction method, device equipment storage medium',
#  'intelligent park personnel congestion dredging management system method',
#  'flotation cell ph adjusting device',
#  'method apparatus control flotation separation process, including parameters flotation process reagent addition optimize mineral recovery',
#  'intelligent film television work subtitle production method system',
#  'ore granularity identification method system based crushed product particle size distribution characteristics',
#  'user tag portrait processing method, user portrait system, device storage medium',
#  'fund product analysis management method, device system',
#  'iron ore air shaft ore pass breaking method system',
#  'flotation automatic dosing system based x-ray dosing method thereof',
#  'cloud-oriented database security situation awareness system',
#  'pulverizing mill mineral aggregate treatment',
#  'ore vehicle loading scheduling optimization method based improved particle swarm optimization',
#  'aviation cost prediction method based cost impact factor intelligent tuning',
#  'two-lane automation equipment management method device, electronic equipment storage medium',
#  'computer system method machine learning inference',
#  'maintenance recommendations using lifecycle clustering',
#  'mechanical automatic ore crushing device',
#  'basketball training analysis method system storage medium',
#  'calculation method theoretical flotation recovery rate gold ore product',
#  'flotation recovery rate prediction device, flotation recovery rate prediction method, program',
#  'full-automatic ore sample preparation moisture determination system',
#  'gold ore grinding-floating process energy consumption prediction method',
#  'laboratory flotation temperature control auxiliary equipment using method thereof',
#  'verbal skill template evaluation method device, electronic equipment storage medium',
#  'construction method system traditional chinese medicine knowledge graph, storage medium',
#  'environmental management system',
#  'ore level control device underground rail transportation unloading station mine',
#  'trusted user system construction method system readable storage medium',
#  'defective finance identification method system based interpretable machine learning, readable storage medium',
#  'automated settlement provisional payment commodity using distributed ledger',
#  'continuous intelligent multi-stage mineral separation device mineral separation application method',
#  'detection system method spiral stirrer vertical stirring mill',
#  'advanced process control system method alumina ore pulp mill',
#  'oxidative heap leaching base metals',
#  'online prediction method chemical quality sintered ore',
#  'distributed ore grinding expert system model prediction control method',
#  'adjusting device ore pulp liquid level flotation tank',
#  'multi-size-fraction mineral preparation machine',
#  'unattended ore full-automatic sample preparation system',
#  'dumping position state detection method device, electronic equipment storage medium',
#  'fine grain tailing damming method simulation device',
#  'experimental device evaluating influence uranium ore in-situ leaching chemical clogging permeability',
#  'maintenance recommendations using lifecycle clustering',
#  'photoelectric beneficiation sorting process phosphorite',
#  'method device measuring ore grinding granularity',
#  'intelligent control system flotation system',
#  'full-automatic ore sample preparation moisture determination system',
#  'device predicting, medium predicting, method predicting production index using moving object stay number',
#  'human body temperature acquisition processing method system',
#  'method device generating availability detection model, equipment storage medium',
#  'multi-modal methods systems disease diagnosis',
#  'intelligent sinter particle counting method based image multi-level feature matching',
#  'preparation valuing method molybdenum raw ore standard sample',
#  'combined detection device ore pulp liquid level foam yield flotation machine',
#  'closed-loop modeling optimization control method equipment multiple groups vertical mills',
#  'automatic updating system flotation dosing',
#  'cloud-based enterprise holographic archive management control method device storage medium',
#  'remote sensing image cloud detection method system based multi-scale network',
#  'automatically labeling functional blocks pipelines existing machine learning projects corpus adaptable use new machine learning projects',
#  'method system predicting time instant providing promotions user',
#  'embedded system-oriented flotation froth flow velocity extraction method',
#  'tailing pond flood regulation storage capacity prediction method device, electronic equipment medium',
#  'intelligent ore blending system method blast furnace ironmaking pellets storage medium',
#  'beneficiation fine grinding control method beneficiation fine grinding control system thereof',
#  'mineral treatment method system applying ultrasound flotation froth',
#  'analysis method gold content gold-containing ore sample',
#  'system method beneficiating collecting lithium using fluidized bed reactor',
#  'strip mine transportation scheduling scheme making method',
#  'method intelligently controlling load rod mill',
#  'source code vulnerability detection method system storage medium',
#  'method optimizing ore grinding overflow particle size interval automatically controlling parameters',
#  'flotation dosing device automatic pipeline cleaning function',
#  'fuzzy optimization control method equipment ore grinding classification process',
#  'big data-based vehicle-mounted video monitoring device processing method',
#  'system method telematics tracking equipment usage',
#  'process recovering titanium dioxide',
#  'method extracting base precious metals pre-treatment leads solubilisation refractory matrices thereof',
#  'hydrogen explosion ore crushing equipment crushing method',
#  'method system training virtual agents fallback analysis',
#  'storage mine pile scanning equipment based single-line laser radar range finder',
#  'method predicting platinum-palladium grade based linear regression model',
#  'system method telematics tracking equipment usage',
#  'ore level control device underground rail transportation unloading station mine',
#  'mine intelligent whole production process management control system',
#  'system method plant control based fluid quality',
#  'method delineating metallogenic target region according existing ore body spatial distribution metallogenic law',
#  'ore grinding process fault diagnosis method device based convolution auto-encoder',
#  'iron ore concentrate long-distance pipeline terminal material treatment device method',
#  'unattended ore full-automatic sample preparation system',
#  'superfine grinding quality control method high-sulfur micro-fine particle disseminated gold concentrate',
#  'flotation equipment laboratory',
#  'prediction method grade platinum palladium flotation concentrate platinum-palladium paragenic ore',
#  'system in-line estimation load distribution rotary mill',
#  'systems methods medical imaging',
#  'mineral pre-enrichment method based solid microwaves',
#  'method monitoring deformation damage height overlying strata stope roof',
#  'method apparatus device-specific determination internal-resistance based state health battery',
#  'systems methods transportation coordination healthcare settings',
#  'battery health state prediction method device, storage medium electronic equipment',
#  'fleet-specific performance impact vehicle configuration',
#  'ore pulp conveying digital pipeline monitoring management system',
#  'automatic detection supplement method device dumping position, storage medium electronic equipment',
#  'automatic crushing control equipment mineral separation',
#  'mine simulation analysis method device, equipment storage medium',
#  'method surveying surveying system',
#  'device preventing ore pulp overflowing pipeline blocked tailing conveying pump station',
#  'method producing titanium-aluminum-vanadium alloy',
#  'system method processing battery passport',
#  'system method processing battery passport',
#  'natural gas extraction desanding dewatering device',
#  'flotation pulp steam heating device',
#  'cloud infrastructure isolation run-time behavioral tuning configuration externalization',
#  'intelligent financial management tool based cloud architecture',
#  'method rapidly delineating porphyry ore deposit ore body using chlorite trace element content',
#  'temperature-control flotation concentrator',
#  'auxiliary feeding device calcium carbonate ore grinding machine',
#  'medical waste intelligent tracking management system method',
#  'ore flow optimization',
#  'ore feeder centrifugal concentrator',
#  'self-learning recommendation method device, computer equipment storage medium',
#  'real-time video intelligent processing method system based cloud edge collaboration',
#  'cloud computing platform container cloud real-time anomaly detection',
#  'intelligent slag discharging device tailing pond',
#  'beneficiation processing method',
#  'method apparatus generating dumping positions, electronic device storage medium',
#  'grayson range extender (gre) 3.0: advanced kinetic energy recovery system: high speed, high efficiency, heat resistant, fluid turbine generator type range extender, motor recharger electric vehicles, equipment, devices machinery',
#  'experimental device evaluating influence uranium ore in-situ leaching chemical clogging permeability',
#  'weak ore spot ore sorting method device, readable storage medium equipment',
#  'flotation blanking device',
#  'intelligent alarm system method based common alarm correlation analysis',
#  'liquid level control system vertical ring high-gradient magnetic separator',
#  'constructional geochemical combination anomaly identification method concealed mine exploration',
#  'hyper-converged infrastructure hierarchical resource management system based internet technology',
#  'method, system device remotely controlling excavator electronic equipment',
#  'post-earthquake trend analysis method device, electronic equipment readable storage medium',
#  'method recording analyzing mill medium dynamics using induction ball',
#  'mineral analysis laboratory business plan lowest turnover',
#  'full-automatic alloy ore sample preparation, screening determination system',
#  'scheme management system method art design',
#  'liquid level control system vertical-ring high-gradient magnetic separator',
#  'automatic ore polished section grinding polishing equipment polished section grinding polishing method',
#  'user behavior analysis method device, electronic equipment storage medium',
#  'novel recharge method improving geothermal recharge efficiency middle-deep layer sandstone',
#  'energy management system machine learning',
#  'sampling device mineral geological exploration',
#  'thickener analogue simulation experiment device',
#  'sampling device lead zinc ore component detection',
#  'intelligent sorting system based x-ray imaging',
#  'system method auto-mining resources, building dependency registry notifying impacted services',
#  'ore sample crushing device geological mineral exploration',
#  'dynamic cascaded clustering dynamic vnf',
#  'phosphate ore sorting method device, readable storage medium equipment',
#  'service quality evaluation processing method device, computer equipment storage medium',
#  'feeding device capable accurately controlling feeding amount control method thereof',
#  'ore granularity grading method system based image deep neural network',
#  'account evaluation method device, computer equipment storage medium',
#  'database design method city management',
#  'ore pulp copper grade online prediction soft measurement modeling method',
#  'e-mirror automatic position adjustment system',
#  'weighing system, carry-scraper weighing method',
#  'ore sampling sample preparation system method',
#  'multi-probe particle size detector ore pulp',
#  'intent-based organisation apis',
#  'intelligent optimization control method ore grinding process',
#  'intelligent precious metal pretreatment reselection equipment',
#  'aerial photography insulator spontaneous explosion defect detection model, method equipment storage medium',
#  'small flotation column laboratory',
#  'user complaint database expansion method device thereof storage medium',
#  'copper grade scn modeling algorithm x fluorescence grade analyzer',
#  'mechanical-electrical integrated ore processing equipment',
#  'electric shovel positioning method based density clustering',
#  'element analysis method based ore grinding image',
#  'method automatic control technological grades crushed ore flow',
#  'crushing mechanism automatic gold ore dressing system',
#  'intelligent sorting system based x-ray imaging',
#  'session prompting method device based artificial intelligence, storage medium equipment',
#  'fluorite mine flotation recovery device based waste heat recycling',
#  'method system secure exchange user cookie-data user interactions cryptocurrency',
#  'method constructing four-dimensional database black rock type uranium mine',
#  'coarse crushing integrated control system method',
#  'lime preparing adding system',
#  'high-quality ultra-pure fine iron powder grading preparation device high-quality ultra-pure fine iron powder grading preparation method',
#  'predictions process industrial plant',
#  'pedestrian flow analysis method, storage medium processor',
#  'centrifugal diffusion fusion type flotation equipment',
#  'ore grinding medium bulk specific gravity measuring device method',
#  'soft measurement method exciting current strong magnetic machine',
#  'titanium dioxide waste residue recycling system',
#  'zinc fast coarse adding amount adjusting method based memory network predictive controller',
#  'mine transportation management system management method',
#  'method flotation separation copper-sulfur minerals ferrate',
#  'digital twin foundation development platform park energy consumption',
#  'attachment status monitoring ground engaging tools (get) heavy machinery',
#  'fracturing evaluation method system based electromagnetic fracturing monitoring storage medium',
#  'digital forest grass system',
#  'tailing slurry sampling device',
#  'abnormal traffic detection method device, storage medium equipment',
#  'method device constructing digital disease module',
#  'multi-metal nodule crushing device method based supercritical carbon dioxide',
#  'equipment detecting vanadium content ore',
#  'business system construction method device, electronic equipment computer storage medium',
#  'reclamation area feature extraction method device, computer equipment storage medium',
#  'liquid iron-free aluminum sulfate production system',
#  'dust removal device mineral separation',
#  'automatic control device liquid level ore pulp tank flotation machine',
#  'computerized system method automatically communicating conditional messages within mobile application environment',
#  'equipment control method device, electronic equipment storage medium',
#  'ore crusher anti-blocking function',
#  'ore grade automatic real-time monitoring system method suitable rail transportation',
#  'agricultural machine maintenance prediction method device, storage medium electronic equipment',
#  'response emergency department surge prediction',
#  'federated learning method apparatus based graph neural network, federated learning system',
#  'personnel positioning-based transportation metering system',
#  'method system analyzing performance oltp service system',
#  'multi-line laser radar range finder coupled stored mine pile scanning equipment',
#  'offline capabilities live applications cloud collaboration platform',
#  'pressure-control temperature-control hypergravity experimental device simulating deep-sea seabed responses',
#  'mine waste identification method, device equipment based fused image storage medium',
#  'strip mine yield determination method, device system, chip terminal',
#  'systems methods trajectory determination',
#  'method generating expert feature dimension required machine learning modeling',
#  'obstacle processing system unmanned mine driving area',
#  'multi-view unsupervised graph contrast learning model construction method system, computer, storage medium application',
#  'automatic separation adjusting system method dry magnetic separator',
#  'method device identifying working state excavator, excavator processor',
#  'belt ore conveying weighing particle size estimation intelligent detection system method',
#  'automatic aging calibration system, intelligent aging cabinet intelligent aging vehicle',
#  'method monitoring mine safety management based insar',
#  'assessing benefits automatic grinding control using pst technology true on-line particle size measurement',
#  'methods processing oil sands containing swelling clays',
#  'hazardous truck transportation risk assessment method system based hierarchical fuzzy neural network',
#  'retaining wall detection method, retaining wall detection device storage medium',
#  'crushing system control method based cyclic load',
#  'frequency conversion control system sand making machine frequency conversion control method device sand making machine',
#  'clamping fixing device ore test',
#  'distributed detection malicious cloud actors',
#  'abnormality detection method device, equipment storage medium',
#  'parameter configuration optimization method optimization system cloud storage system',
#  'cermet cemented carbide mixture three dimensional printing thereof',
#  'laboratory ore sample grinding sample preparation bag',
#  'real-time ore blending-oriented multi-target ore card online scheduling method system',
#  'method recycling mineral powder slurry comprehensively utilizing resources open-pit stope',
#  'vehicle fault analysis method device, electronic equipment storage medium',
#  'arc-shaped lining plate structure ball mill cavity type optimization method',
#  'financial management system financial management method',
#  'super range extension control system electric vehicles (evs)',
#  'negative electrodes electrochemical cells',
#  'solid iron-free aluminum sulfate production system',
#  'mental health state prediction method system based correlation analysis',
#  'device rapidly detecting total iron content iron ore',
#  'security risk prediction method device, equipment storage medium',
#  'estimating moving state rotating machines systems methods',
#  'full-automatic alloy ore sample preparation screening measuring system',
#  'network node, mobile node methods performed therein',
#  'fact management system',
#  'fast hydrating polyacrylamide microplates',
#  'intelligent mine management control method management control facility based digital twinning',
#  'task scheduling method device, electronic equipment storage medium',
#  'collophanite reverse flotation magnesium removal raw ore blending method',
#  'method detecting components lithium-containing mineral flotation pulp real time',
#  'method pre-enrichment, suspension roasting, separation enrichment ferromanganese ore',
#  'unmanned inspection equipment iron ore',
#  'online ore sorting equipment based machine vision',
#  'method arrangement managing power consumption mine',
#  'mineral aggregate distribution method device computer readable storage medium',
#  'credit risk assessment method device, computer equipment storage medium',
#  'collaborative loading transporting system method unmanned transportation mine',
#  'photographing method terminal',
#  'system performance index prediction method device, server storage medium',
#  'metadata-based diagnosis management system cardiovascular cerebrovascular diseases',
#  'storage device memory controller',
#  'mill control method mill control device',
#  'train wheel set turning repair scheduling system method',
#  'learning graph',
#  'downhole ore metering system',
#  'test water tank testing hydraulic ore collecting device',
#  'intelligent ore blending device',
#  'productivity platform providing user specific functionality',
#  'method flotation separation chalcopyrite pyrite h2o2',
#  'average vehicle speed prediction method device based tensor robust decomposition, storage medium',
#  'underground mine stope operation management control system method',
#  'method predicting ore dressing yield vanadium titano-magnetite application',
#  'hydraulic gyratory crusher ore discharge port measuring tool use method thereof',
#  'method system secure exchange user cookie-data user interactions cryptocurrency',
#  'automatic driving scheduling system based mine transportation',
#  'power fault diagnosis early warning method, device, equipment storage medium',
#  'method system predicting feo content sintered finished ore',
#  'methods, systems, computer-readable media semantically enriching content semantic navigation',
#  'x luminoscope measuring ore types',
#  'automatic multifunctional composite magnetic separation equipment',
#  'intelligent financial management tool based cloud architecture',
#  'ore image generation method based generative adversarial network computer readable storage medium',
#  'energy optimization plant operating method thereof',
#  'method system chromatic aberration reduction',
#  'recommendation method device vehicle insurance product, equipment storage medium',
#  'device reducing impurity iron content zircon concentrate stirring flotation machine',
#  'microservice intelligent operation maintenance system method oriented cloud native application',
#  'flotation ore feeding sampling device combined selection test laboratory',
#  'digital ore drawing design platform, automatic ore drawing generation method virtual-real fusion method',
#  'apparatus method guidance sintered ore',
#  'fact management system',
#  'tailing recovery method',
#  'mine car positioning control system',
#  'method rapidly inverting content rare earth ce element',
#  'mine car positioning control system method',
#  'automatic ore blending setting device ball mill',
#  'large-scale photovoltaic power station energy storage capacity configuration method considering light abandoning rate prediction precision',
#  'methods manufacture colorfast masonry',
#  'automatically scanning representing environment collision avoidance',
#  'traffic speed prediction method system storage medium',
#  'intelligent dosing concentration automatic control system quartz sand beneficiation',
#  'ore crusher',
#  'combining device behavioral models building schema cyber-security large-scale iot infrastructure',
#  'high stress impact detection longwall shearer',
#  'method transporting seabed ore shallow sea using air bag',
#  'overflow management configuration engine material processing system',
#  'full-automatic sample preparation detection system ore raw materials',
#  'method device identifying novel double-stranded dna cytidine deaminase, computer readable storage medium application',
#  'scientific characterization method real surface roughness ore grinding product',
#  'radar antenna scanning mode identification method device, equipment storage medium',
# ...
#  'automatic aging calibration system, intelligent aging cabinet intelligent aging vehicle',
#  'device measuring height caved roof height loose ore heap underground mine',
#  'method interactions traffic transportation systems based sdg framework',
#  'wearable computing-based intelligent safety management system nuclear power plant',
#  'traffic violation behavior analysis method system, electronic equipment storage medium',
#  'underground pollutant concentration prediction method device, electronic equipment storage medium',
#  'distribution trolley optimization scheduling method, device equipment storage medium',
#  'voice quality evaluation method device, electronic equipment computer storage medium',
#  'feeding device flotation machine',
#  'mill filling rate vibration monitoring system',
#  'abnormal brain connection prediction system, method device readable storage medium',
#  'method, apparatus device locating pollution source basis big data, storage medium',
#  'full-life-cycle carbon footprint processing method device, storage medium equipment',
#  'device method monitoring concentration filling slurry real time stirring process',
#  'collaborative loading method system unmanned mine card manual excavator',
#  'method predicting failures industrial systems',
#  'method estimating throat temperature blast furnace based multilayer ore-to-coke ratio distribution model',
#  'method monitoring damage depth stope bottom plate',
#  'reduced write amplification using small-block log',
#  'excavator control method, system equipment readable storage medium',
#  'method system assisting performing financial services',
#  'association determination',
#  'mine quantity detection method, device equipment mine car storage medium',
#  'cloud-native reservoir simulation',
#  'multifunctional private cloud storage device',
#  'semantic search method device, electronic equipment, storage medium product',
#  'metallurgical cycle grinding equipment',
#  'multi-entity management node wireless node network',
#  'shale oil exploitation area division method, device equipment readable storage medium',
#  'intelligent logistics storage park safety perception system',
#  'ore separation method based knowledge distillation computer readable storage medium',
#  'tailing pond ore drawing arrangement method based unmanned aerial vehicle remote sensing multiphase sph algorithm',
#  'intelligent mine card automatic driving system strip mine area',
#  'sintered ore feo content detection method sintered ore feo content detection system',
#  'method heap leaching gold poor ores cryolite zone conditions',
#  'determination method constructing taiyuan group limestone water transportation control',
#  'single-cylinder hydraulic cone crusher tool',
#  'chinese medicine production process knowledge system',
#  'intelligent medicine box',
#  'mvt type lead zinc ore mineralization prediction method device, computer equipment storage medium',
#  'computer implemented method defect detection imaging dataset wafer, corresponding computer-readable medium, computer program product systems making use methods',
#  'seawater suspended sediment concentration calculation method device, electronic equipment storage medium',
#  'splash-proof mineral separation flotation machine',
#  'court authorized pedestrian hidden property estimation decision support system architecture',
#  'jaw crusher producing furnace mouth spray coating',
#  'transportation mechanism control system transportation equipment',
#  'automatic water replenishing method mineral flotation flotation machine laboratory',
#  'intelligent air compressor unattended system',
#  'system method inspecting machine',
#  'sample-efficient representation learning real-time latent speaker state characterization',
#  'fine delimiting method spatial range strip mine area',
#  'ore property analysis method equipment based sound signal processing',
#  'virtual-real fusion flexible production line variable control method system',
#  'managing distributing content plurality observation platorms',
#  'crushing plug cleaning system draw shaft',
#  'system separating recycling ilmenite titanium slag collected dust',
#  'embedding magnetic map image file',
#  'recoverable acquisition instrument real-time observation stress characteristics vibration characteristics stope surrounding rocks use method thereof',
#  'economic evaluation method system echelon utilization power battery',
#  'intelligent mineral separation thickener',
#  'intelligent blockage removing system mine aggregate production line',
#  'mineral product crusher conveyor belt',
#  'pulp hydraulic transportation',
#  'ecological environment quality factor analysis method device, storage medium processor',
#  'compartment balance detection method system based three-dimensional laser radar',
#  'mineral exploration method device based semi-supervised learning storage medium',
#  'non-metallic ore superfine grinding high-end intelligent production line',
#  'blended ore production distribution method system based port',
#  'cone crusher cavity type parameter optimization method based edem',
#  'tailing dam loading test method influence lenticular body',
#  'positioning switching method based slam (simultaneous localization mapping) gps (global positioning system)',
#  'intelligent scheduling method system strip mine trucks',
#  'parameter determination method device safe blasting stope computer equipment',
#  'liquid level adjusting device flotation machine',
#  'agricultural water early warning method device, electronic equipment storage medium',
#  'production cost control method system, storage medium equipment',
#  'toilet system sensors measuring excretion output user, fluid balance monitoring system method determining monitoring fluid balance subject',
#  'systems methods autonomous convoy leader vehicle',
#  'techniques improve schedule optimization',
#  'usb-hid safety automatic testing device based remote dynamic injection',
#  'knowledge graph-oriented knowledge reasoning method based online graph processing technology',
#  'lithium-rich brine spatial distribution prediction method system electronic equipment',
#  'strip mine driverless single-marshalling transportation hardware-in-the-loop simulation test system method',
#  'online detection system intelligent material detection ball mill operation state control method',
#  'mineral separation table ore zone analysis model based mask-rcnn algorithm',
#  'natural language understanding model context resolver',
#  'preparation method weathering steel iron tower',
#  'blast furnace material change control method device computer readable storage medium',
#  'home decoration scheme recommendation method system based virtual reality storage medium',
#  'predictive modeling anti-malware solutions',
#  'iron ore selectivity online prediction method based image recognition technology',
#  'natural language understanding model context resolver',
#  'traffic analysis method device based knowledge graph, equipment medium',
#  'gravel crushing device screening mechanism',
#  'soft measurement method device overflow fineness hydrocyclone, electronic equipment medium',
#  'state monitoring early warning method steel structure construction process',
#  'user portrait construction method device oriented poverty prevention early warning, storage medium',
#  'sampler flotation machine',
#  'screening device facilitating mineral crushing',
#  'method system predicting optimal working condition hydrothermal reaction degradation effect thickened oil',
#  'efficient environment-friendly ore finish machining production line',
#  'method system securing communications lead device secondary device',
#  'service processing method device, electronic equipment readable storage medium',
#  'pressurized multi-channel column leaching test device test method thereof',
#  'renewable/sustainable energy harvesting monetization ecosystem',
#  'gravity feeding device antimony ore crusher',
#  'fine-grained energy consumption sensing framework based climate seasons cloud storage system',
#  'remote control method, device, equipment system electric excavator storage medium',
#  'security visualization method system based organization internal e-mail log analysis',
#  'method measuring dissociation degree molybdenite',
#  'recovery metal primary secondary sulphurated minerals oxidized minerals, compositions valuable minerals',
#  'automatic machine learning training method device storage medium',
#  'perception-based driverless transport vehicle pointed parking method',
#  'method removing detecting iron foreign matters iron ore belt conveying process',
#  'system method material density distribution survey based cosmic muon detection',
#  'intelligent power grid fault monitoring system based cloud computing',
#  'dehydration tank control system based spiral pipe real-time measurement',
#  'interpretive conclusion report generation method, device equipment storage medium',
#  'implicit video recommendation algorithm',
#  'horizontal shaft vibration protection device gyratory crusher',
#  'truck fuel consumption prediction method, system equipment storage medium',
#  'online detection system intelligently detecting running state ball mill',
#  'enhanced material detection stereo beam profile analysis',
#  'experimental device simulating tailing pond dam break model various working conditions',
#  'commercial vehicle demand prediction method device, equipment storage medium',
#  'flocculant automatic dosing treatment system',
#  'online ore pulp solid sample cake sample preparation device',
#  'graph database optimization method device, electronic equipment storage medium',
#  'milk powder quality evaluation method based characteristic components combination machine learning',
#  'ore crusher equipment operation state monitoring method',
#  'multi-task joint scheduling method based graph model',
#  'blowback lift pump integrated device brine extraction well',
#  'dust-free ore crusher',
#  'ore pulp monitoring device based microfluid',
#  'knowledge extraction method medical cognition intelligent scientific research platform',
#  'transcritical co2 pulverization',
#  'road surface obstacle detection method mine card automatic driving',
#  'method testing propagation law blasting seismic waves complex engineering geological conditions',
#  'hydrate shallow gas combined exploitation physical simulation experiment device method',
#  'abnormal behavior detection method device, equipment storage medium',
#  'intelligent control system vertical stirring mill method',
#  'ore ecological restoration greening auxiliary device',
#  'warp engine powered gravitional waves',
#  'automatic sampling sample preparation equipment iron ore',
#  'whole-process consultation knowledge integrated management system method',
#  'analog simulation platform natural gas conveying system',
#  'ore pigment production device based intelligent control',
#  'apparatus method seabed resources collection',
#  'apparatus method seabed resources collection',
#  'geological environment treatment monitoring system',
#  'service providing apparatus method skin care based image analysis',
#  'anti-collision method device, storage medium electronic equipment',
#  'text matching method device, storage medium computer equipment',
#  'system method monitoring state oil truck wheels',
#  'radiomics-based prediction severe immune-related adverse events patients lung cancer',
#  'ore conveying device based image processing',
#  'online soft measurement method sand return ratio ore grinding classification process',
#  'financial factor generation method, electronic device computer readable storage medium',
#  'map knowledge service construction method, device system',
#  'ore grinding granularity automatic detection device',
#  'intelligent control method balanced crushing fine crushing workshop machine-made gravel',
#  'terrain detection vehicle',
#  'automatic table ore belt identification receiving method device',
#  'crowd-sourced automatic generation user interface tests enterprise-specific mobile applications',
#  'xrt equipment auditing system method using',
#  'man-machine loop method, device system, electronic equipment storage medium',
#  'high-temperature softening material grinding method device temperature control function',
#  'dynamic modeling method ore grinding medium semi-autogenous mill',
#  'intelligent ore crushing device automatic adjusting function',
#  'fracture density model system, methods, apparatuses',
#  'numerical simulation analysis method bif iron ore bedding slope deformation damage',
#  'mineral mill subcritical rotating speed judgment method',
#  'underground uwb positioning method system based mobile base station, storage medium',
#  'lower-cost, higher efficiency, environmentally friendly, self-dispersible recovery, stimulation fluid enhanced oil recovery (eor) improved oil recovery (ior)',
#  'anomaly event detection using frequent patterns',
#  'method apparatus repairing fail location',
#  'obstacle avoidance planning system method unmanned transportation surface mine',
#  'intelligent construction site informatization management method',
#  'sample storage device iron ore geological exploration',
#  'supervision object employment post intelligent matching method, device equipment storage medium',
#  'method improving overall classification accuracy long-tail distribution speech based transfer learning',
#  'clothing manuscript generation method device, electronic equipment storage medium',
#  'rail type mineral separation system',
#  'ore pulp pipeline erosive wear model construction method based energy method',
#  'method extracting dam emergency event based dual attention mechanism',
#  'decision-making method comprehensive alumina production indexes based multi-scale deep convolutional network',
#  'decision-making method comprehensive alumina production indexes based multi-scale deep convolutional network',
#  'intelligent ore discharge control device',
#  'cone crusher convenient removing foreign matters',
#  'intelligent parameter adjusting system method tailing dry-discharge dehydrator',
#  'full-process safe operation threat discovery system method',
#  'building stone ore tailing pond resource recovery system',
#  'automatic control device mine crusher',
#  'client side diagnostics enhanced customer care',
#  'electric vehicle fast charging station energy storage system based source-network-load-storage cooperative service method thereof',
#  'strip mine forklift walking planning method system oriented simulated ore blending',
#  'automatic ore washing assembly line',
#  'voice playing method computer equipment',
#  'multi-host link hotspot analysis method system, computer equipment storage medium',
#  'mill detection method, device equipment',
#  'excavator operation range setting method, terminal equipment readable storage medium',
#  'method producing steel sponge iron manufacturing process',
#  'static soaking test method simulating release characteristics heavy metals mercury tailings',
#  'three-dimensional space coordinate conversion method, storage medium computing device',
#  'knowledge graph display method device, computer device readable storage medium',
#  'stone vibrating screen mine',
#  'uranium concentration main control factor diagnosis method, device equipment readable storage medium',
#  'method selecting optimal ore grinding medium proportion identifying area inert zone ball mill',
#  'report generation management method apparatus, computer device, storage medium',
#  'control method device pulping process suspension roasting product',
#  'federal learning-based model construction method device, storage medium',
#  'method determining assimilation performance iron ore powder',
#  'system method monitoring presence absence tooth bucket truck hopper primary crusher',
#  'metal agglomerate production configuration',
#  'battery energy storage distributed calculation control system control method',
#  'abnormal analysis method device storage medium',
#  'drilling anchoring type asteroid mineral collection cross-domain transportation system method',
#  'wear-resistant steel plate impact test evaluation processing method system',
#  'intelligent agent map analysis method system readable storage medium',
#  ...]

# %%
descartados_fuzzy_sin_stopwords = obtiene_descartados(filtro_fuzzy_sin_stopwords, data_target)

# %%
len(descartados_fuzzy_sin_stopwords)
# Out:
# 1203

# %%
len(filtro_fuzzy_sin_stopwords)
# Out:
# 1989

# %%
len(filtro_fuzzy_sin_stopwords) + len(descartados_fuzzy_sin_stopwords) == data_target.shape[0]
# Out:
# True

# %%
# Obtiene los descartados
data_descartados_fuzzy_sin_sw = data_target[data_target['title'].isin(descartados_fuzzy_sin_stopwords)]
data_descartados_fuzzy_sin_sw
# Out:
#                                                   title  \
# 1     process integrating mining processing together...
# 3     method water moisture management mining operation
# 13    big data quality inspection method customer se...
# 18    model updating method device automatically min...
# 21    ai-based platform automated labor law complian...
# ...                                                 ...
# 3177  horizontal well sand-water co-production contr...
# 3179  stable curing treatment equipment industrial m...
# 3180  mining anti-explosion all-terrain intelligent ...
# 3182                       mining gas monitoring sensor
# 3189  method providing clock frequencies computing c...
#
#                                                abstract publication_date
# 1     The present invention belongs to the mining se...       2023-08-10
# 3     Wet conditions pose a plurality of hazards for...       2024-03-14
# 13    The invention discloses a big data quality ins...       2022-01-14
# 18    The invention provides a model updating method...       2022-07-05
# 21    An AI-based platform for automated labor law c...       2023-08-10
# ...                                                 ...              ...
# 3177  The invention discloses a horizontal well sand...       2020-07-14
# 3179  The utility model relates to stable solidifica...       2020-11-17
# 3180  The utility model relates to a mining explosio...       2023-06-13
# 3182  The utility model discloses a mining gas monit...       2023-02-14
# 3189  The present disclosure relates to a method for...       2023-04-20
#
# [1203 rows x 3 columns]

# %%
# Obtiene los filtrados
data_filtrados_fuzzy_sin_sw = data_target[~data_target['title'].isin(descartados_fuzzy_sin_stopwords)]
data_filtrados_fuzzy_sin_sw
# Out:
#                                                   title  \
# 0     method operating comminution circuit respectiv...
# 2     system method continuous optimization mineral ...
# 4     method training quality prediction model proce...
# 5     computer-implemented methods referring industr...
# 6            method optimizing mineral recovery process
# ...                                                 ...
# 3186  adaptive control longitudinal roll system deve...
# 3187  systems, methods, program products facilitatin...
# 3188  method system managing vehicle transportation ...
# 3190  wall panels components custom enclosures shipp...
# 3191  retrofit cover plate assembly adapt alternativ...
#
#                                                abstract publication_date
# 0     A method for operating an ore comminution circ...       2020-09-03
# 2     A method for continuously optimizing an ore gr...       2023-12-21
# 4     A method (1000, 1001) for training a quality p...       2022-09-22
# 5     A computer-implemented method is provided. The...       2024-05-23
# 6     Disclosed is a method for optimizing a mineral...       2023-08-24
# ...                                                 ...              ...
# 3186  FIELD: mining.SUBSTANCE: invention relates to ...       2021-09-08
# 3187  Machine learning systems and methods are descr...       2023-06-13
# 3188  CA 03091162 2020-08-13 (12) INTERNATIONAL APPL...       2021-11-16
# 3190  Custom enclosures are made using various types...       2023-08-03
# 3191  A multi-functional retrofit cover plate assemb...       2022-06-23
#
# [1989 rows x 3 columns]

# %% [markdown]
# ---
# **Observación**
#
# ---
#
# La técnica fuzzy considerando un umbral de 90% y descartando las stopwords logra descatar 1203 registos dejando 1989.

# %%
lst_resultados.append(['fuzzy - umbral 90%',
                      data_descartados_fuzzy_sw.shape[0],
                      data_filtrados_fuzzy_sw.shape[0],
                      data_descartados_fuzzy_sin_sw.shape[0],
                      data_filtrados_fuzzy_sin_sw.shape[0]])

# %% [markdown]
# ## Filtro usando coincidencia basada en stemming

# %%
def contains_stem_match(abstract, terms):
    stemmer = PorterStemmer()
    stemmed_terms = [stemmer.stem(term) for term in terms]
    words = abstract.split()
    for word in words:
        if stemmer.stem(word) in stemmed_terms:
            return True
    return False

# %% [markdown]
# ### Experimento considerando stopwords

# %%
# Vuelve a seleecionar los datos para asegurar
data_target = data[['title', 'abstract', 'publication_date']]
data_target['title'] = data_target['title'].apply(convierte_a_minusculas)
# Out:
# <ipython-input-134-ee3b0254d62c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_target['title'] = data_target['title'].apply(convierte_a_minusculas)

# %%
len([title for title in data_target['title'] if not contains_stem_match(title, excluyentes)])
# Out:
# 3192

# %%
filtrados = [title for title in data_target['title'] if not contains_stem_match(title, excluyentes)]

# %%
descartados_con_stemm = obtiene_descartados(filtrados, data_target)

# %%
# Obtiene los filtrados
data_filtrados_stemm_sw = data_target[~data_target['title'].isin(descartados_con_stemm)]
data_filtrados_stemm_sw
# Out:
#                                                   title  \
# 0     method for operating a comminution circuit and...
# 1     process for integrating the mining and process...
# 2     system and method for continuous optimization ...
# 3     method for water and moisture management for a...
# 4     method for training a quality prediction model...
# ...                                                 ...
# 3187  systems, methods, and program products for fac...
# 3188  method and system for managing vehicle transpo...
# 3189  method for providing clock frequencies for com...
# 3190  wall panels and other components for custom en...
# 3191  retrofit cover plate and assembly to adapt alt...
#
#                                                abstract publication_date
# 0     A method for operating an ore comminution circ...       2020-09-03
# 1     The present invention belongs to the mining se...       2023-08-10
# 2     A method for continuously optimizing an ore gr...       2023-12-21
# 3     Wet conditions pose a plurality of hazards for...       2024-03-14
# 4     A method (1000, 1001) for training a quality p...       2022-09-22
# ...                                                 ...              ...
# 3187  Machine learning systems and methods are descr...       2023-06-13
# 3188  CA 03091162 2020-08-13 (12) INTERNATIONAL APPL...       2021-11-16
# 3189  The present disclosure relates to a method for...       2023-04-20
# 3190  Custom enclosures are made using various types...       2023-08-03
# 3191  A multi-functional retrofit cover plate assemb...       2022-06-23
#
# [3192 rows x 3 columns]

# %%
# Obtiene los descartados
data_descartados_stemm_sw = data_target[data_target['title'].isin(descartados_con_stemm)]
data_descartados_stemm_sw
# Out:
# Empty DataFrame
# Columns: [title, abstract, publication_date]
# Index: []

# %% [markdown]
# ---
# **Observación**
#
# ---
# Aplicando esta técnica no se descartan registros

# %% [markdown]
# ### Experimento descartando las stopwords

# %%
# Vuelve a seleecionar los datos para asegurar
data_target = data[['title', 'abstract', 'publication_date']]
data_target['title'] = data_target['title'].apply(convierte_a_minusculas)
data_target['title'] = data_target['title'].apply(preprocesar_texto)
# Out:
# <ipython-input-140-0c1e2dc7e44e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_target['title'] = data_target['title'].apply(convierte_a_minusculas)
# <ipython-input-140-0c1e2dc7e44e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_target['title'] = data_target['title'].apply(preprocesar_texto)

# %%
filtrados = [title for title in data_target['title'] if not contains_stem_match(title, excluyentes)]

# %%
descartados_con_stemm_sin_sw = obtiene_descartados(filtrados, data_target)

# %%
# Obtiene los filtrados
data_filtrados_stemm_sin_sw = data_target[~data_target['title'].isin(descartados_con_stemm_sin_sw)]
data_filtrados_stemm_sin_sw
# Out:
#                                                   title  \
# 0     method operating comminution circuit respectiv...
# 1     process integrating mining processing together...
# 2     system method continuous optimization mineral ...
# 3     method water moisture management mining operation
# 4     method training quality prediction model proce...
# ...                                                 ...
# 3187  systems, methods, program products facilitatin...
# 3188  method system managing vehicle transportation ...
# 3189  method providing clock frequencies computing c...
# 3190  wall panels components custom enclosures shipp...
# 3191  retrofit cover plate assembly adapt alternativ...
#
#                                                abstract publication_date
# 0     A method for operating an ore comminution circ...       2020-09-03
# 1     The present invention belongs to the mining se...       2023-08-10
# 2     A method for continuously optimizing an ore gr...       2023-12-21
# 3     Wet conditions pose a plurality of hazards for...       2024-03-14
# 4     A method (1000, 1001) for training a quality p...       2022-09-22
# ...                                                 ...              ...
# 3187  Machine learning systems and methods are descr...       2023-06-13
# 3188  CA 03091162 2020-08-13 (12) INTERNATIONAL APPL...       2021-11-16
# 3189  The present disclosure relates to a method for...       2023-04-20
# 3190  Custom enclosures are made using various types...       2023-08-03
# 3191  A multi-functional retrofit cover plate assemb...       2022-06-23
#
# [3192 rows x 3 columns]

# %% [markdown]
# ---
# **Observación**
#
# ---
# Aplicando esta técnica no se descartan registros.

# %%
lst_resultados.append(['stemm',
                      data_descartados_stemm_sw.shape[0],
                      data_filtrados_stemm_sw.shape[0],
                      0,
                      data_filtrados_stemm_sin_sw.shape[0]])

# %% [markdown]
# ## Filtro usando coincidencia usando expresiones regulares

# %%
def contains_regex_match(abstract, terms):
  for term in terms:
    pattern = re.compile(term)
    if pattern.search(abstract):
      return True
  return False

# %% [markdown]
# ### Experimento considerando stopwords

# %%
# Vuelve a seleecionar los datos para asegurar
data_target = data[['title', 'abstract', 'publication_date']]
data_target['title'] = data_target['title'].apply(convierte_a_minusculas)
# Out:
# <ipython-input-145-ee3b0254d62c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_target['title'] = data_target['title'].apply(convierte_a_minusculas)

# %%
filtrados = [title for title in data_target['title'] if not contains_regex_match(title, excluyentes)]

# %%
descartados_con_regex_con_sw = obtiene_descartados(filtrados, data_target)

# %%
# Obtiene los filtrados
data_filtrados_regex_sw = data_target[~data_target['title'].isin(descartados_con_regex_con_sw)]
data_filtrados_regex_sw
# Out:
#                                                   title  \
# 0     method for operating a comminution circuit and...
# 1     process for integrating the mining and process...
# 2     system and method for continuous optimization ...
# 3     method for water and moisture management for a...
# 4     method for training a quality prediction model...
# ...                                                 ...
# 3187  systems, methods, and program products for fac...
# 3188  method and system for managing vehicle transpo...
# 3189  method for providing clock frequencies for com...
# 3190  wall panels and other components for custom en...
# 3191  retrofit cover plate and assembly to adapt alt...
#
#                                                abstract publication_date
# 0     A method for operating an ore comminution circ...       2020-09-03
# 1     The present invention belongs to the mining se...       2023-08-10
# 2     A method for continuously optimizing an ore gr...       2023-12-21
# 3     Wet conditions pose a plurality of hazards for...       2024-03-14
# 4     A method (1000, 1001) for training a quality p...       2022-09-22
# ...                                                 ...              ...
# 3187  Machine learning systems and methods are descr...       2023-06-13
# 3188  CA 03091162 2020-08-13 (12) INTERNATIONAL APPL...       2021-11-16
# 3189  The present disclosure relates to a method for...       2023-04-20
# 3190  Custom enclosures are made using various types...       2023-08-03
# 3191  A multi-functional retrofit cover plate assemb...       2022-06-23
#
# [3187 rows x 3 columns]

# %%
# Obtiene los descartados
data_descartados_regex_sw = data_target[data_target['title'].isin(descartados_con_regex_con_sw)]
data_descartados_regex_sw
# Out:
#                                                   title  \
# 145      file system integration into data mining model
# 1544              interactive sequential pattern mining
# 1821  text keyword mining method and device thereof,...
# 2020            keyword mining system and mining method
# 2373  text main body keyword mining method, system a...
#
#                                                abstract publication_date
# 145   Aspects of a storage device including a memory...       2023-11-09
# 1544  Interactive sequential pattern mining is discl...       2020-02-18
# 1821  The invention discloses a text keyword mining ...       2022-02-18
# 2020  The invention discloses a keyword mining syste...       2021-03-26
# 2373  The invention relates to the field of patent d...       2023-05-09

# %% [markdown]
# ---
# **Observación**
#
# ---
#
# La técnica usando expresiones regulares y considerando las stopwords logra descatar 5 registros dejando 3187.

# %% [markdown]
# ### Experimento descartando stopwords

# %%
# Vuelve a seleecionar los datos para asegurar
data_target = data[['title', 'abstract', 'publication_date']]
data_target['title'] = data_target['title'].apply(convierte_a_minusculas)
data_target['title'] = data_target['title'].apply(preprocesar_texto)
# Out:
# <ipython-input-150-0c1e2dc7e44e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_target['title'] = data_target['title'].apply(convierte_a_minusculas)
# <ipython-input-150-0c1e2dc7e44e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_target['title'] = data_target['title'].apply(preprocesar_texto)

# %%
filtrados = [title for title in data_target['title'] if not contains_regex_match(title, excluyentes)]

# %%
descartados_con_regex_sin_sw = obtiene_descartados(filtrados, data_target)

# %%
# Obtiene los filtrados
data_filtrados_regex_sin_sw = data_target[~data_target['title'].isin(descartados_con_regex_sin_sw)]
data_filtrados_regex_sin_sw
# Out:
#                                                   title  \
# 0     method operating comminution circuit respectiv...
# 1     process integrating mining processing together...
# 2     system method continuous optimization mineral ...
# 3     method water moisture management mining operation
# 4     method training quality prediction model proce...
# ...                                                 ...
# 3187  systems, methods, program products facilitatin...
# 3188  method system managing vehicle transportation ...
# 3189  method providing clock frequencies computing c...
# 3190  wall panels components custom enclosures shipp...
# 3191  retrofit cover plate assembly adapt alternativ...
#
#                                                abstract publication_date
# 0     A method for operating an ore comminution circ...       2020-09-03
# 1     The present invention belongs to the mining se...       2023-08-10
# 2     A method for continuously optimizing an ore gr...       2023-12-21
# 3     Wet conditions pose a plurality of hazards for...       2024-03-14
# 4     A method (1000, 1001) for training a quality p...       2022-09-22
# ...                                                 ...              ...
# 3187  Machine learning systems and methods are descr...       2023-06-13
# 3188  CA 03091162 2020-08-13 (12) INTERNATIONAL APPL...       2021-11-16
# 3189  The present disclosure relates to a method for...       2023-04-20
# 3190  Custom enclosures are made using various types...       2023-08-03
# 3191  A multi-functional retrofit cover plate assemb...       2022-06-23
#
# [3185 rows x 3 columns]

# %%
# Obtiene los descartados
data_descartados_regex_sin_sw = data_target[data_target['title'].isin(descartados_con_regex_sin_sw)]
data_descartados_regex_sin_sw
# Out:
#                                                   title  \
# 145           file system integration data mining model
# 544   arrangement delivery production control inform...
# 937   externally validated proof work appending bloc...
# 1544              interactive sequential pattern mining
# 1821  text keyword mining method device thereof, sto...
# 2020                keyword mining system mining method
# 2373  text main body keyword mining method, system d...
#
#                                                abstract publication_date
# 145   Aspects of a storage device including a memory...       2023-11-09
# 544   A method for providing a mining work machine a...       2020-01-07
# 937   A method for establishing an externally verifi...       2024-03-21
# 1544  Interactive sequential pattern mining is discl...       2020-02-18
# 1821  The invention discloses a text keyword mining ...       2022-02-18
# 2020  The invention discloses a keyword mining syste...       2021-03-26
# 2373  The invention relates to the field of patent d...       2023-05-09

# %% [markdown]
# ---
# **Observación**
#
# ---
#
# La técnica usando expresiones regulares y considerando las stopwords logra descatar 7 registros dejando 3185.

# %%
lst_resultados.append(['regex',
                      data_descartados_regex_sw.shape[0],
                      data_filtrados_regex_sw.shape[0],
                      data_descartados_regex_sin_sw.shape[0],
                      data_filtrados_regex_sin_sw.shape[0]])

# %% [markdown]
# ## Filtro usando coincidencia de prefijos y sufijos

# %%
def contains_prefix_suffix(abstract, terms):
    words = abstract.split()
    for word in words:
        for term in terms:
            if word.startswith(term) or word.endswith(term):
                return True
    return False

# %% [markdown]
# ### Experimento considerando stopwords

# %%
# Vuelve a seleecionar los datos para asegurar
data_target = data[['title', 'abstract', 'publication_date']]
data_target['title'] = data_target['title'].apply(convierte_a_minusculas)
# Out:
# <ipython-input-156-ee3b0254d62c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_target['title'] = data_target['title'].apply(convierte_a_minusculas)

# %%
filtrados = [title for title in data_target['title'] if not contains_prefix_suffix(title, excluyentes)]

# %%
descartados_con_prefix_con_sw = obtiene_descartados(filtrados, data_target)

# %%
# Obtiene los filtrados
data_filtrados_prefix_con_sw = data_target[~data_target['title'].isin(descartados_con_prefix_con_sw)]
data_filtrados_prefix_con_sw
# Out:
#                                                   title  \
# 0     method for operating a comminution circuit and...
# 1     process for integrating the mining and process...
# 2     system and method for continuous optimization ...
# 3     method for water and moisture management for a...
# 4     method for training a quality prediction model...
# ...                                                 ...
# 3187  systems, methods, and program products for fac...
# 3188  method and system for managing vehicle transpo...
# 3189  method for providing clock frequencies for com...
# 3190  wall panels and other components for custom en...
# 3191  retrofit cover plate and assembly to adapt alt...
#
#                                                abstract publication_date
# 0     A method for operating an ore comminution circ...       2020-09-03
# 1     The present invention belongs to the mining se...       2023-08-10
# 2     A method for continuously optimizing an ore gr...       2023-12-21
# 3     Wet conditions pose a plurality of hazards for...       2024-03-14
# 4     A method (1000, 1001) for training a quality p...       2022-09-22
# ...                                                 ...              ...
# 3187  Machine learning systems and methods are descr...       2023-06-13
# 3188  CA 03091162 2020-08-13 (12) INTERNATIONAL APPL...       2021-11-16
# 3189  The present disclosure relates to a method for...       2023-04-20
# 3190  Custom enclosures are made using various types...       2023-08-03
# 3191  A multi-functional retrofit cover plate assemb...       2022-06-23
#
# [3192 rows x 3 columns]

# %%
# Obtiene los descartados
data_descartados_prefix_con_sw = data_target[data_target['title'].isin(descartados_con_prefix_con_sw)]
data_descartados_prefix_con_sw
# Out:
# Empty DataFrame
# Columns: [title, abstract, publication_date]
# Index: []

# %% [markdown]
# ### Experimento descartando stopwords

# %%
# Vuelve a seleecionar los datos para asegurar
data_target = data[['title', 'abstract', 'publication_date']]
data_target['title'] = data_target['title'].apply(convierte_a_minusculas)
data_target['title'] = data_target['title'].apply(preprocesar_texto)
# Out:
# <ipython-input-161-0c1e2dc7e44e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_target['title'] = data_target['title'].apply(convierte_a_minusculas)
# <ipython-input-161-0c1e2dc7e44e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_target['title'] = data_target['title'].apply(preprocesar_texto)

# %%
filtrados = [title for title in data_target['title'] if not contains_prefix_suffix(title, excluyentes)]

# %%
descartados_con_prefix_sin_sw = obtiene_descartados(filtrados, data_target)

# %%
# Obtiene los filtrados
data_filtrados_prefix_sin_sw = data_target[~data_target['title'].isin(descartados_con_prefix_sin_sw)]
data_filtrados_prefix_sin_sw
# Out:
#                                                   title  \
# 0     method operating comminution circuit respectiv...
# 1     process integrating mining processing together...
# 2     system method continuous optimization mineral ...
# 3     method water moisture management mining operation
# 4     method training quality prediction model proce...
# ...                                                 ...
# 3187  systems, methods, program products facilitatin...
# 3188  method system managing vehicle transportation ...
# 3189  method providing clock frequencies computing c...
# 3190  wall panels components custom enclosures shipp...
# 3191  retrofit cover plate assembly adapt alternativ...
#
#                                                abstract publication_date
# 0     A method for operating an ore comminution circ...       2020-09-03
# 1     The present invention belongs to the mining se...       2023-08-10
# 2     A method for continuously optimizing an ore gr...       2023-12-21
# 3     Wet conditions pose a plurality of hazards for...       2024-03-14
# 4     A method (1000, 1001) for training a quality p...       2022-09-22
# ...                                                 ...              ...
# 3187  Machine learning systems and methods are descr...       2023-06-13
# 3188  CA 03091162 2020-08-13 (12) INTERNATIONAL APPL...       2021-11-16
# 3189  The present disclosure relates to a method for...       2023-04-20
# 3190  Custom enclosures are made using various types...       2023-08-03
# 3191  A multi-functional retrofit cover plate assemb...       2022-06-23
#
# [3192 rows x 3 columns]

# %%
# Obtiene los descartados
data_descartados_prefix_sin_sw = data_target[data_target['title'].isin(descartados_con_prefix_sin_sw)]
data_descartados_prefix_sin_sw
# Out:
# Empty DataFrame
# Columns: [title, abstract, publication_date]
# Index: []

# %%
lst_resultados.append(['prefix-sufix',
                      data_descartados_prefix_con_sw.shape[0],
                      data_filtrados_prefix_con_sw.shape[0],
                      data_descartados_prefix_sin_sw.shape[0],
                      data_filtrados_prefix_sin_sw.shape[0]])

# %% [markdown]
# # Resumen

# %%
df_resultados = pd.DataFrame(lst_resultados, columns=['tecnica', 'descartados_con_SW', 'filtrados_con_SW',
                                      'descartados_sin_SW', 'filtrados_sin_SW'])
df_resultados
# Out:
#               tecnica  descartados_con_SW  filtrados_con_SW  \
# 0  fuzzy - umbral 90%                2170              1022
# 1               stemm                   0              3192
# 2               regex                   5              3187
# 3        prefix-sufix                   0              3192
#
#    descartados_sin_SW  filtrados_sin_SW
# 0                1203              1989
# 1                   0              3192
# 2                   7              3185
# 3                   0              3192

# %%
# Aplicar bordes a todas las celdas
df_styled = df_resultados.style.set_table_styles(
    [{'selector': 'td', 'props': [('border', '2px solid black')]}]
)
# 2. Aplicar un estilo diferente a la primera columna
df_styled = df_styled.set_table_styles(
    {
        'Col1': [{'selector': 'td', 'props': [('background-color', 'yellow'), ('color', 'red'), ('font-weight', 'bold')]}]
    },
    overwrite=False  # Para mantener los estilos previos
)
df_styled
# Out:
# <style type="text/css">
# #T_ffe80 td {
#   border: 2px solid black;
# }
# #T_ffe80 td.col-1 {
#   background-color: yellow;
#   color: red;
#   font-weight: bold;
# }
# </style>
# <table id="T_ffe80" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ffe80_level0_col0" class="col_heading level0 col0" >tecnica</th>
#       <th id="T_ffe80_level0_col1" class="col_heading level0 col1" >descartados_con_SW</th>
#       <th id="T_ffe80_level0_col2" class="col_heading level0 col2" >filtrados_con_SW</th>
#       <th id="T_ffe80_level0_col3" class="col_heading level0 col3" >descartados_sin_SW</th>
#       <th id="T_ffe80_level0_col4" class="col_heading level0 col4" >filtrados_sin_SW</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ffe80_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ffe80_row0_col0" class="data row0 col0" >fuzzy - umbral 90%</td>
#       <td id="T_ffe80_row0_col1" class="data row0 col1" >2170</td>
#       <td id="T_ffe80_row0_col2" class="data row0 col2" >1022</td>
#       <td id="T_ffe80_row0_col3" class="data row0 col3" >1203</td>
#       <td id="T_ffe80_row0_col4" class="data row0 col4" >1989</td>
#     </tr>
#     <tr>
#       <th id="T_ffe80_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ffe80_row1_col0" class="data row1 col0" >stemm</td>
#       <td id="T_ffe80_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_ffe80_row1_col2" class="data row1 col2" >3192</td>
#       <td id="T_ffe80_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_ffe80_row1_col4" class="data row1 col4" >3192</td>
#     </tr>
#     <tr>
#       <th id="T_ffe80_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ffe80_row2_col0" class="data row2 col0" >regex</td>
#       <td id="T_ffe80_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_ffe80_row2_col2" class="data row2 col2" >3187</td>
#       <td id="T_ffe80_row2_col3" class="data row2 col3" >7</td>
#       <td id="T_ffe80_row2_col4" class="data row2 col4" >3185</td>
#     </tr>
#     <tr>
#       <th id="T_ffe80_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ffe80_row3_col0" class="data row3 col0" >prefix-sufix</td>
#       <td id="T_ffe80_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_ffe80_row3_col2" class="data row3 col2" >3192</td>
#       <td id="T_ffe80_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_ffe80_row3_col4" class="data row3 col4" >3192</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---
# #Código NO CONSIDERADO

# %%
def preprocess_text_v(text):
	# Definir stopwords y puntuación
	stop_words = set(stopwords.words('english'))
	punctuation = set(string.punctuation)
  # Convertir a string y manejar NaN
	if isinstance(text, float):
		return []
  # Tokenizar el texto
	tokens = word_tokenize(text.lower())
	text = text.translate(str.maketrans('', '', string.punctuation))
	# Filtrar stopwords y puntuación
	tokens = [word for word in tokens if word not in stop_words and word not in punctuation]
	return tokens

# %%
# Definir stopwords y puntuación
stop_words = set(stopwords.words('english'))
punctuation = set(string.punctuation)

# Aplicar el preprocesamiento a la columna de abstracts
lst_tokens = data_target['abstract'].apply(preprocess_text_v)
data_target['tokens'] = [token for token in lst_tokens]
# Out:
# <ipython-input-11-8dfbebcdab31>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_target['tokens'] = [token for token in lst_tokens]

# %%
data_target.tokens.head()
# Out:
# 0    [method, operating, ore, comminution, circuit,...
# 1    [present, invention, belongs, mining, sector, ...
# 2    [method, continuously, optimizing, ore, grindi...
# 3    [wet, conditions, pose, plurality, hazards, mi...
# 4    [method, 1000, 1001, training, quality, predic...
# Name: tokens, dtype: object
